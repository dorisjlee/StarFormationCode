# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import yt

# %%
ds= yt.load("output_00001/info_00001.txt")
# Out:
# yt : [INFO     ] 2015-05-19 15:30:12,953 Parameters: current_time              = 0.0
# yt : [INFO     ] 2015-05-19 15:30:12,953 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2015-05-19 15:30:12,955 Parameters: domain_left_edge          = [ 0.  0.  0.]
# yt : [INFO     ] 2015-05-19 15:30:12,956 Parameters: domain_right_edge         = [ 1.  1.  1.]
# yt : [INFO     ] 2015-05-19 15:30:12,957 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2015-05-19 15:30:12,957 Parameters: current_redshift          = 0.0
# yt : [INFO     ] 2015-05-19 15:30:12,957 Parameters: omega_lambda              = 0.0
# yt : [INFO     ] 2015-05-19 15:30:12,958 Parameters: omega_matter              = 1.0
# yt : [INFO     ] 2015-05-19 15:30:12,958 Parameters: hubble_constant           = 0.01

# %%
p = yt.ProjectionPlot(ds, "y", "density")
p.show()
# Out:
# yt : [INFO     ] 2015-05-18 09:50:05,961 Loading field plugins.
# yt : [INFO     ] 2015-05-18 09:50:05,962 Loaded angular_momentum (8 new fields)
# yt : [INFO     ] 2015-05-18 09:50:05,962 Loaded astro (15 new fields)
# yt : [INFO     ] 2015-05-18 09:50:05,963 Loaded cosmology (22 new fields)
# yt : [WARNING  ] 2015-05-18 09:50:05,964 Field ('gas', 'pressure') already exists. To override use force_override=True.
# yt : [INFO     ] 2015-05-18 09:50:05,965 Loaded fluid (63 new fields)
# yt : [INFO     ] 2015-05-18 09:50:05,966 Loaded fluid_vector (95 new fields)
# yt : [INFO     ] 2015-05-18 09:50:05,967 Loaded geometric (111 new fields)
# yt : [INFO     ] 2015-05-18 09:50:05,967 Loaded local (111 new fields)
# yt : [INFO     ] 2015-05-18 09:50:05,968 Loaded magnetic_field (119 new fields)
# yt : [INFO     ] 2015-05-18 09:50:05,969 Loaded my_plugins (119 new fields)
# yt : [INFO     ] 2015-05-18 09:50:05,970 Loaded species (121 new fields)
# ...

# %%
ds= yt.load("../../bin/output_00001/info_00001.txt")
p = yt.ProjectionPlot(ds, "y", "density")
p.show()
# Out:
# yt : [INFO     ] 2015-05-19 20:42:39,226 Parameters: current_time              = 0.0
# yt : [INFO     ] 2015-05-19 20:42:39,227 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2015-05-19 20:42:39,228 Parameters: domain_left_edge          = [ 0.  0.  0.]
# yt : [INFO     ] 2015-05-19 20:42:39,229 Parameters: domain_right_edge         = [ 1.  1.  1.]
# yt : [INFO     ] 2015-05-19 20:42:39,230 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2015-05-19 20:42:39,230 Parameters: current_redshift          = 0.0
# yt : [INFO     ] 2015-05-19 20:42:39,231 Parameters: omega_lambda              = 0.0
# yt : [INFO     ] 2015-05-19 20:42:39,232 Parameters: omega_matter              = 1.0
# yt : [INFO     ] 2015-05-19 20:42:39,232 Parameters: hubble_constant           = 0.01
# yt : [INFO     ] 2015-05-19 20:42:40,281 Loading field plugins.
# yt : [INFO     ] 2015-05-19 20:42:40,281 Loaded angular_momentum (8 new fields)
# ...

# %%
ds= yt.load("../../bin/output_00002/info_00002.txt")
p = yt.ProjectionPlot(ds, "y", "density")
p.show()
# Out:
# yt : [INFO     ] 2015-05-19 20:45:46,964 Parameters: current_time              = 1.82287109602e+25
# yt : [INFO     ] 2015-05-19 20:45:46,964 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2015-05-19 20:45:46,965 Parameters: domain_left_edge          = [ 0.  0.  0.]
# yt : [INFO     ] 2015-05-19 20:45:46,967 Parameters: domain_right_edge         = [ 1.  1.  1.]
# yt : [INFO     ] 2015-05-19 20:45:46,969 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2015-05-19 20:45:47,955 Loading field plugins.
# yt : [INFO     ] 2015-05-19 20:45:47,955 Loaded angular_momentum (8 new fields)
# yt : [INFO     ] 2015-05-19 20:45:47,956 Loaded astro (15 new fields)
# yt : [INFO     ] 2015-05-19 20:45:47,956 Loaded cosmology (22 new fields)
# yt : [WARNING  ] 2015-05-19 20:45:47,957 Field ('gas', 'pressure') already exists. To override use force_override=True.
# yt : [INFO     ] 2015-05-19 20:45:47,959 Loaded fluid (63 new fields)
# ...

# %% [markdown]
# # Using amr2map

# %% [markdown]
# - can not tuse amr2cube because this creates a __uniform__ data cube (with a bunch of AAAAAAAAA...., I dont really see what the point of this is..)
# -
#
# ``dorislee@edison11:~/ramses/trunk/ramses> utils/f90/amr2map -inp patch/isothermalsphere/output_00001 -out dens.map -typ 1 -nx 512 -ny 512 -fil ascii
#  ordering type=             hilbert
#  time=  0.000000000000000E+000
#  Working resolution =        1024
#  Processing file patch/isothermalsphere/output_00001/amr_00001.out00001
#            1           8          64         512        4096       32768
#       262144     2097152           0           0
#  Norm=  1.100000029715560E-019``

# %%
# cd run1/

# %%
from matplotlib.colors import LogNorm
data= np.loadtxt("dens.map")

# %%
data.shape
# Out:
# (1048576, 3)

# %%
rho
# Out:
# array([[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        ...,
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan]])

# %% [markdown]
# ### With boxlen of 2e17

# %%
width = sqrt(size(data[:,2]))
rho  = data[:,2].reshape(width,width)
plt.imshow(rho)#,cmap=cm.gray_r, norm=LogNorm())
plt.xlabel("x [cm]")
plt.ylabel("y [cm]")

# %% [markdown]
# ### With boxlen of 3e17

# %%
width = sqrt(size(data[:,2]))
rho  = data[:,2].reshape(width,width)
plt.imshow(rho)#,cmap=cm.gray_r, norm=LogNorm())
plt.xlabel("x [cm]")
plt.ylabel("y [cm]")

# %% [markdown]
# ### With a boxlen of 3.5e17

# %%
width = sqrt(size(data[:,2]))
rho  = data[:,2].reshape(width,width)
plt.imshow(rho)#,cmap=cm.gray_r, norm=LogNorm())
plt.xlabel("x [cm]")
plt.ylabel("y [cm]")

# %%
data2= np.loadtxt("dens2.map")

# %%
data2.shape
# Out:
# (263169, 3)

# %% [raw]
# dorislee@edison11:~/ramses/trunk/ramses> utils/f90/amr2map -inp patch/isothermalsphere/output_00002 -out dens2.map -typ 1 -nx 512 -ny 512 -fil ascii
#  ordering type=             hilbert
#  time=   10416250.0333115
#  Working resolution =        1024
#  Processing file patch/isothermalsphere/output_00002/amr_00002.out00001
#            1           8          64         512        4096       32768
#       262144     2097152           0           0
#  Norm=                     NaN

# %%
imshow()
# Out:
# (263169, 3)

# %%
width = sqrt(size(data2[:,2]))
rho  = data2[:,2].reshape(width,width)
plt.imshow(rho)
plt.xlabel("x [cm]")
plt.ylabel("y [cm]")
# Out:
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/numpy/ma/core.py:3895: UserWarning: Warning: converting a masked element to nan.
#   warnings.warn("Warning: converting a masked element to nan.")

# %% [markdown]
# Checking if the is.nml is okay

# %% [markdown]
# - what's flow variables? d_region, u_region..etc?

# %% [markdown]
# - since I copied this over unchagned from sedov's setup. The INIT_PARAMS that they set was kind of strange. They first defined two regions, one square and one point. Then for all the initial parameters they defined different values for each of the region. Now I just set everything back as default value for a single square region.

# %% [markdown]
# #### Calculating initial condition for P by IC of $\rho$ and T using ideal gas law

# %% [markdown]
# $P=\rho R T$ in cgs

# %%
1.1e-19*3.36e7*10
# Out:
# 3.6959999999999994e-11

# %%
1.1e-25*3.36e7*10
# Out:
# 3.696e-17
