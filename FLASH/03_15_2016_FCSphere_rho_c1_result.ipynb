# %%
import yt
yt.mylog.setLevel(50)
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ~/project/FLASH4.3/object/
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3/object

# %%
def plot_all(i):
    ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
    physical_quantity="density"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_figure_size(5)
    slc.annotate_grids()
    slc.set_cmap("all","rainbow")
    slc.show()

    physical_quantity="pressure"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_cmap("all","rainbow")
    slc.set_figure_size(5)
    slc.set_log("all", False)
    # slc.set_zlim(physical_quantity,58,60)
    slc.show()

    physical_quantity="temperature"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_cmap("all","rainbow")
    slc.set_figure_size(5)
    # slc.set_log("all", False)
    # slc.set_zlim(physical_quantity,58,60)
    slc.show()

# %%
plot_all(0)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
def plot_dens(i):
    ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
    physical_quantity="density"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_figure_size(5)
    slc.annotate_grids()
    slc.annotate_velocity()
    slc.set_cmap("all","rainbow")
    slc.show()

# %%
for i in np.arange(22):
    plot_dens(i)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# ...

# %% [markdown]
# After waiting for 5 days in the queue, I finally got to run my 2 hour regular job. The actual thing took 8954.415 seconds, which is around 2.5 hours, with AMR

# %% [markdown]
# I evolved it for 2200 seconds, which is about 1 tff time (1tff = 2101 s). Clearly I needed to evolve it for longer, but I need to figure out this restart file business because the queue time is way to long.

# %% [markdown]
# ## Trying to figure out how the restart file works :

# %% [markdown]
# - tried putting the restart values inside the copy of flash.par inside object, but didn't restart just started from the beginning because the checkpointFilenumber and plotfileNumber were set as zero after that so the values are overwritten . Now if I take those out then I DO get the restart !!

# %% [raw]
# restart         = .true.
# checkpointFileNumber = 22
# plotfileNumber = 44

# %% [raw]
# Initial plotfile written
#  Driver init all done
#  *** Wrote plotfile to sod_hdf5_plt_cnt_0044 ****
#        n          t         dt  (         x,          y,          z) |  dt_hydro
#     8128 2.2003E+03 1.3585E-01  ( 5.273E+08,  2.461E+08,  5.117E+08) |  1.359E-01
#  *** Wrote checkpoint file to sod_hdf5_chk_0023 ****
#  exiting: reached max SimTime
#  *** Wrote plotfile to sod_forced_hdf5_plt_cnt_0001 ****

# %%
plot_dens(25)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
