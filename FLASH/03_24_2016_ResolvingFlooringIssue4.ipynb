# %% [markdown]
# I realized in my config file I forgot to set the smlrho , I only set the smallp, smalle, and smallt and tiny!!!! Because this is not smallr it's smlrho! The spelling is different!!

# %% [raw]
# Computing default values for options not specified on command line
#
#     INFO: Parameter smallp defined in both
#     physics/Hydro/HydroMain/unsplit (default 1.E-10) and
#     Simulation/SimulationMain/UniformSphere_small_dens (default 1.e-30)
#     Simulation instance overrides; removing other instance.
#
#     INFO: Parameter smlrho defined in both
#     physics/Hydro/HydroMain/unsplit (default 1.E-10) and
#     Simulation/SimulationMain/UniformSphere_small_dens (default 1.e-30)
#     Simulation instance overrides; removing other instance.
#
#     INFO: Parameter smallt defined in both
#     physics/Hydro/HydroMain/unsplit (default 1.E-10) and
#     Simulation/SimulationMain/UniformSphere_small_dens (default 1.e-30)
#     Simulation instance overrides; removing other instance.
#
#     INFO: Parameter tiny defined in both
#     physics/Hydro/HydroMain/unsplit (default 1.e-16) and
#     Simulation/SimulationMain/UniformSphere_small_dens (default 1.e-30)
#     Simulation instance overrides; removing other instance.
#
#     INFO: Parameter smalle defined in both
#     Grid/GridMain (default 1.E-10) and
#     Simulation/SimulationMain/UniformSphere_small_dens (default 1.e-30)
#     Simulation instance overrides; removing other instance.

# %%
import yt
yt.mylog.setLevel(50)
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ../../../projects/FLASH4.3/object/
# Out:
# /Users/dorislee/Desktop/projects/FLASH4.3/object

# %%
# cd ~/project/FLASH4.3/object/

# %%
def plot_dens(i):
    ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
    physical_quantity="density"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_figure_size(5)
    slc.annotate_grids()
    slc.annotate_velocity()
    slc.set_cmap("all","rainbow")
    slc.show()

# %%
def plot_all(i):
    ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
    physical_quantity="density"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_figure_size(5)
    slc.annotate_grids()
    slc.set_cmap("all","rainbow")
    slc.show()

    physical_quantity="pressure"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_cmap("all","rainbow")
    slc.set_figure_size(5)
    slc.set_log("all", False)
    # slc.set_zlim(physical_quantity,58,60)
    slc.show()

    physical_quantity="temperature"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_cmap("all","rainbow")
    slc.set_figure_size(5)
    # slc.set_log("all", False)
    # slc.set_zlim(physical_quantity,58,60)
    slc.show()

# %% [markdown]
# # 271739.out

# %% [markdown]
# rhoOut                  = 1.0E-31
# rhoIn                   = 1.0

# %%
cd US_small_floor/
# Out:
# /Users/dorislee/Desktop/projects/FLASH4.3/object/US_small_floor

# %%
i=0
ds = yt.load("uniform_sphere_hdf5_plt_cnt_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.set_cmap("all","rainbow")
slc.show()
# Out:
# <img src="data:image/png;base64,..."><br>

# %%
plot_dens(2)
# Out:
# <img src="data:image/png;base64,..."><br>

# %%
plot_dens(3)
# Out:
# <img src="data:image/png;base64,..."><br>

# %%
plot_dens(5)
# Out:
# <img src="data:image/png;base64,..."><br>

# %% [markdown]
# Sucessfully finishes the run for 1 tff

# %% [markdown]
# # 271692

# %% [markdown]
# Now if I lower the rhoIn below the default floor , then it will uniform the whole box then crash

# %% [markdown]
# rhoOut                  = 1.0E-31
# rhoIn                   = 1.0E-15

# %%
i=0
ds = yt.load("uniform_sphere_hdf5_plt_cnt_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.set_cmap("all","rainbow")
slc.show()
# Out:
# <img src="data:image/png;base64,..."><br>

# %%
plot_dens(1)
# Out:
# <img src="data:image/png;base64,..."><br>

# %%
plot_dens(5)
# Out:
# <img src="data:image/png;base64,..."><br>

# %% [markdown]
# okay lesson learned smlrho __not__ smallr

# %% [markdown]
# ### Without REQUIRE Grid

# %% [markdown]
# still see :
#
#     Computing default values for options not specified on command line
#
#     INFO: Parameter smallp defined in both
#     physics/Hydro/HydroMain/unsplit (default 1.E-10) and
#     Simulation/SimulationMain/UniformSphere_small_dens (default 1.e-30)
#     Simulation instance overrides; removing other instance.
#
#     INFO: Parameter smlrho defined in both
#     physics/Hydro/HydroMain/unsplit (default 1.E-10) and
#     Simulation/SimulationMain/UniformSphere_small_dens (default 1.e-30)
#     Simulation instance overrides; removing other instance.
#
#     INFO: Parameter smallt defined in both
#     physics/Hydro/HydroMain/unsplit (default 1.E-10) and
#     Simulation/SimulationMain/UniformSphere_small_dens (default 1.e-30)
#     Simulation instance overrides; removing other instance.
#
#     INFO: Parameter tiny defined in both
#     physics/Hydro/HydroMain/unsplit (default 1.e-16) and
#     Simulation/SimulationMain/UniformSphere_small_dens (default 1.e-30)
#     Simulation instance overrides; removing other instance.
#
#     INFO: Parameter smalle defined in both
#     Grid/GridMain (default 1.E-10) and
#     Simulation/SimulationMain/UniformSphere_small_dens (default 1.e-30)
#     Simulation instance overrides; removing other instance.

# %%
plot_dens(0)
plot_dens(1)
plot_dens(5)
# Out:
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/matplotlib/quiver.py:570: RuntimeWarning: divide by zero encountered in double_scalars
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/matplotlib/quiver.py:570: RuntimeWarning: invalid value encountered in multiply
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/matplotlib/quiver.py:626: RuntimeWarning: invalid value encountered in less
#   short = np.repeat(length < minsh, 8, axis=1)
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/matplotlib/quiver.py:636: RuntimeWarning: invalid value encountered in less
#   tooshort = length < self.minlength
# <img src="data:image/png;base64,..."><br>
# <img src="data:image/png;base64,..."><br>
# <img src="data:image/png;base64,..."><br>

# %% [markdown]
# Okay so it works without the Grid

# %% [markdown]
# # Without +unsplithydro; Grid back on (271910.out)

# %%
plot_dens(0)
plot_dens(1)
plot_dens(5)
# Out:
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/matplotlib/quiver.py:570: RuntimeWarning: divide by zero encountered in double_scalars
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/matplotlib/quiver.py:570: RuntimeWarning: invalid value encountered in multiply
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/matplotlib/quiver.py:626: RuntimeWarning: invalid value encountered in less
#   short = np.repeat(length < minsh, 8, axis=1)
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/matplotlib/quiver.py:636: RuntimeWarning: invalid value encountered in less
#   tooshort = length < self.minlength
# <img src="data:image/png;base64,..."><br>
# <img src="data:image/png;base64,..."><br>
# <img src="data:image/png;base64,..."><br>

# %% [markdown]
# Computing default values for options not specified on command line
#
#     INFO: Parameter smallp defined in both
#     physics/Hydro/HydroMain/split/PPM (default 1.E-10) and
#     Simulation/SimulationMain/UniformSphere_small_dens (default 1.e-30)
#     Simulation instance overrides; removing other instance.
#
#     INFO: Parameter smlrho defined in both
#     physics/Hydro/HydroMain/split/PPM (default 1.E-10) and
#     Simulation/SimulationMain/UniformSphere_small_dens (default 1.e-30)
#     Simulation instance overrides; removing other instance.
#
#     INFO: Parameter smallt defined in both
#     physics/Hydro/HydroMain/split/PPM (default 1.E-10) and
#     Simulation/SimulationMain/UniformSphere_small_dens (default 1.e-30)
#     Simulation instance overrides; removing other instance.
#
#     INFO: Parameter smalle defined in both
#     physics/Hydro/HydroMain/split/PPM (default 1.E-10) and
#     Simulation/SimulationMain/UniformSphere_small_dens (default 1.e-30)
#     Simulation instance overrides; removing other instance.
# Using Makefile.h: /global/homes/d/dorislee/project/FLASH4.3/sites/edison.nersc.gov/Makefile.h
# generating Makefile

# %% [markdown]
# So this did work

# %% [markdown]
# # Overriding only smlrho (271988.out)
# Computing default values for options not specified on command line
#
#     INFO: Parameter smlrho defined in both
#     physics/Hydro/HydroMain/unsplit (default 1.E-10) and
#     Simulation/SimulationMain/UniformSphere_small_dens (default 1.e-30)
#     Simulation instance overrides; removing other instance.

# %%
plot_dens(0)
# plot_dens(1)
# plot_dens(5)
# Out:
# <img src="data:image/png;base64,..."><br>

# %% [raw]
#  [ 03-24-2016  20:16:43.318 ] WARNING after gc filling: min. unk(ENER_VAR)=1.0000000000000001E-11 PE=0 block=1560 type=1
#  [ 03-24-2016  20:16:43.324 ] WARNING after gc filling: min. unk(EINT_VAR)=1.0000000000000001E-11 PE=0 block=1560 type=1
#  [ 03-24-2016  20:16:43.328 ] WARNING after gc filling: min. unk(ENER_VAR)=1.0000000000000001E-11 PE=0 block=1561 type=1
#  [ 03-24-2016  20:16:43.332 ] WARNING after gc filling: min. unk(EINT_VAR)=1.0000000000000001E-11 PE=0 block=1561 type=1
#  [ 03-24-2016  20:16:43.336 ] WARNING after gc filling: min. unk(ENER_VAR)=1.0000000000000001E-11 PE=0 block=1562 type=1
#  [ 03-24-2016  20:16:43.340 ] WARNING after gc filling: min. unk(EINT_VAR)=1.0000000000000001E-11 PE=0 block=1562 type=1

# %% [markdown]
# Eint and energy too low

# %% [markdown]
# # no tiny but smalle,smallp,smallt,smlrho set

# %%
plot_dens(0)
# Out:
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/matplotlib/quiver.py:570: RuntimeWarning: divide by zero encountered in double_scalars
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/matplotlib/quiver.py:570: RuntimeWarning: invalid value encountered in multiply
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/matplotlib/quiver.py:626: RuntimeWarning: invalid value encountered in less
#   short = np.repeat(length < minsh, 8, axis=1)
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/matplotlib/quiver.py:636: RuntimeWarning: invalid value encountered in less
#   tooshort = length < self.minlength
# <img src="data:image/png;base64,..."><br>

# %%
plot_dens(5)
# Out:
# <img src="data:image/png;base64,..."><br>
