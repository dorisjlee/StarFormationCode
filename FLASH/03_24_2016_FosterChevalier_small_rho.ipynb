# %%
import yt
yt.mylog.setLevel(50)
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ../../../projects/FLASH4.3_2/object/
# Out:
# /Users/dorislee/Desktop/projects/FLASH4.3_2/object

# %%
# cd ~/project/FLASH4.3/object/

# %%
def plot_dens(i):
    ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
    physical_quantity="density"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_figure_size(5)
    slc.annotate_grids()
    slc.annotate_velocity()
    slc.set_cmap("all","rainbow")
    slc.show()

# %%
def plot_all(i):
    ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
    physical_quantity="density"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_figure_size(5)
    slc.annotate_grids()
    slc.set_cmap("all","rainbow")
    slc.show()

    physical_quantity="pressure"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_cmap("all","rainbow")
    slc.set_figure_size(5)
    slc.set_log("all", False)
    # slc.set_zlim(physical_quantity,58,60)
    slc.show()

    physical_quantity="temperature"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_cmap("all","rainbow")
    slc.set_figure_size(5)
    # slc.set_log("all", False)
    # slc.set_zlim(physical_quantity,58,60)
    slc.show()

# %% [raw]
#  DRIVER_ABORT: ^M
#  [Eos_putData] ERROR Density or Internal Energy are zero after a call to EOS!^M
#  DRIVER_ABORT: ^M
#  [Eos_putData] ERROR Density or Internal Energy are zero after a call to EOS!^M
#  DRIVER_ABORT: ^M
#  [Eos_putData] ERROR Density or Internal Energy are zero after a call to EOS!^M
#  DRIVER_ABORT: ^M
#  [Eos_putData] ERROR Density or Internal Energy are zero after a call to EOS!^M
#  DRIVER_ABORT: ^M
#  [Eos_putData] ERROR Density or Internal Energy are zero after a call to EOS!^M
#  ERROR After calling Eos, eosData(EOS_EINT) or eosData(EOS_DENS) are zero^M
#  iflag=           0           0           0           1           1           0^M
#            0           0^M
#  solnData(EINT_VAR,ib:ie,jb,kb)=  8.253606491685942E+017  8.253606491685942E+017^M
#   8.253606491685942E+017                     NaN                     NaN^M
#   8.253606491685942E+017  8.253606491685942E+017  8.253606491685942E+017^M
#  eosData (eint+1:eint+vecLen)  =  8.253606491685942E+017  8.253606491685942E+017^M
#   8.253606491685942E+017  1.000000000000000E-030  1.000000000000000E-030^M
#   8.253606491685942E+017  8.253606491685942E+017  8.253606491685942E+017^M
#  solnData(DENS_VAR,ib:ie,jb,kb)=  7.985600000000000E-027  7.985600000000000E-027^M
#   7.985600000000000E-027  0.000000000000000E+000  0.000000000000000E+000^M
#   7.985600000000000E-027  7.985600000000000E-027  7.985600000000000E-027^M
#  eosData(dens+1:dens+vecLen)   =  7.985600000000000E-027  7.985600000000000E-027^M
#   7.985600000000000E-027  0.000000000000000E+000  0.000000000000000E+000^M
#   7.985600000000000E-027  7.985600000000000E-027  7.985600000000000E-027^M
#    Perhaps the initialization routine is wrong..... or^M
#    perhaps the runtime parameter eosMode is wrong.^M
#       Check constants.h to determine value of MODE_DENS_??^M
#   ^M
#  Driver_abort called. See log file for details.^M
#  Error message is ^M
#  [Eos_putData] ERROR Density or Internal Energy are zero after a call to EOS!^M
#  Calling MPI_Abort() for shutdown in   2 seconds!^M

# %% [markdown]
# so the reason why its doing this is because I forgot to copy the density.txt over in the FLASH/ directory

# %%
plot_all(0)
# Out:
# <img src="data:image/png;base64,..."><br>
# <img src="data:image/png;base64,..."><br>
# <img src="data:image/png;base64,..."><br>

# %%
plot_dens(2)
# Out:
# <img src="data:image/png;base64,..."><br>

# %%
plot_dens(7)
# Out:
# <img src="data:image/png;base64,..."><br>

# %%
plot_dens(25)
# Out:
# <img src="data:image/png;base64,..."><br>

# %%
plot_dens(28)
# Out:
# <img src="data:image/png;base64,..."><br>
