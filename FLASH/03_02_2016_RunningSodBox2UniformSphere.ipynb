# %%
import yt
yt.mylog.setLevel(50)
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ~/project/FLASH4.3/object/
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3/object

# %%
i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
# slc.set_log("all", False)
# slc.set_zlim(physical_quantity,0,1)
slc.show()

ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
#59.6525
slc.set_zlim(physical_quantity,58,60)
slc.show()

ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="temperature"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
# slc.set_log("all", False)
# slc.set_zlim(physical_quantity,5e-8,5e-9)
slc.show()
# sim_rhoLeft    = 2.386E6 #1.
# sim_rhoRight   = 23861.3108 #0.125
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
i = 1
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
# slc.set_log("all", False)
# slc.set_zlim(physical_quantity,0,1)
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [raw]
# Woah what's going on here. The program crashed because of Nonconvergence in subroutine rieman
#
# vim 204338.out

# %% [raw]
#  gamma_cL =    1.00100000000000       gamma_cR =   1.00100000000000
#
#  Iteration history:
#
#    n                    p*
#    1    0.100000000000E-09
#    2    0.452631557025E+02
#    3    0.438744473183E+02
#    4    0.100000000000E-09
#    5    0.425581303305E+02
#    6    0.413096027854E+02
#    7    0.100000000000E-09
#    8    0.401246102978E+02
#    9    0.389992156941E+02
#   10    0.100000000000E-09
#   11    0.379297716608E+02
#   12    0.369128960666E+02
#
#  Terminating execution.
#  DRIVER_ABORT: Nonconvergence in subroutine rieman
