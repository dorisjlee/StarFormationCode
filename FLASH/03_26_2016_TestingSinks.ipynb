# %%
import yt
yt.mylog.setLevel(50)
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ~/project/FLASH4.3/object/
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3/object

# %%
def plot_all(i):
    ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
    physical_quantity="density"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_figure_size(5)
    slc.annotate_grids()
#     slc.set_log("all", False)
    slc.set_cmap("all","rainbow")
    slc.show()

    physical_quantity="pressure"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_cmap("all","rainbow")
    slc.set_figure_size(5)
    slc.set_log("all", False)
    # slc.set_zlim(physical_quantity,58,60)
    slc.show()

    physical_quantity="temperature"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_cmap("all","rainbow")
    slc.set_figure_size(5)
#     slc.set_zlim(physical_quantity,58,60)
    slc.set_log("all", False)
    slc.show()

# %% [markdown]
# The first thing I noticed when I ran this with sink is that there's a lot of sod_hdf5_part_* files getting spit out like 700!!'

# %% [markdown]
# These are set by :
#
#     particleFileIntervalTime = 1.E12
#     particleFileIntervalStep = 0
#     particleFileNumber = 0

# %%
plot_all(0)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [raw]
# I'm getting a warning :
#
#  WARNING: globalNumParticles = 0!!!'

# %% [raw]
# SinkParticles: You have set the sink particle accretion radius to   0.00 * (1+redshift) cells at the highest level of refinement.
# CAUTION: Sink particle accretion radius is not within the recommended range (2-3 cells)!
#          Sink particle creation checks might fail!
#  WARNING: globalNumParticles = 0!!!

# %% [markdown]
# yt says "but particle files are not currently directly loadable by themselves, due to the fact that they typically lack grid information. "

# %%
i=1
physical_quantity="density"
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)), particle_filename="sod_hdf5_part_{}".format(str(i).zfill(4)))
slc = yt.SlicePlot(ds, "z",physical_quantity)
# Out:
# ---------------------------------------------------------------------------
# YTOutputNotIdentified                     Traceback (most recent call last)
# <ipython-input-31-8b761471d133> in <module>()
#       1 i=1
#       2 physical_quantity="density"
# ----> 3 ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)), particle_filename="sod_hdf5_part_{}".format(str(i).zfill(4)))
#       4 slc = yt.SlicePlot(ds, "z",physical_quantity)
#
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/yt/convenience.pyc in load(*args, **kwargs)
#      72         mylog.error("None of the arguments provided to load() is a valid file")
#      73         mylog.error("Please check that you have used a correct path")
# ---> 74         raise YTOutputNotIdentified(args, kwargs)
#      75     for n, c in output_type_registry.items():
#      76         if n is None: continue
#
# YTOutputNotIdentified: Supplied ('sod_hdf5_chk_0001',) {'particle_filename': 'sod_hdf5_part_0001'}, but could not load!

# %%
dd = ds.all_data()
# print dd["particle_position_x"]
# print dd["particle_position_y"]
# print dd["particle_position_z"]

# %%
# print dd["particle_position_x"]

# %%
# ds.field_info

# %% [markdown]
# http://flash.uchicago.edu/pipermail/flash-users/2014-November/001570.html

# %% [raw]
# Bad syntax: file Simulation/SimulationMain/FosterChevalier/Config, line 57:
# PARTICLEPROP dens
#
# input doesn't match regular expression "PARTICLEPROP\s+(?P<name>\w+)\s+(?P<type>INTEGER|REAL)\s*$"

# %% [markdown]
#  [ 03-28-2016  08:32:05.957 ] [SinkParticles]: localnpf now: 0

# %% [markdown]
# I think maybe there just hasn't been any sink particles outputted yet .'

# %% [markdown]
# I lowered the sink density criterion to 5e-18 but still don't get anything.
#
#  [ 03-28-2016  08:40:43.184 ] [SinkParticles]: localnpf now: 0

# %%
# slc.annotate_particles((0.01, 'pc'))

# %%
def plot_dens(i):
    ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
    physical_quantity="density"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_figure_size(5)
    slc.annotate_grids()
    slc.annotate_velocity()
    slc.annotate_particles()
    slc.set_cmap("all","rainbow")
    slc.show()

# %%
plot_dens(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a8a6fd5000a6> in <module>()
# ----> 1 plot_dens(1)
#
# NameError: name 'plot_dens' is not defined
