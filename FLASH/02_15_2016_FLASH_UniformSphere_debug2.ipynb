# %% [raw]
# Now fixing the error:
#
#     Too many blocks!  Increase MAXBLOCKS or use more processors.

# %% [raw]
# --maxblock =
# specify maximum number of blocks per process

# %% [raw]
# This option is also used by setup in constructing the makefile compiler options. It determines the amount of memory allocated at runtime to the adaptive mesh refinement (AMR) block data structure. For example, to allocate enough memory on each processor for 500 blocks, use -maxblocks=500. If the default block buffer size is too large for your system, you may wish to try a smaller number here; the default value depends upon the dimensionality of the simulation and the grid type. Alternatively, you may wish to experiment with larger buffer sizes, if your system has enough memory. A common cause of aborted simulations occurs when the AMR grid creates greater than maxblocks during refinement. Resetup the simulation using a larger value of this option.

# %% [raw]
# Okay trying
#
# ./setup UniformSphere -3d --maxblock=500 -auto
#
# to begin with

# %% [raw]
# Still not enough:
#     trying:
#         ./setup UniformSphere -3d --maxblock=1000 -auto

# %% [raw]
# Still not enough:
#     trying:
#         ./setup UniformSphere -3d --maxblock=3000 -auto

# %% [markdown]
# Woah this is good now and its running !

# %% [raw]
#       28 5.3687E-02 2.6844E-02  ( 4.980E-01,  4.980E-01,  7.480E-01) |  2.208E-01^M
#  *** Wrote checkpoint file to uniform_sphere_hdf5_chk_0003 ****^M
#  exiting: reached max SimTime^M
#  *** Wrote plotfile to uniform_sphere_forced_hdf5_plt_cnt_0000 ****^M

# %% [markdown]
# Ran sucesfully, lets check what it looks like :

# %%
import yt
yt.mylog.setLevel(50)
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ~/project/FLASH4.3/object/
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3/object

# %%
for i in np.arange(0,4):
    ds = yt.load("uniform_sphere_hdf5_chk_000{}".format(i))
    physical_quantity="density"
    slc = yt.SlicePlot(ds, "z",physical_quantity)
    slc.annotate_velocity()
    slc.annotate_grids()
    slc.show()
# Out:
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:645: RuntimeWarning: divide by zero encountered in double_scalars
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:645: RuntimeWarning: invalid value encountered in multiply
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:701: RuntimeWarning: invalid value encountered in less
#   short = np.repeat(length < minsh, 8, axis=1)
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:711: RuntimeWarning: invalid value encountered in less
#   tooshort = length < self.minlength
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# ...

# %%
i=0
ds = yt.load("uniform_sphere_hdf5_chk_000{}".format(i))
physical_quantity="temperature"
slc = yt.SlicePlot(ds, "z",physical_quantity)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# This is weird the pressure is not uniform even in IC

# %%
i=0
ds = yt.load("uniform_sphere_hdf5_chk_000{}".format(i))
# physical_quantity="pres"
physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# This is so weird this is definitely initialised correctly:
#
#           solnData(PRES_VAR,i,j,k) = P
#            solnData(TEMP_VAR,i,j,k) = solnData(PRES_VAR,i,j,k) /(solnData(DENS_VAR,i,j,k)*sim_gascon)
# But for some reason it feels like it is switch around.
#
# Also what's the code units ?? '

# %% [markdown]
# Okay the time I was setting was a bit too little, also I should start AMR (but not too sure how to count the levels because yt's grid is not actual grid)

# %%
ls uniform_sphere_hdf5_chk_0*
# Out:
# uniform_sphere_hdf5_chk_0000  uniform_sphere_hdf5_chk_0004
# uniform_sphere_hdf5_chk_0001  uniform_sphere_hdf5_chk_0005
# uniform_sphere_hdf5_chk_0002  uniform_sphere_hdf5_chk_0006
# uniform_sphere_hdf5_chk_0003

# %%
for i in np.arange(0,7):
    ds = yt.load("uniform_sphere_hdf5_chk_000{}".format(i))
    physical_quantity="density"
    slc = yt.SlicePlot(ds, "z",physical_quantity)
    slc.annotate_velocity()
    slc.annotate_grids()
    slc.show()
# Out:
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:645: RuntimeWarning: divide by zero encountered in double_scalars
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:645: RuntimeWarning: invalid value encountered in multiply
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:701: RuntimeWarning: invalid value encountered in less
#   short = np.repeat(length < minsh, 8, axis=1)
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:711: RuntimeWarning: invalid value encountered in less
#   tooshort = length < self.minlength
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# ...

# %%
import yt
yt.mylog.setLevel(50)
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ~/project/FLASH4.3/object/
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3/object

# %%
ls uniform_sphere_hdf5_chk_0*
# Out:
# uniform_sphere_hdf5_chk_0000  uniform_sphere_hdf5_chk_0004
# uniform_sphere_hdf5_chk_0001  uniform_sphere_hdf5_chk_0005
# uniform_sphere_hdf5_chk_0002  uniform_sphere_hdf5_chk_0006
# uniform_sphere_hdf5_chk_0003

# %%
for i in np.arange(0,7):
    ds = yt.load("uniform_sphere_hdf5_chk_000{}".format(i))
    physical_quantity="density"
    slc = yt.SlicePlot(ds, "z",physical_quantity)
    slc.annotate_velocity()
    slc.annotate_grids()
    slc.show()
