# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ~/project/FLASH4.3_2/object/
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3_2/object

# %%
import glob
glob.glob("fat*")
# Out:
# ['fat100', 'fat10', 'fat3', 'fat1000']

# %%
3.16 ---> 30~40 
10 ---> >~30 
31.6 ---> 20~40 
100 --->

# %%
fattening_factor= [1000,100,31.6, 10,3.16]
# Time until collapse till point-ish
time = [4.149995E+11, 1.8727E+12,4.5127E+12,1.7015E+13,2.6706E+13]
# Order of magnitude computational time in seconds
comp_time = [120,3600,5400,28800,25200]

# %%
plt.loglog(fattening_factor,time)
plt.loglog(fattening_factor,time,'o',color = "red")
plt.xlabel("Fattening Factor ",fontsize=14)
plt.ylabel("Time",fontsize=14)

# %%
plt.semilogx(fattening_factor,time)
plt.xlabel("Fattening Factor ",fontsize=14)
plt.ylabel("Time",fontsize=14)

# %%
plt.loglog(fattening_factor,comp_time)
plt.xlabel("Fattening Factor ",fontsize=14)
plt.ylabel("Computational Time",fontsize=14)
