# %%
import yt
yt.mylog.setLevel(50)
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ~/project/FLASH4.3/object/
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3/object

# %% [markdown]
# Pressure/temp still not fixed but trying to fix the box length now

# %% [markdown]
# I think rcloud is actually extending out of 0.25.
#
# Tried changing the value of rcloud to 0.4 just to see if the rcloud is actually in effect accurately
#
# also testing whether it is okay to just run the par files

# %% [markdown]
# - try printing the value of P and found that the P value is correct

# %%
P:    59.6525000000000
 P:    59.6525000000000
 P:    59.6525000000000
 P:    59.6525000000000
 P:    59.6525000000000
 P:    59.6525000000000

# %%
i = 2
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# Okay either I actually need to recompile for this to work, or cloud is total BS to start with

# %%
i = 0
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [raw]
# Okay this is good, this confirmed two things:
#     1) rcloud is actually computing the right physical values for the size of the cloud
#     2) need to recompile even if you only changed the flash.par file

# %%
i = 0
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# This confirms that the center is shifted so we are now making slice through 0.5 and we see the sphere, so actually we need to set the center in the par file as 1 so that its the real center

# %% [markdown]
# Okay giving one last try for the par file thing

# %%
i = 0
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
i = 2
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
i = 6
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# This is when I had sim_xctr,y z as 0.5 which doesnt make a whole lot of sense

# %% [markdown]
# Now I changed the sim_xctr ..etc to 1,1,1

# %%
i = 0
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity,center=(0.9,0.9,0.9))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# okay this is weird this is only a quarter of a sphere

# %%
i = 0
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"

# %%
slc = yt.SlicePlot(ds, "z",physical_quantity,center=(0.9,0.9,0.9))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
i = 1
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
i = 2
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
i = 5
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [raw]
# 25G	./object/uniform_sphere_unigrid
# 21G	./object/uniform_sphere2
# 46G	./object
# 50G	.

# %% [markdown]
# wow these are huge files

# %% [markdown]
# trying projection plot of volume rendering 3d might be better

# %%
Printing out the coordinates again to see if they make sense :

# %%
i = 0
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
i = 0
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.ProjectionPlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
i = 0
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.ProjectionPlot(ds, "z",physical_quantity,center=(1,1,1))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# Now (0,0,0)

# %%
i = 0
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.ProjectionPlot(ds, "z",physical_quantity)
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
i = 3
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# oh yeah need to compile

# %%
i = 0
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
i = 1
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
i = 2
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
physical_quantity="temperature"
slc = yt.SlicePlot(ds, "z",physical_quantity)
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()

physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [raw]
# This thing just crashes after 3 times steps not sure why
#
#  Terminating execution.
#
#  Driver_abort called. See log file for details.
#  Error message is Nonconvergence in subroutine rieman
#  Calling MPI_Abort() for shutdown in   2 seconds!
#
#
#  Nonconvergence in subroutine rieman
#
#  Zone index       =            6
#  Zone center      =   1.171875000000000E-002
#  Iterations tried =           12
#  Pressure error   =   4.504544764789028E-005
#  rieman_tol       =   1.000000000000000E-005

# %% [markdown]
# something about the rieman solver just barfed I guess

# %% [markdown]
# Okay back to fixing the pressure because that might be the reason why the rieman solver is unhappy
