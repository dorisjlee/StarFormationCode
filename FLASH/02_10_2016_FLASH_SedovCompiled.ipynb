# %%
import yt
yt.mylog.setLevel(50)

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ~/project/FLASH4.3/object/
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3/object

# %%
for i in np.arange(0,6):
    ds = yt.load("sedov_hdf5_chk_000{}".format(i))
    physical_quantity="density"
    slc = yt.SlicePlot(ds, "z",physical_quantity)
    slc.annotate_velocity()
    slc.annotate_grids()
    slc.show()
# Out:
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:645: RuntimeWarning: divide by zero encountered in double_scalars
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:645: RuntimeWarning: invalid value encountered in multiply
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:701: RuntimeWarning: invalid value encountered in less
#   short = np.repeat(length < minsh, 8, axis=1)
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:711: RuntimeWarning: invalid value encountered in less
#   tooshort = length < self.minlength
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# ...

# %% [raw]
# cp -r DustCollapse/ UniformSphere

# %% [markdown]
# Okay I tried running this using qsub so its in the quue now , we'll see what it looks like then modify the code later '

# %%
-with-unit=Gravity/GravityMain/Poisson

# %% [raw]
#  flash:  initializing for dust collapse problem.
#
#   iteration, no. not moved =            0           0
#  refined: total leaf blocks =            1
#  refined: total blocks =            1
#  INFO: Grid_fillGuardCells is ignoring masking.
#   iteration, no. not moved =            0           0
#  refined: total leaf blocks =            4
#  refined: total blocks =            5
#   iteration, no. not moved =            0           4
#   iteration, no. not moved =            1           1
#   iteration, no. not moved =            2           0
#  refined: total leaf blocks =           16
#  refined: total blocks =           21
#  DRIVER_ABORT: [gr_mpoleInit] ERROR: unsupported geometry
#  DRIVER_ABORT: [gr_mpoleInit] ERROR: unsupported geometry
#  DRIVER_ABORT: [gr_mpoleInit] ERROR: unsupported geometry
#  DRIVER_ABORT: [gr_mpoleInit] ERROR: unsupported geometry
#  DRIVER_ABORT: [gr_mpoleInit] ERROR: unsupported geometry
#  DRIVER_ABORT: [gr_mpoleInit] ERROR: unsupported geometry
#  DRIVER_ABORT: [gr_mpoleInit] ERROR: unsupported geometry
#  DRIVER_ABORT: [gr_mpoleInit] ERROR: unsupported geometry
#  DRIVER_ABORT: [gr_mpoleInit] ERROR: unsupported geometry
#  DRIVER_ABORT: [gr_mpoleInit] ERROR: unsupported geometry
#  DRIVER_ABORT: [gr_mpoleInit] ERROR: unsupported geometry
#  DRIVER_ABORT: [gr_mpoleInit] ERROR: unsupported geometry
#  DRIVER_ABORT: [gr_mpoleInit] ERROR: unsupported geometry
#  DRIVER_ABORT: [gr_mpoleInit] ERROR: unsupported geometry
#  DRIVER_ABORT: [gr_mpoleInit] ERROR: unsupported geometry
#
#  Driver_abort called. See log file for details.
#  Error message is [gr_mpoleInit] ERROR: unsupported geometry
#  Calling MPI_Abort() for shutdown in   2 seconds!

# %% [markdown]
# Okay so this stuff is complicated maybe I'll use the Sedov one as base template first then .. since that's what I understand for now
