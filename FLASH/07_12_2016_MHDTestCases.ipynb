# %%
# %pylab inline
from matplotlib.colors import LogNorm
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # MHD_Torus

# %%
from yt.visualization.fixed_resolution import FixedResolutionBuffer

# %%
i=1
ds = yt.load("torus_mhd_2d_hdf5_chk_{}".format(str(i).zfill(4)))
xdir=0
ydir=1
slicedirection=2
sl = ds.slice(slicedirection,0) ##Get the Slice
w = [ds.domain_left_edge[xdir],ds.domain_right_edge[xdir],ds.domain_left_edge[ydir],ds.domain_right_edge[ydir]] 
frb1 = FixedResolutionBuffer(sl,w,(128,128))  #Create FixedResolution Buffer

plt.figure()
plt.imshow(np.array(frb1["density"]))
plt.colorbar()
plt.figure()
plt.imshow(np.array(frb1["magnetic_field_strength"]))
plt.colorbar()

# %%
def plot_stuff(i):
    ds = yt.load("torus_mhd_2d_hdf5_chk_{}".format(str(i).zfill(4)))
    xdir=0
    ydir=1
    slicedirection=2
    sl = ds.slice(slicedirection,0) ##Get the Slice
    w = [ds.domain_left_edge[xdir],ds.domain_right_edge[xdir],ds.domain_left_edge[ydir],ds.domain_right_edge[ydir]] 
    frb1 = FixedResolutionBuffer(sl,w,(128,128))  #Create FixedResolution Buffer

    plt.figure()
    plt.imshow(np.array(frb1["density"]))
    plt.colorbar()
    plt.figure()
    plt.imshow(np.array(frb1["magnetic_field_strength"]))
    plt.colorbar()

# %%
plot_stuff(0)

# %%
plot_stuff(7)

# %% [markdown]
# # Orzag Tang

# %%
from IPython.display import Image
from IPython.display import display
init = Image(filename='orszag_mhd_2d_hdf5_chk_0000_density.png',width=400) 
x = Image(filename='orszag_mhd_2d_hdf5_chk_0001_density.png',width=400) 
y = Image(filename="orszag_mhd_2d_hdf5_chk_0002_density.png",width=400) 
z = Image(filename="orszag_mhd_2d_hdf5_chk_0003_density.png",width=400) 
a = Image(filename="orszag_mhd_2d_hdf5_chk_0004_density.png",width=400) 
b = Image(filename="orszag_mhd_2d_hdf5_chk_0005_density.png",width=400) 
display(init,x, y,z,a,b)

# %%
from IPython.display import Image
from IPython.display import display
init = Image(filename='orszag_mhd_2d_hdf5_chk_0000_Bstrength.png',width=400) 
x = Image(filename='orszag_mhd_2d_hdf5_chk_0001_Bstrength.png',width=400) 
y = Image(filename="orszag_mhd_2d_hdf5_chk_0002_Bstrength.png",width=400) 
z = Image(filename="orszag_mhd_2d_hdf5_chk_0003_Bstrength.png",width=400) 
a = Image(filename="orszag_mhd_2d_hdf5_chk_0004_Bstrength.png",width=400) 
b = Image(filename="orszag_mhd_2d_hdf5_chk_0005_Bstrength.png",width=400) 
display(init,x, y,z,a,b)
