# %%
import yt
yt.mylog.setLevel(50)
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ~/project/FLASH4.3/object/
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3/object

# %%
i = 1
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()

# %% [markdown]
# - can we just examine the plot files without yt?
# - What happens if we dont define the energy and just let it be ?
#     - energy is missing a rho factors? (no according to Table 14.2 the energy that we are recording is energy per mass)

# %% [markdown]
# I thought maybe this has to do with the parameter EXTERIOR and INTEROIR but that's just a matter of where you start counting whether inclucde the ghost cell or not '
#
# http://flash.uchicago.edu/site/flashcode/user_support/robodoc-FLASH4/home.py?submit=docs/source/Grid/Grid_putPointData_F90.html

# %% [markdown]
# There should be more plot files that's getting spat out than the interval checkpoint files (since these are heavier with grid info and more stuff )'

# %% [markdown]
# I took out some stuff that setted temperatrure constant for if there is two materials, I dont think this is activated but I took it out just in case

# %%
i = 0
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
# Out:
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:645: RuntimeWarning: divide by zero encountered in double_scalars
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:645: RuntimeWarning: invalid value encountered in multiply
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:701: RuntimeWarning: invalid value encountered in less
#   short = np.repeat(length < minsh, 8, axis=1)
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:711: RuntimeWarning: invalid value encountered in less
#   tooshort = length < self.minlength
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
i = 0
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
i = 0
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="temperature"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# Maybe the reimann solver is crashing because the pressue is too high (I tried testing it to set as 1e5, but that clearly did not translate over to what yt is seeing)?

# %% [markdown]
# - Try not setting energy all together ??
# - try plotting the first with another software?

# %%
i = 0
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
i = 0
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="temperature"
slc = yt.ProjectionPlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# Okay not even a projection plot would help , this box is completely isothermal !

# %% [markdown]
# Maybe it has to do with the factor that we are using the wrong EoS??

# %% [markdown]
# Another thing if I'm really stuck is to move onto seeing whether sink particles work or not'

# %% [markdown]
# This seems like it might be relevant
# http://flash.uchicago.edu/pipermail/flash-users/2014-April/001430.html
