# %%
# %pylab inline
from matplotlib.colors import LogNorm
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
G = 6.67e-8 #cgs
c_s = 28730.5 #cm/s

# %%
cd ~/project/FLASH4.3_2/object/fat100/
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3_2/object/fat100

# %%
xi_range = np.logspace(-1.5,1.5,num=30)
tlst = [0,28,30,32,40]
hsv = plt.get_cmap('rainbow_r')
colors = hsv(np.linspace(0, 1.0, len(tlst)))
for s , c in zip(tlst,colors):
    data = np.loadtxt("new_fast_sum_args_list{}_lev5.txt".format(s))
    plt.loglog(xi_range[::-1],4*np.pi*G*data/c_s,label= "t={}".format(s), color=c)
# plt.xlim(0.1,2)
# plt.ylim(1e9,1e10)
plt.legend(loc ="center left", bbox_to_anchor=(1, 0.5))
min_cell_size =  1e19/2**(7)*1.057E-17
plt.axvline(min_cell_size,c="blue")
plt.axvline(1e19*1.057E-17,c="blue")
plt.legend(loc ="center left", bbox_to_anchor=(1, 0.5))
plt.xlabel(r"$\xi$",fontsize=16)
plt.ylabel(r"m/$\xi$",fontsize=16)

# %%
39062500000000000
3906250000000000
# Out:
# False

# %%
xi_range = np.logspace(-1.5,1.5,num=30)
tlst = [0,28,30,32,40]
hsv = plt.get_cmap('rainbow_r')
colors = hsv(np.linspace(0, 1.0, len(tlst)))
for s , c in zip(tlst,colors):
    data = np.loadtxt("new_fast_sum_args_list{}_lev5.txt".format(s))
    plt.loglog(xi_range[::-1],4*np.pi*G*data/c_s,label= "t={}".format(s), color=c)
# plt.xlim(0.1,2)
# plt.ylim(1e9,1e10)
plt.legend(loc ="center left", bbox_to_anchor=(1, 0.5))
min_cell_size =  1e19/2**(7)*1.057E-17
plt.axvline(min_cell_size,c="blue")
plt.axvline(1e19*1.057E-17,c="blue")
plt.legend(loc ="center left", bbox_to_anchor=(1, 0.5))
plt.xlabel(r"$\xi$",fontsize=16)
plt.ylabel(r"m/$\xi$",fontsize=16)

# %%
cd ~/project/FLASH4.3_3/lev8nosink/
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3_3/lev8nosink

# %%
xi_range = np.logspace(-1.5,1.5,num=30)
tlst = [0,28,30,32,40]
hsv = plt.get_cmap('rainbow_r')
colors = hsv(np.linspace(0, 1.0, len(tlst)))
for s , c in zip(tlst,colors):
    data = np.loadtxt("new_fast_sum_args_list{}_lev7.txt".format(s))
    plt.loglog(xi_range[::-1],4*np.pi*G*data/c_s,label= "t={}".format(s), color=c)
    
min_cell_size =  1e19/2**(9)*1.057E-17
plt.axvline(min_cell_size,c="red")
plt.axvline(4e18*1.057E-17,c="red")
plt.legend(loc ="center left", bbox_to_anchor=(1, 0.5))
plt.xlabel(r"log $\xi$",fontsize=16)
plt.ylabel(r"log m/$\xi$",fontsize=16)
plt.title("Hi-res no sink",fontsize=16)

plt.xlim(0.05,100)
# Out:
# (0.05, 100)

# %%
cd ~/project/FLASH4.3_3/lev8sink/
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3_3/lev8sink

# %%
xi_range = np.logspace(-1.5,1.5,num=30)
tlst = [0,28,30,32,40]
hsv = plt.get_cmap('rainbow_r')
colors = hsv(np.linspace(0, 1.0, len(tlst)))
for s , c in zip(tlst,colors):
    data = np.loadtxt("new_fast_sum_args_list{}_lev7.txt".format(s))
    plt.loglog(xi_range[::-1],4*np.pi*G*data/c_s,label= "t={}".format(s), color=c)
    
min_cell_size =  1e19/2**(9)*1.057E-17
plt.axvline(min_cell_size,c="red")
plt.axvline(4e18*1.057E-17,c="red")
plt.legend(loc ="center left", bbox_to_anchor=(1, 0.5))
plt.xlabel(r"log $\xi$",fontsize=16)
plt.ylabel(r"log m/$\xi$",fontsize=16)
plt.title("Hi-res no sink",fontsize=16)

plt.xlim(0.05,100)
# Out:
# (0.05, 100)

# %% [markdown]
# # ----------------------------------------------

# %% [markdown]
# # Red = No Sink
# # Blue = Sink
# - both level 6~8, AMR refinement based on Jean's criterion
# - plotted in cyan is the accretion radius of the sink
# - plotted in magenta is the minimum cell size and the max box size (beyond these values might be bogus)

# %%
import mpld3

# %%
mpld3.disable_notebook()

# %%
xi_range = np.logspace(-1.5,1.5,num=30)
tlst = [0,28,30,32,40]
hsv = plt.get_cmap('Blues')
colors = hsv(np.linspace(0.5, 1.0, len(tlst)))
for s , c in zip(tlst,colors):
#     c="red"
    data = np.loadtxt("new_fast_sum_args_list{}_lev7.txt".format(s))
    plt.loglog(xi_range[::-1],4*np.pi*G*data/c_s,"x",label= "t={}".format(s), color=c)
    
min_cell_size =  1e19/2**(9)*1.057E-17
# plt.axvline(min_cell_size,c="magenta")
# plt.axvline(4e18*1.057E-17,c="magenta")
# plt.axvline(6.103515625e+15*1.057E-17,c="cyan")

xi_range = np.logspace(-1.5,1.5,num=30)
tlst = [0,28,30,32,40]
hsv = plt.get_cmap('Reds')
colors = hsv(np.linspace(0.6,0.8, len(tlst)))
for s , c in zip(tlst,colors):
#     c="blue"
    data = np.loadtxt("../lev8sink/new_fast_sum_args_list{}_lev7.txt".format(s))
    plt.loglog(xi_range[::-1],4*np.pi*G*data/c_s,label= "t*={}".format(s), color=c)

plt.legend(loc ="center left", bbox_to_anchor=(1, 0.5))
plt.xlabel(r"$\xi$",fontsize=16)
plt.ylabel(r"m/$\xi$",fontsize=16)

# %% [markdown]
# ### The last plot is Interactive for zooming in to see the differences + when inflection happens
# - click on the cross hair on bottom left

# %%
mpld3.enable_notebook()

# %%
xi_range = np.logspace(-1.5,1.5,num=30)
tlst = [0,28,30,32,40]
hsv = plt.get_cmap('Blues')
colors = hsv(np.linspace(0.5, 1.0, len(tlst)))
for s , c in zip(tlst,colors):
#     c="red"
    data = np.loadtxt("new_fast_sum_args_list{}_lev7.txt".format(s))
    plt.loglog(xi_range[::-1],4*np.pi*G*data/c_s,"x",label= "t={}".format(s), color=c)
    
min_cell_size =  1e19/2**(9)*1.057E-17
plt.axvline(min_cell_size,c="magenta")
plt.axvline(4e18*1.057E-17,c="magenta")
plt.axvline(6.103515625e+15*1.057E-17,c="cyan")

xi_range = np.logspace(-1.5,1.5,num=30)
tlst = [0,28,30,32,40]
hsv = plt.get_cmap('Reds')
colors = hsv(np.linspace(0.6,0.8, len(tlst)))
for s , c in zip(tlst,colors):
#     c="blue"
    data = np.loadtxt("../lev8sink/new_fast_sum_args_list{}_lev7.txt".format(s))
    plt.loglog(xi_range[::-1],4*np.pi*G*data/c_s,label= "t*={}".format(s), color=c)

plt.legend(loc ="center left", bbox_to_anchor=(1, 0.5))
plt.xlabel(r"$\xi$",fontsize=16)
plt.ylabel(r"m/$\xi$",fontsize=16)
# Out:
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/mpld3/mplexporter/exporter.py:82: UserWarning: Blended transforms not yet supported. Zoom behavior may not work as expected.
#   warnings.warn("Blended transforms not yet supported. "

# %% [markdown]
# At large radii, the results converge. At small radii, things differ, even before sink comes in at t = 34.
# No sink case crashes at t = 43. Sink case crashes at t = 50 .

# %% [markdown]
# # Now compare this with our low-res, no sink run, converge at low radii
#
# # Red = No Sink, high res
# # Blue = No Sink, low res, larger box

# %%
mpld3.disable_notebook()

# %%
xi_range = np.logspace(-1.5,1.5,num=30)
tlst = [0,28,30,32,40]
hsv = plt.get_cmap('Reds')
colors = hsv(np.linspace(0, 1.0, len(tlst)))
for s , c in zip(tlst,colors):
    data = np.loadtxt("new_fast_sum_args_list{}_lev7.txt".format(s))
    plt.loglog(xi_range[::-1],4*np.pi*G*data/c_s,label= "t={}".format(s), color=c)
    
min_cell_size =  1e19/2**(9)*1.057E-17
plt.axvline(min_cell_size,c="red")
plt.axvline(4e18*1.057E-17,c="red")

plt.xlabel(r"log $\xi$",fontsize=16)
plt.ylabel(r"log m/$\xi$",fontsize=16)
plt.title("Hi-res no sink",fontsize=16)

# plt.xlim(0.05,100)

xi_range = np.logspace(-1.5,1.5,num=30)
tlst = [0,28,30,32,40]
hsv = plt.get_cmap('Blues')
colors = hsv(np.linspace(0.5, 1.0, len(tlst)))
for s , c in zip(tlst,colors):
    data = np.loadtxt("../../FLASH4.3_2/object/fat100/new_fast_sum_args_list{}_lev5.txt".format(s))
    plt.loglog(xi_range[::-1],4*np.pi*G*data/c_s,label= "t={}".format(s), color=c)
min_cell_size =  1e19/2**(7)*1.057E-17
plt.axvline(min_cell_size,c="blue")
plt.axvline(1e19*1.057E-17,c="blue")
plt.legend(loc ="center left", bbox_to_anchor=(1, 0.5))
plt.xlabel(r"$\xi$",fontsize=16)
plt.ylabel(r"m/$\xi$",fontsize=16)
# plt.title("New code, better ranges (No Sink)",fontsize=16)

# %% [markdown]
# ## Interactive version

# %%
mpld3.enable_notebook()

# %%
xi_range = np.logspace(-1.5,1.5,num=30)
tlst = [0,28,30,32,40]
hsv = plt.get_cmap('Reds')
colors = hsv(np.linspace(0.3, 1.0, len(tlst)))
for s , c in zip(tlst,colors):
    data = np.loadtxt("new_fast_sum_args_list{}_lev7.txt".format(s))
    plt.loglog(xi_range[::-1],4*np.pi*G*data/c_s,label= "t={}".format(s), color=c)
    
min_cell_size =  1e19/2**(9)*1.057E-17
# plt.axvline(min_cell_size,c="red")
# plt.axvline(4e18*1.057E-17,c="red")

plt.xlabel(r"log $\xi$",fontsize=16)
plt.ylabel(r"log m/$\xi$",fontsize=16)
plt.title("Hi-res no sink",fontsize=16)

# plt.xlim(0.05,100)

xi_range = np.logspace(-1.5,1.5,num=30)
tlst = [0,28,30,32,40]
hsv = plt.get_cmap('Blues')
colors = hsv(np.linspace(0.5, 1.0, len(tlst)))
for s , c in zip(tlst,colors):
    data = np.loadtxt("../../FLASH4.3_2/object/fat100/new_fast_sum_args_list{}_lev5.txt".format(s))
    plt.loglog(xi_range[::-1],4*np.pi*G*data/c_s,label= "t={}".format(s), color=c)
min_cell_size =  1e19/2**(7)*1.057E-17
# plt.axvline(min_cell_size,c="blue")
# plt.axvline(1e19*1.057E-17,c="blue")
plt.legend(loc ="center left", bbox_to_anchor=(1, 0.5))
plt.xlabel(r"$\xi$",fontsize=16)
plt.ylabel(r"m/$\xi$",fontsize=16)
# plt.title("New code, better ranges (No Sink)",fontsize=16)

# %%
mpld3.disable_notebook()

# %%
cd ../lev8nosink/
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3_3/lev8nosink

# %%
xi_range = np.logspace(-1.5,1.5,num=30)
tlst = [0,28,30,32,40]
hsv = plt.get_cmap('Reds')
colors = hsv(np.linspace(0.3, 1.0, len(tlst)))
for s , c in zip(tlst,colors):
    data = np.loadtxt("new_fast_sum_args_list{}_lev7.txt".format(s))
    plt.loglog(xi_range[::-1],4*np.pi*G*data/c_s,label= "t={}".format(s), color=c)
    
min_cell_size =  1e19/2**(9)*1.057E-17
# plt.axvline(min_cell_size,c="red")
# plt.axvline(4e18*1.057E-17,c="red")

plt.xlabel(r"log $\xi$",fontsize=16)
plt.ylabel(r"log m/$\xi$",fontsize=16)
plt.title("Hi-res no sink",fontsize=16)

# plt.xlim(0.05,100)

xi_range = np.logspace(-1.5,1.5,num=30)
tlst = [0,28,30,32,40]
hsv = plt.get_cmap('Blues')
colors = hsv(np.linspace(0.5, 1.0, len(tlst)))
for s , c in zip(tlst,colors):
    data = np.loadtxt("../../FLASH4.3_2/object/fat100/new_fast_sum_args_list{}_lev5.txt".format(s))
    plt.loglog(xi_range[::-1],4*np.pi*G*data/c_s,label= "t={}".format(s), color=c)
min_cell_size =  1e19/2**(7)*1.057E-17
# plt.axvline(min_cell_size,c="blue")
# plt.axvline(1e19*1.057E-17,c="blue")
plt.legend(loc ="center left", bbox_to_anchor=(1, 0.5))
plt.xlabel(r"$\xi$",fontsize=16)
plt.ylabel(r"m/$\xi$",fontsize=16)
# plt.title("New code, better ranges (No Sink)",fontsize=16)
