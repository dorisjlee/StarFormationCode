# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['plot']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
G = 6.67e-8 #cgs
a = 28730.5 #cm/s

# %% [markdown]
# # Fatten = 1000

# %%
tlst = [0,10,20,22,24,26,30,31]
hsv = plt.get_cmap('rainbow')
colors = hsv(np.linspace(0, 1.0, len(tlst)))
for s , c in zip(tlst,colors):
    data = np.loadtxt("../../project/FLASH4.3_2/object/fat1000/sum_args_list{}.txt".format(s))
    plt.loglog(xi_range,4*np.pi*G*data/a,label= "t={}".format(s), color=c)
plt.legend()
plt.xlabel(r"log $\xi$",fontsize=16)
plt.ylabel(r"log m/$\xi$",fontsize=16)
plt.title("Fattening 1000 Ricker Sphere",fontsize=16)

# %% [markdown]
# # Fatten =  100

# %% [markdown]
# chk file up to 40

# %%
ls ../../project/FLASH4.3_2/object/fat100/sum_args_list*
# Out:
# ../../project/FLASH4.3_2/object/fat100/sum_args_list0.txt
# ../../project/FLASH4.3_2/object/fat100/sum_args_list10.txt
# ../../project/FLASH4.3_2/object/fat100/sum_args_list20.txt
# ../../project/FLASH4.3_2/object/fat100/sum_args_list22.txt
# ../../project/FLASH4.3_2/object/fat100/sum_args_list24.txt
# ../../project/FLASH4.3_2/object/fat100/sum_args_list25.txt
# ../../project/FLASH4.3_2/object/fat100/sum_args_list26.txt
# ../../project/FLASH4.3_2/object/fat100/sum_args_list30.txt
# ../../project/FLASH4.3_2/object/fat100/sum_args_list34.txt
# ../../project/FLASH4.3_2/object/fat100/sum_args_list36.txt
# ../../project/FLASH4.3_2/object/fat100/sum_args_list38.txt
# ../../project/FLASH4.3_2/object/fat100/sum_args_list39.txt
# ../../project/FLASH4.3_2/object/fat100/sum_args_list40.txt

# %%
# xi_range = np.logspace(-0.5,np.log10(17),num=20)
# tlst = [0,10,20,22,24,25,26,30,34,36,38,39,40]
# hsv = plt.get_cmap('plasma')
# colors = hsv(np.linspace(0, 1.0, len(tlst)))
# for s , c in zip(tlst,colors):
#     data = np.loadtxt("../../project/FLASH4.3_2/object/fat100/sum_args_list{}.txt".format(s))
#     plt.loglog(xi_range,4*np.pi*G*data/a,label= "t={}".format(s), color=c)
# plt.legend(loc ="lower right")
# plt.xlabel(r"log $\xi$",fontsize=16)
# plt.ylabel(r"log m/$\xi$",fontsize=16)
# plt.title("Fattening 100 Ricker Sphere",fontsize=16)

# %% [markdown]
# # Fatten =31.6

# %% [markdown]
# chk file up to 247, but things go awry on or before 120

# %%
ls ../../project/FLASH4.3_3/object/fat31/sum_args_list*
# Out:
# ../../project/FLASH4.3_3/object/fat31/sum_args_list0_2.txt
# ../../project/FLASH4.3_3/object/fat31/sum_args_list100_2.txt
# ../../project/FLASH4.3_3/object/fat31/sum_args_list110_2.txt
# ../../project/FLASH4.3_3/object/fat31/sum_args_list20_2.txt
# ../../project/FLASH4.3_3/object/fat31/sum_args_list40_2.txt
# ../../project/FLASH4.3_3/object/fat31/sum_args_list60_2.txt
# ../../project/FLASH4.3_3/object/fat31/sum_args_list80_2.txt
# ../../project/FLASH4.3_3/object/fat31/sum_args_list84_2.txt
# ../../project/FLASH4.3_3/object/fat31/sum_args_list86_2.txt
# ../../project/FLASH4.3_3/object/fat31/sum_args_list88_2.txt
# ../../project/FLASH4.3_3/object/fat31/sum_args_list90_2.txt

# %%
xi_range = np.logspace(-np.log10(0.5),np.log10(18),num=20)
tlst = [  0, 40,  60,  80,84,86,88, 90]
hsv = plt.get_cmap('jet')
colors = hsv(np.linspace(0, 1.0, len(tlst)))
for s , c in zip(tlst,colors):
    data = np.loadtxt("../../project/FLASH4.3_3/object/fat31/sum_args_list{}_2.txt".format(s))
    plt.loglog(xi_range,4*np.pi*G*data/a,label= "t={}".format(s), color=c)
plt.legend(loc ="lower right")
plt.xlabel(r"log $\xi$",fontsize=16)
plt.ylabel(r"log m/$\xi$",fontsize=16)
plt.title("Fattening 31.6 Ricker Sphere",fontsize=16)

# %%
import plot

# %%
cd ../../project/FLASH4.3_3/object/fat31/
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3_3/object/fat31

# %%
plot.plot_dens(78)
plot.plot_dens(80)
plot.plot_dens(85)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# # Fatten =10

# %% [markdown]
# chk file up to 104

# %%
ls ../../project/FLASH4.3_2/object/fat10/sum_args_list*
# Out:
# ../../project/FLASH4.3_2/object/fat10/sum_args_list0.txt
# ../../project/FLASH4.3_2/object/fat10/sum_args_list100.txt
# ../../project/FLASH4.3_2/object/fat10/sum_args_list20.txt
# ../../project/FLASH4.3_2/object/fat10/sum_args_list40.txt
# ../../project/FLASH4.3_2/object/fat10/sum_args_list60.txt
# ../../project/FLASH4.3_2/object/fat10/sum_args_list80.txt

# %%
xi_range = np.logspace(-np.log10(0.5),np.log10(40),num=40)
tlst = [  0,  20]#,  40,  60,  80, 90,100,110]
hsv = plt.get_cmap('prism')
colors = hsv(np.linspace(0, 1.0, len(tlst)))
for s , c in zip(tlst,colors):
    data = np.loadtxt("../../project/FLASH4.3_2/object/fat10/sum_args_list{}.txt".format(s))
    plt.loglog(xi_range,4*np.pi*G*data/a,label= "t={}".format(s), color=c,marker = 'o')
plt.legend(loc ="lower right")
plt.xlabel(r"log $\xi$",fontsize=16)
plt.ylabel(r"log m/$\xi$",fontsize=16)
plt.title("Fattening 10 Ricker Sphere",fontsize=16)

# %% [markdown]
# # Fatten  = 3

# %% [markdown]
# chk file up to 95

# %%
tlst = [  0,  20, 30,35, 40, 95]
xi_range = np.logspace(np.log10(0.5),1,num=20)
hsv = plt.get_cmap('spectral_r')
colors = hsv(np.linspace(0, 1.0, len(tlst)))
for s , c in zip(tlst,colors):
    data = np.loadtxt("../../project/FLASH4.3_2/object/fat3/sum_args_list{}_3.txt".format(s))
    plt.loglog(xi_range,4*np.pi*G*data/a,label= "t={}".format(s), color=c)
plt.legend(loc ="lower left")
plt.xlabel(r"log $\xi$",fontsize=16)
plt.ylabel(r"log m/$\xi$",fontsize=16)
plt.title("Fattening 3 Ricker Sphere",fontsize=16)

# %%
import yt
yt.load("../../project/FLASH4.3_2/object/fat3/sod_hdf5_chk_0040")
# Out:
# yt : [INFO     ] 2016-04-23 21:48:48,462 integer runtime parameter checkpointfilenumber overwrites a simulation scalar of the same name
# yt : [INFO     ] 2016-04-23 21:48:48,463 integer runtime parameter iprocs overwrites a simulation scalar of the same name
# yt : [INFO     ] 2016-04-23 21:48:48,463 integer runtime parameter jprocs overwrites a simulation scalar of the same name
# yt : [INFO     ] 2016-04-23 21:48:48,464 integer runtime parameter kprocs overwrites a simulation scalar of the same name
# yt : [INFO     ] 2016-04-23 21:48:48,464 integer runtime parameter plotfilenumber overwrites a simulation scalar of the same name
# yt : [INFO     ] 2016-04-23 21:48:48,487 Parameters: current_time              = 8.04336296196e+12
# yt : [INFO     ] 2016-04-23 21:48:48,488 Parameters: domain_dimensions         = [8 8 8]
# yt : [INFO     ] 2016-04-23 21:48:48,490 Parameters: domain_left_edge          = [ 0.  0.  0.]
# yt : [INFO     ] 2016-04-23 21:48:48,491 Parameters: domain_right_edge         = [  1.00000000e+19   1.00000000e+19   1.00000000e+19]
# yt : [INFO     ] 2016-04-23 21:48:48,492 Parameters: cosmological_simulation   = 0.0
# sod_hdf5_chk_0040

# %%
import plot
import os
os.chdir("../../project/FLASH4.3_2/object/fat3/")
plot.plot_dens(1)
os.chdir("/global/homes/d/dorislee/StarFormationCode/FLASH/")
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# So core formation happens at around t = 40 = 8.04336296196e+12 s

# %%
rho = 3e-19
tff = sqrt(3*pi/(32*6.67e-8*rho))
print "tff: ",tff
print "core formation at ",8.04336296196e+12/tff, "tff"
# Out:
# tff:  3.83651614562e+12
# core formation at  2.09652785409 tff

# %% [markdown]
# # Fatten  = 1

# %%
tlst = [  0, 150,200,220,240,250,260,280,300,305]
xi_range = np.logspace(np.log10(0.5),1,num=20)
hsv = plt.get_cmap('spectral')
colors = hsv(np.linspace(0, 1.0, len(tlst)))
for s , c in zip(tlst,colors):
    data = np.loadtxt("../../project/FLASH4.3_2/object/fat1/sum_args_list{}_3.txt".format(s))
    plt.loglog(xi_range,4*np.pi*G*data/a,label= "t={}".format(s), color=c)
plt.legend(loc ="lower left")
plt.xlabel(r"log $\xi$",fontsize=16)
plt.ylabel(r"log m/$\xi$",fontsize=16)
plt.title("Fattening 1 Ricker Sphere",fontsize=16)

# %%
import yt 
#yt.mylog.setLevel(0)
ds = yt.load("../../project/FLASH4.3_2/object/fat1/sod_hdf5_chk_0220")
# Out:
# yt : [INFO     ] 2016-04-23 21:57:06,249 integer runtime parameter checkpointfilenumber overwrites a simulation scalar of the same name
# yt : [INFO     ] 2016-04-23 21:57:06,251 integer runtime parameter forcedplotfilenumber overwrites a simulation scalar of the same name
# yt : [INFO     ] 2016-04-23 21:57:06,251 integer runtime parameter iprocs overwrites a simulation scalar of the same name
# yt : [INFO     ] 2016-04-23 21:57:06,252 integer runtime parameter jprocs overwrites a simulation scalar of the same name
# yt : [INFO     ] 2016-04-23 21:57:06,252 integer runtime parameter kprocs overwrites a simulation scalar of the same name
# yt : [INFO     ] 2016-04-23 21:57:06,252 integer runtime parameter nbegin overwrites a simulation scalar of the same name
# yt : [INFO     ] 2016-04-23 21:57:06,253 integer runtime parameter plotfilenumber overwrites a simulation scalar of the same name
# yt : [INFO     ] 2016-04-23 21:57:06,276 Parameters: current_time              = 1.33066066886e+14
# yt : [INFO     ] 2016-04-23 21:57:06,276 Parameters: domain_dimensions         = [8 8 8]
# yt : [INFO     ] 2016-04-23 21:57:06,277 Parameters: domain_left_edge          = [ 0.  0.  0.]
# yt : [INFO     ] 2016-04-23 21:57:06,278 Parameters: domain_right_edge         = [  1.00000000e+19   1.00000000e+19   1.00000000e+19]
# yt : [INFO     ] 2016-04-23 21:57:06,279 Parameters: cosmological_simulation   = 0.0

# %%
import plot
import os
os.chdir("../../project/FLASH4.3_2/object/fat1/")
plot.plot_dens(1)
os.chdir("/global/homes/d/dorislee/StarFormationCode/FLASH/")
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
rho = 1e-19
tff = sqrt(3*pi/(32*6.67e-8*rho))
print "tff: ",tff
print "core formation at ",1.33066066886e+14/tff, "tff"
# Out:
# tff:  6.64504088828e+12
# core formation at  20.0248680367 tff
