# %%
# %pylab inline
import yt
from yt.mods import *
yt.funcs.mylog.setLevel(50) #coerce output null
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Fat Sphere (Ricker et al sphere :density contrast of 150, outside density 1oom lower): finished running in <1min

# %%
cd ~/project/FLASH4.3_2/object/
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3_2/object

# %%
def plot_dens(i,velocity=False):
    ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
    physical_quantity="density"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_figure_size(5)
#     slc.annotate_grids()
    if velocity: slc.annotate_velocity()
    slc.set_cmap("all","rainbow")
    slc.set_zlim(physical_quantity, 5.0e-20,1.0e-16)
    slc.show()
def plot_all(i):
    ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
    physical_quantity="density"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_figure_size(5)
    slc.annotate_grids()
#     slc.set_log("all", False)
    slc.set_zlim(physical_quantity, 5.0e-20,1.0e-16)
#     slc.set_zlim(physical_quantity, 5.5e-22,1.1e-19)
    slc.set_cmap("all","rainbow")
    slc.show()

    physical_quantity="pressure"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_cmap("all","rainbow")
    slc.set_figure_size(5)
#     slc.set_log("all", False)
    # slc.set_zlim(physical_quantity,58,60)
    slc.show()

    physical_quantity="temperature"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_cmap("all","rainbow")
    slc.set_figure_size(5)
#     slc.set_zlim(physical_quantity,58,60)
#     slc.set_log("all", False)
    slc.show()

# %%
plot_all(0)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
from scipy import integrate
from matplotlib.legend_handler import HandlerLine2D
from mpl_toolkits.axes_grid1 import AxesGrid
i =0
rho_c = 1.1E-19
# pf= yt.load("output_{0}/info_{0}.txt".format(str(timestep).zfill(5)))
pf = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
plt.figure()
sp = pf.sphere(pf.domain_center, (1.5,"pc"))
rp = yt.create_profile(sp,'radius','density')#,units={'radius':'pc'},logs={'radius':False})
plt.loglog(rp.x.value,rp["density"].in_units("g/cm**3").value,label="Simulation")
xi_max = 20.0
def solvr(Y, t):
    return [Y[1], exp(-Y[0])-2/t*Y[1]]
xi = np.arange(1e-6, xi_max, 0.01) #start at small poisitive number to avoid div-by-0
asol = integrate.odeint(solvr, [0, 0], xi)
rho = np.exp(-asol[:,0]) #rho/rho_c
r = xi/1.05e-17 #[cm]
#1cm = 3.24077929e-19 Parsecs
plt.loglog(r,rho*rho_c,label ='Integration',color="red")#$\rho$')
plt.xlabel("Physical radius [cm]",fontsize=15)
plt.ylabel("Density[g/cm^3]",fontsize=15)
plt.legend(loc='upper right',prop={'size':12},numpoints=1)
plt.xlim(1e17,5e18)
# Out:
# (1e+17, 5e+18)

# %% [markdown]
# Profile plots aren't the best at looking at these objects because they have trouble binning at small radii, which is the region that  we care about. Centering at pf.domain_center is indeed the way to go (5e18 in x,y,z)

# %% [markdown]
# Hitting "Nonconvergence in subroutine rieman" really fast.  So I'm making the output time smaller so maybe we will be able to see something

# %%
# plt.subplot(211)
def density_radial_profile(timestep):
    ds = yt.load("sod_hdf5_chk_{}".format(str(timestep).zfill(4)))
    c = ds.find_max("density")[1]
    ax = 0 # Cut through x axis
    # cutting through the y0,z0 such that we hit the max density
    ray = ds.ortho_ray(ax, (c[1], c[2]))
    srt = np.argsort(ray['x'])
    plt.loglog(np.array(ray['x'][srt]), np.array(ray['density'][srt]),label="i={}".format(timestep))
#     plt.title("Timestep {}".format(timestep),fontsize=13)
    plt.xlabel("log Radius",fontsize=13)
    plt.ylabel('log Density',fontsize=13)

# %%
plt.figure()
density_radial_profile(0)
density_radial_profile(10)
density_radial_profile(20)
density_radial_profile(25)
density_radial_profile(27)
density_radial_profile(29)
density_radial_profile(31)
plt.xlim(3.5e18,7e18)
plt.legend(loc='upper right',prop={'size':11},numpoints=1)

# %% [markdown]
# Zooming in a bit

# %%
plt.figure()
density_radial_profile(0)
density_radial_profile(10)
density_radial_profile(20)
density_radial_profile(25)
density_radial_profile(27)
density_radial_profile(29)
density_radial_profile(31)
plt.xlim(4.3e18,5.8e18)
plt.ylim(1e-18,1e-14)
plt.legend(loc='upper right',prop={'size':11},numpoints=1)

# %%
plot_dens(10)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_dens(25)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_dens(27)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_dens(29)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_dens(30)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# sqrt(3*pi/(32*G*1e-16g/cm^3)) = 2e11 s

# %% [markdown]
# code crashed at t=4.149995E+11

# %% [markdown]
# so this is about 2tff

# %% [raw]
#  Terminating execution.
#  DRIVER_ABORT: Nonconvergence in subroutine rieman

# %%
def plot_rv(i):
    ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
    physical_quantity="radial_velocity"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_figure_size(5)
#     slc.annotate_grids()
#     slc.annotate_velocity()
    slc.set_cmap("all","rainbow")
#     slc.set_zlim(physical_quantity, -1.1e-2 ,-0.1e-2)
    slc.set_log("all", False)
    slc.show()

# %%
plot_rv(1)
plot_rv(16)
plot_rv(30)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# I keep setting dt output as something smaller now its at 1.0, but then it just stalls after this, so back to 1e2. The stuff towards the end happens really fast its hard to catch them

# %% [markdown]
# ### Note about FLASH output files

# %% [markdown]
# I also think that FLASH output files work a bit differently from what we are used to in RAMSES.
# Here I kept decreasing the output times but I didn't see the t/$\Delta t$ number of outputs that I expected to see.
# I have checkpointFileIntervalTime = 1.E7 (same for plotfile) set, but it looks like in FLASH we don't have "fillers" for output files before we reach the first t=1e7. Simmilarly we don't have "fillers" for when we take larger steps.
# So really the way the files are spit out is kind of non-uniform, at least we can't expect to just derived the time back by t = $\Delta t$ *number

# %% [raw]
#       8 5.1000E+05 2.5600E+05  ( 4.961E+18,  4.961E+18,  3.398E+18) |  2.132E+11
#        9 1.0220E+06 5.1200E+05  ( 4.961E+18,  4.961E+18,  3.398E+18) |  2.132E+11
#       10 2.0460E+06 1.0240E+06  ( 4.961E+18,  4.961E+18,  3.398E+18) |  2.132E+11
#       11 4.0940E+06 2.0480E+06  ( 4.961E+18,  4.961E+18,  3.398E+18) |  2.132E+11
#       12 8.1900E+06 4.0960E+06  ( 4.961E+18,  4.961E+18,  3.398E+18) |  2.132E+11
#       13 1.6382E+07 8.1920E+06  ( 4.961E+18,  4.961E+18,  3.398E+18) |  2.132E+11
#       14 3.2766E+07 1.6384E+07  ( 3.398E+18,  4.961E+18,  4.961E+18) |  2.131E+11
#       15 6.5534E+07 3.2768E+07  ( 3.398E+18,  4.961E+18,  4.961E+18) |  2.131E+11
#  *** Wrote plotfile to sod_hdf5_plt_cnt_0001 ****
#       16 1.3107E+08 6.5536E+07  ( 3.398E+18,  4.961E+18,  4.961E+18) |  2.129E+11
#  *** Wrote checkpoint file to sod_hdf5_chk_0001 ****
#  *** Wrote plotfile to sod_hdf5_plt_cnt_0002 ****
#       17 2.6214E+08 1.3107E+08  ( 3.398E+18,  4.961E+18,  4.961E+18) |  2.126E+11
#  *** Wrote checkpoint file to sod_hdf5_chk_0002 ****
#  *** Wrote plotfile to sod_hdf5_plt_cnt_0003 ****
#       18 5.2429E+08 2.6214E+08  ( 3.398E+18,  4.961E+18,  4.961E+18) |  2.120E+11
#  *** Wrote checkpoint file to sod_hdf5_chk_0003 ****
#  *** Wrote plotfile to sod_hdf5_plt_cnt_0004 ****
#       19 1.0486E+09 5.2429E+08  ( 5.039E+18,  4.961E+18,  3.398E+18) |  2.108E+11
#  *** Wrote checkpoint file to sod_hdf5_chk_0004 ****
#  *** Wrote plotfile to sod_hdf5_plt_cnt_0005 ****
#       20 2.0972E+09 1.0486E+09  ( 3.398E+18,  4.961E+18,  4.961E+18) |  2.085E+11
#  *** Wrote checkpoint file to sod_hdf5_chk_0005 ****
# *** Wrote plotfile to sod_hdf5_plt_cnt_0006 ****
#       21 4.1943E+09 2.0972E+09  ( 3.398E+18,  5.039E+18,  4.961E+18) |  2.039E+11
#  *** Wrote checkpoint file to sod_hdf5_chk_0006 ****
#  *** Wrote plotfile to sod_hdf5_plt_cnt_0007 ****
#       22 8.3886E+09 4.1943E+09  ( 3.398E+18,  4.961E+18,  4.961E+18) |  1.954E+11
#  *** Wrote checkpoint file to sod_hdf5_chk_0007 ****
#  *** Wrote plotfile to sod_hdf5_plt_cnt_0008 ****
#       23 1.6777E+10 8.3886E+09  ( 3.398E+18,  4.961E+18,  4.961E+18) |  1.803E+11
#  *** Wrote checkpoint file to sod_hdf5_chk_0008 ****
#  *** Wrote plotfile to sod_hdf5_plt_cnt_0009 ****
#       24 3.3554E+10 1.6777E+10  ( 4.727E+18,  5.039E+18,  4.961E+18) |  1.314E+11
#  *** Wrote checkpoint file to sod_hdf5_chk_0009 ****
#  *** Wrote plotfile to sod_hdf5_plt_cnt_0010 ****
#       25 6.7109E+10 3.3554E+10  ( 4.727E+18,  4.961E+18,  4.961E+18) |  7.039E+10
#  *** Wrote checkpoint file to sod_hdf5_chk_0010 ****
#  *** Wrote plotfile to sod_hdf5_plt_cnt_0011 ****
#       26 1.3422E+11 3.4699E+10  ( 5.273E+18,  4.961E+18,  4.961E+18) |  3.470E+10
#  *** Wrote checkpoint file to sod_hdf5_chk_0011 ****
#  *** Wrote plotfile to sod_hdf5_plt_cnt_0012 ****
#       27 2.0362E+11 2.0802E+10  ( 5.039E+18,  5.039E+18,  5.195E+18) |  2.080E+10
#  *** Wrote checkpoint file to sod_hdf5_chk_0012 ****
#  *** Wrote plotfile to sod_hdf5_plt_cnt_0013 ****
#       28 2.4522E+11 1.6276E+10  ( 5.039E+18,  4.961E+18,  5.195E+18) |  1.628E+10
#  *** Wrote checkpoint file to sod_hdf5_chk_0013 ****
#  *** Wrote plotfile to sod_hdf5_plt_cnt_0014 ****
#       29 2.7777E+11 1.3673E+10  ( 5.195E+18,  4.961E+18,  5.039E+18) |  1.367E+10
#  *** Wrote checkpoint file to sod_hdf5_chk_0014 ****
