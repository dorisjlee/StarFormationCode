# %%
import yt
yt.mylog.setLevel(50)
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ~/project/FLASH4.3_2/object/
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3_2/object

# %%
def plot_all(i):
    ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
    physical_quantity="density"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_figure_size(5)
    slc.annotate_grids()
#     slc.set_log("all", False)
    slc.set_cmap("all","rainbow")
    slc.show()

    physical_quantity="pressure"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_cmap("all","rainbow")
    slc.set_figure_size(5)
    slc.set_log("all", False)
    # slc.set_zlim(physical_quantity,58,60)
    slc.show()

    physical_quantity="temperature"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_cmap("all","rainbow")
    slc.set_figure_size(5)
#     slc.set_zlim(physical_quantity,58,60)
    slc.set_log("all", False)
    slc.show()

# %%
def plot_dens(i):
    ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
    physical_quantity="density"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_figure_size(5)
    slc.annotate_grids()
    slc.annotate_velocity()
    slc.set_cmap("all","rainbow")
    slc.show()

# %%
plot_all(0)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_dens(1)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_dens(14)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
ls sod*
# Out:
# sod.dat                       sod_hdf5_chk_0009      sod_hdf5_plt_cnt_0005
# sod_forced_hdf5_plt_cnt_0000  sod_hdf5_chk_0010      sod_hdf5_plt_cnt_0006
# sod_hdf5_chk_0000             sod_hdf5_chk_0011      sod_hdf5_plt_cnt_0007
# sod_hdf5_chk_0001             sod_hdf5_chk_0012      sod_hdf5_plt_cnt_0008
# sod_hdf5_chk_0002             sod_hdf5_chk_0013      sod_hdf5_plt_cnt_0009
# sod_hdf5_chk_0003             sod_hdf5_chk_0014      sod_hdf5_plt_cnt_0010
# sod_hdf5_chk_0004             sod_hdf5_plt_cnt_0000  sod_hdf5_plt_cnt_0011
# sod_hdf5_chk_0005             sod_hdf5_plt_cnt_0001  sod_hdf5_plt_cnt_0012
# sod_hdf5_chk_0006             sod_hdf5_plt_cnt_0002  sod_hdf5_plt_cnt_0013
# sod_hdf5_chk_0007             sod_hdf5_plt_cnt_0003  sod_hdf5_plt_cnt_0014
# sod_hdf5_chk_0008             sod_hdf5_plt_cnt_0004  sod.log

# %%
# for i in np.arange(27):
#     plot_dens(i)
