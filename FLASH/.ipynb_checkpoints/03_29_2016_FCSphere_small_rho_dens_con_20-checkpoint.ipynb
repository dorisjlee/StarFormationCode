# %%
# %pylab inline
from scipy import integrate
from matplotlib.legend_handler import HandlerLine2D
from scipy import integrate
from mpl_toolkits.axes_grid1 import AxesGrid
import yt
from yt.mods import *
yt.funcs.mylog.setLevel(50) #coerce output null
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
xi_max = 6.451
from scipy import integrate
def solvr(Y, t):
    return [Y[1], exp(-Y[0])-2/t*Y[1]]
xi = np.arange(1e-6, xi_max, 0.01) #start at small poisitive number to avoid div-by-0
asol = integrate.odeint(solvr, [0, 0], xi)
rho = np.exp(-asol[:,0]) #rho/rho_c
r = xi/1.05e-17 #[cm]
plt.plot(r,asol[:,0],label ='psi')#$\psi$' )
plt.plot(r,rho,label ='rho/rho_c')#$\rho$')
plt.xlabel("Physical radius",fontsize=15)
from matplotlib.legend_handler import HandlerLine2D
plt.legend(loc='upper left',prop={'size':12},numpoints=1)

# %% [markdown]
# In the FC sphere that I evolved with FLASH for 6tff I used a rmax =6.41

# %%
1/rho[641]
# Out:
# 13.8272032312771

# %%
shape(rho)
# Out:
# (700,)

# %%
xi_max = 7.0
xi = np.arange(1e-6, xi_max, 0.01) #start at small poisitive number to avoid div-by-0
asol = integrate.odeint(solvr, [0, 0], xi)
rho =  np.exp(-asol[:,0]) 
r = xi/1.05e-17 #[cm]
plt.plot(xi,asol[:,0],label ='psi')#$\psi$' )
plt.plot(xi,rho,label ='rho/rho_c')#$\rho$')
# plt.xlabel("Physical radius",fontsize=15)
from matplotlib.legend_handler import HandlerLine2D
plt.legend(loc='upper left',prop={'size':12},numpoints=1)
# np.savetxt("../patch/hydro/isothermal_sphere/density.txt",rho)

# %%
cd ~/project/FLASH4.3_2/object/fc_sphere_small_rho_6tff/
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3_2/object/fc_sphere_small_rho_6tff

# %%
i =1
rho_c = 1.1E-19
# pf= yt.load("output_{0}/info_{0}.txt".format(str(timestep).zfill(5)))
pf = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
plt.figure()
sp = pf.sphere(pf.domain_center, (0.30,"pc"))
rp = yt.create_profile(sp,'radius','density')#,units={'radius':'pc'},logs={'radius':False})
plt.plot(rp.x.value*3.24077929e-19,rp["density"].in_units("g/cm**3").value,label="Simulation")
xi_max = 20.0
def solvr(Y, t):
    return [Y[1], exp(-Y[0])-2/t*Y[1]]
xi = np.arange(1e-6, xi_max, 0.01) #start at small poisitive number to avoid div-by-0
asol = integrate.odeint(solvr, [0, 0], xi)
rho = np.exp(-asol[:,0]) #rho/rho_c
r = xi/1.05e-17 #[cm]
#1cm = 3.24077929e-19 Parsecs
plt.plot(r*3.24077929e-19,rho*rho_c,label ='Integration',color="red")#$\rho$')
plt.xlabel("Physical radius [pc]",fontsize=15)
plt.ylabel("Density[g/cm^3]",fontsize=15)
plt.legend(loc='upper right',prop={'size':12},numpoints=1)

# %%
shape(rho)
# Out:
# (2000,)

# %%
rho_txt = np.loadtxt("../../density.txt")

# %%
plt.plot(rho,'--',color="red",linewidth=5)
plt.plot(rho_txt)

# %%
shape(rho)
# Out:
# (2000,)

# %%
d_ratio = 1.0/rho
d_ratio[np.where(d_ratio<20)[0]][-1]
# Out:
# 19.963728865699053

# %%
np.where(d_ratio<20)[0][-1]
# Out:
# 744

# %%
d_ratio[646]
# Out:
# 14.091107794349936

# %%
np.where(d_ratio<20)[0][-1]
# Out:
# 744

# %%
d_ratio[745]
# Out:
# 20.030667873735172

# %%
cd ..
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3_2/object

# %%
i =0
rho_c = 1.1E-19
# pf= yt.load("output_{0}/info_{0}.txt".format(str(timestep).zfill(5)))
pf = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
plt.figure()
sp = pf.sphere(pf.domain_center, (0.30,"pc"))
rp = yt.create_profile(sp,'radius','density')#,units={'radius':'pc'},logs={'radius':False})
plt.plot(rp.x.value*3.24077929e-19,rp["density"].in_units("g/cm**3").value,label="Simulation")
xi_max = 20.0
def solvr(Y, t):
    return [Y[1], exp(-Y[0])-2/t*Y[1]]
xi = np.arange(1e-6, xi_max, 0.01) #start at small poisitive number to avoid div-by-0
asol = integrate.odeint(solvr, [0, 0], xi)
rho = np.exp(-asol[:,0]) #rho/rho_c
r = xi/1.05e-17 #[cm]
#1cm = 3.24077929e-19 Parsecs
plt.plot(r*3.24077929e-19,rho*rho_c,label ='Integration',color="red")#$\rho$')
plt.xlabel("Physical radius [pc]",fontsize=15)
plt.ylabel("Density[g/cm^3]",fontsize=15)
plt.legend(loc='upper right',prop={'size':12},numpoints=1)
# Out:
# yt : [INFO     ] 2016-03-29 22:08:01,909 integer runtime parameter iprocs overwrites a simulation scalar of the same name
# yt : [INFO     ] 2016-03-29 22:08:01,910 integer runtime parameter jprocs overwrites a simulation scalar of the same name
# yt : [INFO     ] 2016-03-29 22:08:01,910 integer runtime parameter kprocs overwrites a simulation scalar of the same name
# yt : [INFO     ] 2016-03-29 22:08:01,922 Parameters: current_time              = 0.0
# yt : [INFO     ] 2016-03-29 22:08:01,923 Parameters: domain_dimensions         = [8 8 8]
# yt : [INFO     ] 2016-03-29 22:08:01,924 Parameters: domain_left_edge          = [ 0.  0.  0.]
# yt : [INFO     ] 2016-03-29 22:08:01,925 Parameters: domain_right_edge         = [  5.00000000e+18   5.00000000e+18   5.00000000e+18]
# yt : [INFO     ] 2016-03-29 22:08:01,925 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2016-03-29 22:08:02,080 Loading field plugins.
# yt : [INFO     ] 2016-03-29 22:08:02,081 Loaded angular_momentum (8 new fields)
# yt : [INFO     ] 2016-03-29 22:08:02,082 Loaded astro (15 new fields)
# yt : [INFO     ] 2016-03-29 22:08:02,083 Loaded cosmology (22 new fields)
# yt : [INFO     ] 2016-03-29 22:08:02,085 Loaded fluid (62 new fields)
# yt : [INFO     ] 2016-03-29 22:08:02,086 Loaded fluid_vector (94 new fields)
# yt : [INFO     ] 2016-03-29 22:08:02,087 Loaded geometric (110 new fields)
# yt : [INFO     ] 2016-03-29 22:08:02,088 Loaded local (110 new fields)
# yt : [INFO     ] 2016-03-29 22:08:02,089 Loaded magnetic_field (118 new fields)
# yt : [INFO     ] 2016-03-29 22:08:02,090 Loaded my_plugins (118 new fields)
# yt : [INFO     ] 2016-03-29 22:08:02,091 Loaded species (120 new fields)

# %%
sim_rho = rp["density"].in_units("g/cm**3").value

# %%
min(sim_rho[np.where(sim_rho>1e-26)[0]])
# Out:
# 5.7765544645315567e-21

# %%
1.10e-19*rho[745]
# Out:
# 5.4915792470522352e-21

# %%
# sim_rho[np.where(sim_rho>1e-26)[0]]

# %%
idx=np.where(1.1e-19/sim_rho>20)[0]

# %%
sim_rho[idx]
# Out:
# array([  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   7.98560000e-27,   7.98560000e-27,
#          7.98560000e-27,   7.98560000e-27,   7.98560000e-27])

# %%
1.1e-19/5.776e-21
# Out:
# 19.04432132963989

# %%
rho_out=8e-27
1.1e-19/sim_rho[np.where(sim_rho>rho_out)[0][-1]]
# Out:
# 19.042493354024028

# %%
cd ~/project/FLASH4.3_2/object/
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3_2/object

# %%
def plot_dens(i):
    ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
    physical_quantity="density"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_figure_size(5)
#     slc.annotate_grids()
    slc.annotate_velocity()
    slc.set_cmap("all","rainbow")
    slc.set_zlim(physical_quantity, 5.5e-26,1.1e-19)
    slc.show()
def plot_all(i):
    ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
    physical_quantity="density"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_figure_size(5)
    slc.annotate_grids()
#     slc.set_log("all", False)
    slc.set_cmap("all","rainbow")
    slc.show()

    physical_quantity="pressure"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_cmap("all","rainbow")
    slc.set_figure_size(5)
    slc.set_log("all", False)
    # slc.set_zlim(physical_quantity,58,60)
    slc.show()

    physical_quantity="temperature"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_cmap("all","rainbow")
    slc.set_figure_size(5)
#     slc.set_zlim(physical_quantity,58,60)
#     slc.set_log("all", False)
    slc.show()

# %%
plot_all(0)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
for i in np.arange(0,36):
    if i%2==0:
        plot_dens(i)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
3.2401E+13/6.33e12
# Out:
# 5.118641390205371

# %%
ls sod*
# Out:
# sod.dat                       sod_hdf5_chk_0034      sod_hdf5_plt_cnt_0034
# sod_forced_hdf5_plt_cnt_0000  sod_hdf5_chk_0035      sod_hdf5_plt_cnt_0035
# sod_hdf5_chk_0000             sod_hdf5_plt_cnt_0000  sod_hdf5_plt_cnt_0036
# sod_hdf5_chk_0001             sod_hdf5_plt_cnt_0001  sod_hdf5_plt_cnt_0037
# sod_hdf5_chk_0002             sod_hdf5_plt_cnt_0002  sod_hdf5_plt_cnt_0038
# sod_hdf5_chk_0003             sod_hdf5_plt_cnt_0003  sod_hdf5_plt_cnt_0039
# sod_hdf5_chk_0004             sod_hdf5_plt_cnt_0004  sod_hdf5_plt_cnt_0040
# sod_hdf5_chk_0005             sod_hdf5_plt_cnt_0005  sod_hdf5_plt_cnt_0041
# sod_hdf5_chk_0006             sod_hdf5_plt_cnt_0006  sod_hdf5_plt_cnt_0042
# sod_hdf5_chk_0007             sod_hdf5_plt_cnt_0007  sod_hdf5_plt_cnt_0043
# sod_hdf5_chk_0008             sod_hdf5_plt_cnt_0008  sod_hdf5_plt_cnt_0044
# sod_hdf5_chk_0009             sod_hdf5_plt_cnt_0009  sod_hdf5_plt_cnt_0045
# sod_hdf5_chk_0010             sod_hdf5_plt_cnt_0010  sod_hdf5_plt_cnt_0046
# sod_hdf5_chk_0011             sod_hdf5_plt_cnt_0011  sod_hdf5_plt_cnt_0047
# sod_hdf5_chk_0012             sod_hdf5_plt_cnt_0012  sod_hdf5_plt_cnt_0048
# sod_hdf5_chk_0013             sod_hdf5_plt_cnt_0013  sod_hdf5_plt_cnt_0049
# sod_hdf5_chk_0014             sod_hdf5_plt_cnt_0014  sod_hdf5_plt_cnt_0050
# sod_hdf5_chk_0015             sod_hdf5_plt_cnt_0015  sod_hdf5_plt_cnt_0051
# sod_hdf5_chk_0016             sod_hdf5_plt_cnt_0016  sod_hdf5_plt_cnt_0052
# sod_hdf5_chk_0017             sod_hdf5_plt_cnt_0017  sod_hdf5_plt_cnt_0053
# sod_hdf5_chk_0018             sod_hdf5_plt_cnt_0018  sod_hdf5_plt_cnt_0054
# sod_hdf5_chk_0019             sod_hdf5_plt_cnt_0019  sod_hdf5_plt_cnt_0055
# sod_hdf5_chk_0020             sod_hdf5_plt_cnt_0020  sod_hdf5_plt_cnt_0056
# sod_hdf5_chk_0021             sod_hdf5_plt_cnt_0021  sod_hdf5_plt_cnt_0057
# sod_hdf5_chk_0022             sod_hdf5_plt_cnt_0022  sod_hdf5_plt_cnt_0058
# sod_hdf5_chk_0023             sod_hdf5_plt_cnt_0023  sod_hdf5_plt_cnt_0059
# sod_hdf5_chk_0024             sod_hdf5_plt_cnt_0024  sod_hdf5_plt_cnt_0060
# sod_hdf5_chk_0025             sod_hdf5_plt_cnt_0025  sod_hdf5_plt_cnt_0061
# sod_hdf5_chk_0026             sod_hdf5_plt_cnt_0026  sod_hdf5_plt_cnt_0062
# sod_hdf5_chk_0027             sod_hdf5_plt_cnt_0027  sod_hdf5_plt_cnt_0063
# sod_hdf5_chk_0028             sod_hdf5_plt_cnt_0028  sod_hdf5_plt_cnt_0064
# sod_hdf5_chk_0029             sod_hdf5_plt_cnt_0029  sod_hdf5_plt_cnt_0065
# sod_hdf5_chk_0030             sod_hdf5_plt_cnt_0030  sod_hdf5_plt_cnt_0066
# sod_hdf5_chk_0031             sod_hdf5_plt_cnt_0031  sod_hdf5_plt_cnt_0067
# sod_hdf5_chk_0032             sod_hdf5_plt_cnt_0032  sod.log
# sod_hdf5_chk_0033             sod_hdf5_plt_cnt_0033

# %% [markdown]
# "set plotfileNumber and particleFileNumber to the number of the next plotfile and particle file you want FLASH to output.""

# %% [markdown]
# rho_min = 5.7765544645315567e-21

# %% [markdown]
# 1529754.out ran for 8:23:44, then switched to 1541426.out started running 4am

# %% [markdown]
# 5 tff reached at around 16 hrs so that's a total of 16+8=24 hrs
