# %%
import yt
yt.mylog.setLevel(50)
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ~/project/FLASH4.3/object/
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3/object

# %% [raw]
# ./setup FosterChevalier -3d --maxblock=3000 -auto; cd object/;make -j;cd ..;qsub srun.pbs

# %%
i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
# slc.set_log("all", False)
# slc.set_zlim(physical_quantity,0,1)
slc.show()

physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,58,60)
slc.show()

physical_quantity="temperature"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
# Out:
# yt : [INFO     ] 2016-03-06 19:36:27,382 Parameters: current_time              = 0.0
# yt : [INFO     ] 2016-03-06 19:36:27,382 Parameters: domain_dimensions         = [8 8 8]
# yt : [INFO     ] 2016-03-06 19:36:27,384 Parameters: domain_left_edge          = [ 0.  0.  0.]
# yt : [INFO     ] 2016-03-06 19:36:27,385 Parameters: domain_right_edge         = [ 1.  1.  1.]
# yt : [INFO     ] 2016-03-06 19:36:27,386 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2016-03-06 19:36:31,598 Loading field plugins.
# yt : [INFO     ] 2016-03-06 19:36:31,599 Loaded angular_momentum (8 new fields)
# yt : [INFO     ] 2016-03-06 19:36:31,600 Loaded astro (15 new fields)
# yt : [INFO     ] 2016-03-06 19:36:31,601 Loaded cosmology (22 new fields)
# yt : [INFO     ] 2016-03-06 19:36:31,602 Loaded fluid (62 new fields)
# yt : [INFO     ] 2016-03-06 19:36:31,603 Loaded fluid_vector (94 new fields)
# yt : [INFO     ] 2016-03-06 19:36:31,604 Loaded geometric (110 new fields)
# ...

# %%
i = 5
ds = yt.load("sod_hdf5_plt_cnt_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.show()

physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.set_log("all", False)
slc.set_zlim(physical_quantity,58,60)
slc.show()
# Out:
# yt : [INFO     ] 2016-03-06 19:39:41,169 xlim = 0.000000 1.000000
# yt : [INFO     ] 2016-03-06 19:39:41,170 ylim = 0.000000 1.000000
# yt : [INFO     ] 2016-03-06 19:39:41,172 xlim = 0.000000 1.000000
# yt : [INFO     ] 2016-03-06 19:39:41,173 ylim = 0.000000 1.000000
# yt : [INFO     ] 2016-03-06 19:39:41,174 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2016-03-06 19:39:43,078 xlim = 0.000000 1.000000
# yt : [INFO     ] 2016-03-06 19:39:43,079 ylim = 0.000000 1.000000
# yt : [INFO     ] 2016-03-06 19:39:43,081 xlim = 0.000000 1.000000
# yt : [INFO     ] 2016-03-06 19:39:43,082 ylim = 0.000000 1.000000
# yt : [INFO     ] 2016-03-06 19:39:43,083 Making a fixed resolution buffer of (('gas', 'pressure')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [raw]
# rho_min:   7.985580336402862E-021

# %% [markdown]
# Okay so I fixed the EOF error by this :
#
#     If you prepare the input using keyboard, hiting the Ctrl-D key would generate the end-of-mark under UNIX. Once you hit Ctrl-D, the system would consider your input stop at there. If your program tries to read passing this point, this is an error.

# %%
i = 0
ds = yt.load("sod_hdf5_plt_cnt_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.show()

physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.set_log("all", False)
slc.set_zlim(physical_quantity,58,60)
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# again crash at non-convergence rieman . sphere looks uniform and not FC!!

# %% [markdown]
# Oh that's becuase I was silly and forgot to put in the density values read in by the density.txt file. '

# %%
i = 0
ds = yt.load("sod_hdf5_plt_cnt_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.show()

physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.set_log("all", False)
slc.set_zlim(physical_quantity,58,60)
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [raw]
#  [Eos_putData] ERROR Density or Internal Energy are zero after a call to EOS!

# %% [raw]
#  rhoZone:   7.985600000000000E-027
#  presZone:   6.591314240000000E-018
#  rhoZone:   7.985600000000000E-027
#  presZone:   6.591314240000000E-018
#  rhoZone:   7.985600000000000E-027
#  presZone:   6.591314240000000E-018
#  rhoZone:   0.000000000000000E+000
#  presZone:   0.000000000000000E+000
#  rhoZone:   0.000000000000000E+000
#  presZone:   0.000000000000000E+000
#  rhoZone:   0.000000000000000E+000
#  presZone:   0.000000000000000E+000
#  rhoZone:   0.000000000000000E+000
#  presZone:   0.000000000000000E+000
#  rhoZone:   0.000000000000000E+000
#  presZone:   0.000000000000000E+000
#  rhoZone:   7.985600000000000E-027
#  presZone:   6.591314240000000E-018

# %% [markdown]
# Why is there regions with zero pressure ?

# %% [raw]
# It looks like only the inside ones are problematic

# %% [raw]
# Outisde^M
#  rhoZone:   7.985600000000000E-027^M
#  presZone:   6.591314240000000E-018^M
#  xx,yy,zz:  -1.406250000000000E+017  1.562500000000000E+016^M
#   1.562500000000000E+016^M
#  rr:   1.423505246741297E+017^M
#  Inside^M
#  rhoZone:   0.000000000000000E+000^M
#  presZone:   0.000000000000000E+000^M
#  xx,yy,zz:  -1.093750000000000E+017  1.562500000000000E+016^M
#   1.562500000000000E+016^M
#  rr:   1.115848191959820E+017^M

# %% [markdown]
# This is weird because when it reads dens_arr(0,1) it reads a value of zero even though the first element in density.txt is 1.0 and when I read dens_arr(2,1) it actually returns the 2nd value of the list so it means that it starts counting from 1 somehow, not sure why this differs frmo rameses since this is both fortran but I guess something is weird, so I use ceiling to up all the index by one alltogether and this should fix the problem

# %% [raw]
#      n          t         dt  (         x,          y,          z) |  dt_hydro ^M
#        1 2.0000E-02 2.0000E-02  ( 2.568E+17,  4.111E+17,  2.334E+17) |  1.530E+15^M

# %% [markdown]
# Taking big steps this is good

# %%
i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_grids()
slc.set_cmap("all","rainbow")
slc.show()

physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_cmap("all","rainbow")
slc.set_figure_size(5)
# slc.set_log("all", False)
# slc.set_zlim(physical_quantity,58,60)
slc.show()

physical_quantity="temperature"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_cmap("all","rainbow")
slc.set_figure_size(5)
# slc.set_log("all", False)
# slc.set_zlim(physical_quantity,58,60)
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [raw]
#  *** Wrote checkpoint file to sod_hdf5_chk_0000 ****^M

# %% [markdown]
# doesn't look very FC because it looks like all rho values are rho_c '

# %% [markdown]
# temperature should not be constant differes inside and outside by 6 orders of magnitude

# %% [raw]
# So I think this:
#     WARNING after gc filling: min. unk(DENS_VAR)=0.7985599999999999992868E-26     PE=15    block=470

# %% [markdown]
# the density values correspond to what I put as rho_out so maybe that's not being filled properly, but on the plot it looks okay though

# %% [markdown]
# fix the reading of the rho value from lane emden first

# %%
i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_grids()
slc.set_cmap("all","rainbow")
slc.show()

physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_cmap("all","rainbow")
slc.set_figure_size(5)
# slc.set_log("all", False)
# slc.set_zlim(physical_quantity,58,60)
slc.show()

physical_quantity="temperature"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_cmap("all","rainbow")
slc.set_figure_size(5)
# slc.set_log("all", False)
# slc.set_zlim(physical_quantity,58,60)
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# woah ok this is good we're getting like FC sphere but need to increase boxsize'
