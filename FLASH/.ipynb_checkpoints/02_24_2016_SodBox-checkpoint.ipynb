# %% [markdown]
# Basically exactly the same thing as Sod to begin with

# %%
import yt
yt.mylog.setLevel(50)
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ~/project/FLASH4.3/object/
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3/object

# %%
i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
# slc.set_zlim(physical_quantity,1e-18,1e-19)
slc.show()


i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
# slc.set_zlim(physical_quantity,1e-18,1e-19)
slc.show()

i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="temperature"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
# slc.set_zlim(physical_quantity,1e-18,1e-19)
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# Attempt to make it uniform now

# %%
sim_rhoRight    = 0.125
sim_pRight              = 0.1

# %% [markdown]
# This agree with what is predicted from ideal gas law :
#
#     (0.125 g/cm^3)*(boltzman's constant)*(1.5e-8K)/mass of proton  in g/cm/s^2

# %%
i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,1)
slc.show()


i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
# slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,1)
slc.show()

i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="temperature"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
# slc.set_log("all", False)
slc.set_zlim(physical_quantity,5e-8,5e-9)
slc.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-137393c7e28e> in <module>()
#       2 ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
#       3 physical_quantity="density"
# ----> 4 slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
#       5 slc.set_figure_size(5)
#       6 slc.annotate_velocity()
#
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/yt/visualization/plot_window.pyc in SlicePlot(ds, normal, fields, axis, *args, **kwargs)
#    2131             del kwargs['north_vector']
#    2132
# -> 2133         return AxisAlignedSlicePlot(ds, normal, fields, *args, **kwargs)
#
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/yt/visualization/plot_window.pyc in __init__(self, ds, axis, fields, center, width, axes_unit, origin, fontsize, field_parameters, window_size, aspect, data_source)
#    1272         PWViewerMPL.__init__(self, slc, bounds, origin=origin,
#    1273                              fontsize=fontsize, fields=fields,
# -> 1274                              window_size=window_size, aspect=aspect)
#    1275         if axes_unit is None:
#    1276             axes_unit = get_axes_unit(width, ds)
#
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/yt/visualization/plot_window.pyc in __init__(self, *args, **kwargs)
#     667             self._plot_type = kwargs.pop("plot_type")
#     668         self._splat_color = kwargs.pop("splat_color", None)
# --> 669         PlotWindow.__init__(self, *args, **kwargs)
#     670
#     671     def _setup_origin(self):
#
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/yt/visualization/plot_window.pyc in __init__(self, data_source, bounds, buff_size, antialias, periodic, origin, oblique, window_size, fields, fontsize, aspect, setup)
#     247                 self._field_transform[field] = linear_transform
#     248         self.setup_callbacks()
# --> 249         self._setup_plots()
#     250
#     251     def _initialize_dataset(self, ts):
#
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/yt/visualization/plot_window.pyc in _setup_plots(self)
#     834                 self._colormaps[f], extent, zlim,
#     835                 self.figure_size, font_size,
# --> 836                 self.aspect, fig, axes, cax)
#     837
#     838             axes_unit_labels = ['', '']
#
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/yt/visualization/plot_window.pyc in __init__(self, data, cbname, cblinthresh, cmap, extent, zlim, figure_size, fontsize, aspect, figure, axes, cax)
#    1955             size, axrect, caxrect, zlim, figure, axes, cax)
#    1956
# -> 1957         self._init_image(data, cbname, cblinthresh, cmap, extent, aspect)
#    1958
#    1959         self.image.axes.ticklabel_format(scilimits=(-2, 3))
#
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/yt/visualization/base_plot_types.pyc in _init_image(self, data, cbnorm, cblinthresh, cmap, extent, aspect)
#     160             self.cb.set_ticks(yticks)
#     161         else:
# --> 162             self.cb = self.figure.colorbar(self.image, self.cax)
#     163
#     164     def _repr_png_(self):
#
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/figure.pyc in colorbar(self, mappable, cax, ax, use_gridspec, **kw)
#    1567                 cax, kw = cbar.make_axes(ax, **kw)
#    1568         cax.hold(True)
# -> 1569         cb = cbar.colorbar_factory(cax, mappable, **kw)
#    1570
#    1571         self.sca(current_ax)
#
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/colorbar.pyc in colorbar_factory(cax, mappable, **kwargs)
#    1328         cb = ColorbarPatch(cax, mappable, **kwargs)
#    1329     else:
# -> 1330         cb = Colorbar(cax, mappable, **kwargs)
#    1331
#    1332     cid = mappable.callbacksSM.connect('changed', cb.on_mappable_changed)
#
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/colorbar.pyc in __init__(self, ax, mappable, **kw)
#     903                 kw['alpha'] = mappable.get_alpha()
#     904
# --> 905             ColorbarBase.__init__(self, ax, **kw)
#     906
#     907     def on_mappable_changed(self, mappable):
#
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/colorbar.pyc in __init__(self, ax, cmap, norm, alpha, values, boundaries, orientation, ticklocation, extend, spacing, ticks, format, drawedges, filled, extendfrac, extendrect, label)
#     321         # The rest is in a method so we can recalculate when clim changes.
#     322         self.config_axis()
# --> 323         self.draw_all()
#     324
#     325     def _extend_lower(self):
#
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/colorbar.pyc in draw_all(self)
#     346         X, Y = self._mesh()
#     347         C = self._values[:, np.newaxis]
# --> 348         self._config_axes(X, Y)
#     349         if self.filled:
#     350             self._add_solids(X, Y, C)
#
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/colorbar.pyc in _config_axes(self, X, Y)
#     442         ax.add_artist(self.patch)
#     443
# --> 444         self.update_ticks()
#     445
#     446     def _set_label(self):
#
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/colorbar.pyc in update_ticks(self)
#     371         """
#     372         ax = self.ax
# --> 373         ticks, ticklabels, offset_string = self._ticker()
#     374         if self.orientation == 'vertical':
#     375             ax.yaxis.set_ticks(ticks)
#
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/colorbar.pyc in _ticker(self)
#     592         formatter.set_data_interval(*intv)
#     593
# --> 594         b = np.array(locator())
#     595         if isinstance(locator, ticker.LogLocator):
#     596             eps = 1e-10
#
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/ticker.pyc in __call__(self)
#    1533         'Return the locations of the ticks'
#    1534         vmin, vmax = self.axis.get_view_interval()
# -> 1535         return self.tick_values(vmin, vmax)
#    1536
#    1537     def tick_values(self, vmin, vmax):
#
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/ticker.pyc in tick_values(self, vmin, vmax)
#    1551             if vmin <= 0.0 or not np.isfinite(vmin):
#    1552                 raise ValueError(
# -> 1553                     "Data has no positive values, and therefore can not be "
#    1554                     "log-scaled.")
#    1555
#
# ValueError: Data has no positive values, and therefore can not be log-scaled.
