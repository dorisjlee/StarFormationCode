# %%
import yt
yt.mylog.setLevel(50)
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ~/project/FLASH4.3/object/
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3/object

# %% [markdown]
# Things that I still have to fix:
# - pressure/temperature
# - change size of the box and size of sphere
# - ~~activate AMR~~
# - put a sink particle at the center

# %%
i =0 
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()

i =0 
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
i =0 
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="temperature"
slc = yt.SlicePlot(ds, "z",physical_quantity)
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
# Out:
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:645: RuntimeWarning: divide by zero encountered in double_scalars
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:645: RuntimeWarning: invalid value encountered in multiply
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:701: RuntimeWarning: invalid value encountered in less
#   short = np.repeat(length < minsh, 8, axis=1)
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:711: RuntimeWarning: invalid value encountered in less
#   tooshort = length < self.minlength
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
i =1
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()

ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()

ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="temperature"
slc = yt.SlicePlot(ds, "z",physical_quantity)
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# Switching to using the new code based off of Sod Shock tube

# %%
i =0 
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()

i =0 
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
i =0 

ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="temperature"
slc = yt.SlicePlot(ds, "z",physical_quantity)
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
# Out:
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:645: RuntimeWarning: divide by zero encountered in double_scalars
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:645: RuntimeWarning: invalid value encountered in multiply
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:701: RuntimeWarning: invalid value encountered in less
#   short = np.repeat(length < minsh, 8, axis=1)
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:711: RuntimeWarning: invalid value encountered in less
#   tooshort = length < self.minlength
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# Forgot to set the distance as x - xctr ..etc

# %%
i =0 
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()

i =0 
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
i =0 

ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="temperature"
slc = yt.SlicePlot(ds, "z",physical_quantity)
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
i =0 
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()

i =0 
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()
i =0 

ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="temperature"
slc = yt.SlicePlot(ds, "z",physical_quantity)
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()

# %%
ds = yt.load("uniform_sphere_unigrid/uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"

slc = yt.SlicePlot(ds,'z', physical_quantity,center=(0.5,0.5,0.5))

#slc = yt.SlicePlot(ds, "z",physical_quantity)
slc.set_figure_size(5)
slc.annotate_velocity()
# slc.annotate_grids()
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [raw]
#  zCoord,yCoord,xCenter:  3.125000000000000E-002  0.218750000000000
#   0.906250000000000
#  (i,j,k):          12           8           5
#  (xx,yy,zz):  0.468750000000000      -0.281250000000000
#  -0.468750000000000
#  zCoord,yCoord,xCenter:  3.125000000000000E-002  0.218750000000000
#   0.968750000000000
#  (i,j,k):           5           9           5
#  (xx,yy,zz):  3.125000000000000E-002 -0.218750000000000
#  -0.468750000000000
#  zCoord,yCoord,xCenter:  3.125000000000000E-002  0.281250000000000
#   0.531250000000000
#  (i,j,k):           6           9           5
#  (xx,yy,zz):  9.375000000000000E-002 -0.218750000000000
#  -0.468750000000000
#  zCoord,yCoord,xCenter:  3.125000000000000E-002  0.281250000000000
#   0.593750000000000
#  (i,j,k):           7           9           5
#  (xx,yy,zz):  0.156250000000000      -0.218750000000000

# %%
i =0
ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"

slc = yt.SlicePlot(ds, "z",physical_quantity)
slc.set_log('density', False)
slc.set_figure_size(5)
slc.set_zlim(physical_quantity, zmin,zmax)
slc.annotate_velocity()
slc.annotate_grids()
slc.show()

# ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
# physical_quantity="pressure"
# slc = yt.SlicePlot(ds, "z",physical_quantity)
# slc.set_figure_size(5)
# slc.annotate_velocity()
# slc.annotate_grids()
# slc.show()

# ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
# physical_quantity="temperature"
# slc = yt.SlicePlot(ds, "z",physical_quantity)
# slc.set_figure_size(5)
# slc.annotate_velocity()
# slc.annotate_grids()
# slc.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-ec5b2c40b37a> in <module>()
#       6 slc.set_log('density', False)
#       7 slc.set_figure_size(5)
# ----> 8 slc.set_zlim(physical_quantity, zmin,zmax)
#       9 slc.annotate_velocity()
#      10 slc.annotate_grids()
#
# NameError: name 'zmin' is not defined
