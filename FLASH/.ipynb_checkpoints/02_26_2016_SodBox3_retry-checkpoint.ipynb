# %%
import yt
yt.mylog.setLevel(50)
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ~/project/FLASH4.3/object/
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3/object

# %% [raw]
# Basic check uniform case
#
# sim_rhoLeft     = 1.
# sim_rhoRight    = 0.125
# sim_pLeft               = 1.
# sim_pRight              = 0.1
# sim_uLeft               = 0.
# sim_uRight              = 0.
#
# gamma = 1.4

# %%
i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,1)
slc.show()


i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,1)
slc.show()

i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="temperature"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,5e-8,5e-9)
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [raw]
# Now changed to this :
#
#     sim_rhoLeft     = 2.386E6  #1.
#     sim_rhoRight    = 23861.3108 #0.125
#     sim_pLeft               = 1.
#     sim_pRight              = 59.6525  #0.1
#     sim_uLeft               = 0.
#     sim_uRight              = 0.

# %% [markdown]
# remember redo setup and compile everytime

# %%
i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,1)
slc.show()


i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,1)
slc.show()

i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="temperature"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,5e-8,5e-9)
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# maybe the simulation_init overrides the values in the flash.par file?

# %% [raw]
# "A text file that specifies values for the runtime parameters. The
# values in flash.par override the defaults from Config files"

# %% [markdown]
# so that's not true...

# %% [markdown]
# Kept with the same things but added the if statemetn for the sphere

# %%
i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,1)
slc.show()


i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,1)
slc.show()

i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="temperature"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,5e-8,5e-9)
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# Still dont see anything

# %%
i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.ProjectionPlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,1)
slc.show()


i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="pressure"
slc = yt.ProjectionPlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,1)
slc.show()

i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="temperature"
slc = yt.ProjectionPlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,5e-8,5e-9)
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# So it looks like its completely uniform which is werid because there's definitely cells that fall into "inside" and "outside" if we look inside
# "vim 194236.out"

# %% [markdown]
# Now putting in actual values for these in numerical form

# %%
i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,1)
slc.show()


i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,1)
slc.show()

i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="temperature"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,5e-8,5e-9)
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# Don't see anything at all '

# %%
i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,1)
slc.show()


i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,1)
slc.show()

i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="temperature"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,5e-8,5e-9)
slc.show()
# Out:
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:645: RuntimeWarning: divide by zero encountered in double_scalars
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:645: RuntimeWarning: invalid value encountered in multiply
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:701: RuntimeWarning: invalid value encountered in less
#   short = np.repeat(length < minsh, 8, axis=1)
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:711: RuntimeWarning: invalid value encountered in less
#   tooshort = length < self.minlength
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# This is actually really bad, the reason why there was no change as at all was becayse yt had a "memory" of what the grid looks like

# %%
i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,1)
slc.show()


i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,1)
slc.show()

i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="temperature"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,5e-8,5e-9)
slc.show()
# Out:
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:645: RuntimeWarning: divide by zero encountered in double_scalars
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:645: RuntimeWarning: invalid value encountered in multiply
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:701: RuntimeWarning: invalid value encountered in less
#   short = np.repeat(length < minsh, 8, axis=1)
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:711: RuntimeWarning: invalid value encountered in less
#   tooshort = length < self.minlength
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
i = 1
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,1)
slc.show()


i = 1
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,1)
slc.show()

i = 1
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="temperature"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,5e-8,5e-9)
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# so right now the density are all "inside" values, but the grid resolution is way too low even though I'm doing unigrid level 6 which does make sense since that used to correspond to 2^6 cells on each side!

# %% [markdown]
# Changed gamma from 1.4 to 1.001 to see if it affects anything

# %%
i = 1
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,1)
slc.show()


i = 1
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,1)
slc.show()

i = 1
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="temperature"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,5e-8,5e-9)
slc.show()
# Out:
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:645: RuntimeWarning: divide by zero encountered in double_scalars
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:645: RuntimeWarning: invalid value encountered in multiply
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:701: RuntimeWarning: invalid value encountered in less
#   short = np.repeat(length < minsh, 8, axis=1)
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:711: RuntimeWarning: invalid value encountered in less
#   tooshort = length < self.minlength
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# That's a misktake that might be why it was messed up '

# %% [raw]
# lrefine_max     = 6
# lrefine_max     = 6

# %%
i = 1
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,1.5)
slc.show()


i = 1
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,1)
slc.show()

i = 1
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="temperature"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,5e-8,5e-9)
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [raw]
# Check to see if the numbers are registering by
#
#    if (rr <= 0.25) then
#            !    print *,"Inside"
#                rhoZone =0.125 !sim_rhoRight
#            else
#            !    print *,"Outisde"
#                rhoZone =0.5!1.  !sim_rhoLeft
#            endif

# %%
i = 1
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,1.5)
slc.show()


i = 1
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,1)
slc.show()

i = 1
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="temperature"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,5e-8,5e-9)
slc.show()
# Out:
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:645: RuntimeWarning: divide by zero encountered in double_scalars
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:645: RuntimeWarning: invalid value encountered in multiply
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:701: RuntimeWarning: invalid value encountered in less
#   short = np.repeat(length < minsh, 8, axis=1)
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:711: RuntimeWarning: invalid value encountered in less
#   tooshort = length < self.minlength
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# Okay so the density did change

# %%
i = 1
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.ProjPlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,1.5)
slc.show()


i = 1
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="pressure"
slc = yt.ProjPlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,1)
slc.show()

i = 1
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="temperature"
slc = yt.ProjPlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,5e-8,5e-9)
slc.show()
