# %%
# %pylab inline
from matplotlib.colors import LogNorm
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Last timestep is 348

# %% [raw]
# lrefine_max                 =          7 [CHANGED]
# lrefine_min                 =          5 [CHANGED]'
#
# sink_accretion_radius       =                 0.195E+18 [CHANGED]
# sink_density_thresh         =                 0.255E-18 [CHANGED]
# sink_dt_factor              =                 0.500E+00
# sink_softening_radius       =                 0.195E+18 [CHANGED]
# cfl                         =                 0.300E+00 [CHANGED]
# sink_merging                =  T [CHANGED]
# usesinkparticles            =  T [CHANGED]

# %% [markdown]
# restart at 320 with higher res AMR

# %%
lrefine_max                 =          9 [CHANGED]
lrefine_min                 =          7 [CHANGED]
------------------------------------------------

sink_accretion_radius       =                 0.195E+18 [CHANGED]
sink_density_thresh         =                 0.255E-18 [CHANGED]
sink_dt_factor              =                 0.500E+00
sink_softening_radius       =                 0.195E+18 [CHANGED]
cfl                         =                 0.300E+00 [CHANGED]
sink_merging                =  T [CHANGED]
usesinkparticles            =  T [CHANGED]

# %%
def compute_sink_param(lev_max=9):
    # Simple script for calculating sink parameters 
    rho = 1.0e-16
    G = 6.67e-8
    c_s  = 28730.5 #cm/s (based on T = 10K) 
    jeans_length = sqrt(pi*c_s**2/(G*rho))
    boxlen =1e19
    cell_size = boxlen / 8.0 / 2**(lev_max)
    #cell_size = boxlen/(2**(lev_max+2))
    #rho_threshold = pi*c_s**2/(4*G*jeans_length**2)
    r_acc = 2.5*cell_size
    rho_threshold=  pi*c_s**2/(16.0*G*cell_size**2)

    print "sink_density_thresh = ", rho_threshold
    print "sink_accretion_radius = ", r_acc
    print "sink_softening_radius = ", r_acc

# %%
compute_sink_param(7)
# Out:
# sink_density_thresh =  2.54794669312e-17
# sink_accretion_radius =  2.44140625e+16
# sink_softening_radius =  2.44140625e+16

# %%
from IPython.display import Image
from IPython.display import display

# %% [markdown]
# ## Originally

# %%
init = Image(filename='sod_hdf5_chk_0310_density.png',width=400) 
x = Image(filename='sod_hdf5_chk_0320_density.png',width=400) 
y = Image(filename='sod_hdf5_chk_0330_density.png',width=400) 
yy = Image(filename='sod_hdf5_chk_0340_density.png',width=400) 
z = Image(filename='sod_hdf5_chk_0350_density.png',width=400) 
display(init,x, y,yy,z)

# %% [raw]
# vim 1143643.out

# %% [raw]
# get error:
#     WARNING after gc filling: min. unk(DENS_VAR)=0.000000000000000000000

# %% [raw]
# WARNING after gc filling: min. unk(DENS_VAR)=0.000000000000000000000          PE=326   block=1                                type=1
#  16  0.52E-20 0.52E-20 0.52E-20 0.52E-20 0.51E-20 0.51E-20 0.51E-20 0.51E-20 0.51E-20 0.51E-20 0.51E-20 0.51E-20 0.52E-20 0.52E-20 0.52E-20 0.52E-20
#  15  0.51E-20 0.52E-20 0.52E-20 0.52E-20 0.51E-20 0.51E-20 0.51E-20 0.51E-20 0.51E-20 0.51E-20 0.51E-20 0.51E-20 0.52E-20 0.52E-20 0.52E-20 0.52E-20
#  14  0.51E-20 0.52E-20 0.52E-20 0.52E-20 0.51E-20 0.51E-20 0.51E-20 0.51E-20 0.51E-20 0.51E-20 0.51E-20 0.51E-20 0.52E-20 0.52E-20 0.52E-20 0.52E-20

# %% [markdown]
# ## Changed back to lev 5 to 7

# %% [raw]
# vim 1143723.out

# %% [raw]
# lrefine_max                 =          7
# lrefine_min                 =          5

# %% [markdown]
# ## Changed back to lev 6 to 8

# %% [raw]
# vim 1150856.out

# %% [raw]
# still crashed on
#
# WARNING after gc filling: min. unk(DENS_VAR)=0.000000000000000000000          PE=326   block=1                                type=1
#  16  0.52E-20 0.52E-20 0.52E-20 0.52E-20 0.51E-20 0.51E-20 0.51E-20 0.51E-20 0.51E-20 0.51E-20 0.51E-20 0.51E-20 0.52E-20 0.52E-20 0.52E-20 0.52E-20
#  15  0.51E-20 0.52E-20 0.52E-20 0.52E-20 0.51E-20 0.51E-20 0.51E-20 0.51E-20 0.51E-20 0.51E-20 0.51E-20 0.51E-20 0.52E-20 0.52E-20 0.52E-20 0.52E-20
#  14  0.51E-20 0.52E-20 0.52E-20 0.52E-20 0.51E-20 0.51E-20 0.51E-20 0.51E-20 0.51E-20 0.51E-20 0.51E-20 0.51E-20 0.52E-20 0.52E-20 0.52E-20 0.52E-20

# %% [markdown]
# ## Changed back to lev 5 to 8

# %% [raw]
# vim 1151530.out

# %% [markdown]
# If we keep the base grid as 5,

# %% [raw]
#  *** Wrote checkpoint file to sod_hdf5_chk_0311 ****
#  Particles_sinkAdvanceParticles: #subcycles:           1
#  Starting to merge sink particles on MasterPE. Localnpf =            1
#  done merging sink particles. merging happened= F
#  Particles_sinkAdvanceParticles: #subcycles:           1
#  Starting to merge sink particles on MasterPE. Localnpf =            1
#  done merging sink particles. merging happened= F
#   iteration, no. not moved =            0        5404
#   iteration, no. not moved =            1        1884
#   iteration, no. not moved =            2           0
#  refined: total leaf blocks =         8184
#  refined: total blocks =         9353
#      416 3.6667E+12 1.4175E+09  ( 4.985E+18,  4.976E+18,  4.946E+18) |  1.417E+09 4.115E+13
#
#
#
#  Nonconvergence in subroutine rieman
#
#
#  Zone index       =           11
#  Nonconvergence in subroutine rieman
#
#  Zone index       =           10
#  Zone center      =   5.063476562500000E+018
#  Zone center      =   4.897460937500000E+018
#  Iterations tried =           12
#  Iterations tried =           12
#  Pressure error   =   0.102786968734731
#  Pressure error   =   0.184472293204394
#  rieman_tol       =   1.000000000000000E-005
#  rieman_tol       =   1.000000000000000E-005

# %% [markdown]
# ### Try changing the sink parameters to correspond to lev max 8

# %%
compute_sink_param(8)
# Out:
# sink_density_thresh =  1.6306858836e-17
# sink_accretion_radius =  2.44140625e+16
# sink_softening_radius =  2.44140625e+16
