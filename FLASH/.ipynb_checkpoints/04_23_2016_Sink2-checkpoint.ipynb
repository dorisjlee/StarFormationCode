# %%
import yt 
yt.mylog.setLevel(50)
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [raw]
# /setup unitTest/SinkMomTest  -3d --maxblock=3000 -auto ; cd object/;make -j;cd ..;qsub srun2.pbs

# %%
cd ~/project/FLASH4.3_3/object/
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3_3/object

# %% [markdown]
# # SinkMomTest

# %% [markdown]
# To get the sink particle activated, we need a density rise, which we previously didn't get. But now if we use a huge fattening factor, we should get a couple orders of magnitude of density rise really quick

# %% [raw]
# vim 366416.out

# %%
import yt
from yt.mods import *
yt.funcs.mylog.setLevel(50) #coerce output null
def plot_dens(i,velocity=False):
    ds = yt.load("SMT_hdf5_chk_{}".format(str(i).zfill(4)))
    physical_quantity="density"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_figure_size(5)
#     slc.annotate_grids()
    if velocity: slc.annotate_velocity()
    slc.set_cmap("all","rainbow")
#     slc.set_zlim(physical_quantity, 5.0e-20,1.0e-16)
    slc.show()

# %%
for i in np.arange(10):
    plot_dens(i)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# If we look into utils we find some python script that reads SMT.dat which seems to contain numerical information about some physical variables. And some IDL script that reads the part files
# There's also :
#
# sink_ewald.txt: contain dx,dy,dz, and force correction in all directions (not too sure what this is ... )
#
# sinks_evol.dat : contain x,v,a kinematic information and accretion rate for each pcl

# %%
ds = yt.load("SMT_hdf5_chk_{}".format(str(i).zfill(4)))
dd = ds.all_data()
print dd["particle_position_x"]
print dd["particle_position_y"]
print dd["particle_position_z"]
# Out:
# [ -2.97649795e+16   6.45817720e+16] code_length
# [  1.99679826e+16   1.53885190e+16] code_length
# [  4.26540749e+14   5.56089046e+14] code_length

# %% [markdown]
# so this is good they have this information inside the chk files. But slc.annotate_particles() still doesn't work (no particleCallback)

# %% [markdown]
# yt says "but particle files are not currently directly loadable by themselves, due to the fact that they typically lack grid information. "

# %% [markdown]
# # ----------------------------------------------------------------------------------

# %% [raw]
# There doesn't seem to be anything related to sinks inside Simulation_initBlock.F90.
#
# In simulation_init , I needed to add in
#
# use Particles_sinkData
# use pt_sinkInterface, only: pt_sinkCreateParticle, pt_sinkGatherGlobal
#
# There's some (hopefully optional things) inside flash.par that I didn't put in:
#
# sink_softening_type_gas   = "linear"
# sink_softening_type_sinks = "spline"
# sink_integrator           = "leapfrog"
# sink_subdt_factor         = 0.01
# sink_dt_factor            = 0.5
# sink_merging              = .false.
# sink_convergingFlowCheck  = .true.
# sink_potentialMinCheck    = .true.
# sink_jeansCheck           = .true.
# sink_negativeEtotCheck    = .true.
# sink_GasAccretionChecks   = .true.
# pt_maxPerProc             = 500
#
# refineOnSinkParticles = .true.

# %% [markdown]
# TODO: Now try to analyze the particle data, once I figured that out I could look at the COnfig and flash.par and compared to my sink test to see what I'm doing wrong '

# %% [markdown]
# after fixing this, it runs!

# %% [markdown]
# we do get a sink_evol.dat, but not a sink_ewald.txt . Its okay I dont really know what that is anyways..

# %%
import yt
from yt.mods import *
yt.funcs.mylog.setLevel(50) #coerce output null
def plot_dens(i,velocity=False):
    ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
    physical_quantity="density"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_figure_size(5)
#     slc.annotate_grids()
    if velocity: slc.annotate_velocity()
    slc.set_cmap("all","rainbow")
#     slc.set_zlim(physical_quantity, 5.0e-20,1.0e-16)
    slc.show()

# %%
for i in np.arange(10):
    plot_dens(i)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [raw]
# > python source/Simulation/SimulationMain/unitTest/SinkMomTest/utils/clean_sinks_evol.py
# ************ Python Script started ************
# Start time:    2016-04-25  13:54.50
# cp sinks_evol.dat sinks_evol.dat_sav
# columns in table : 17
# lines in table   : 58
# 'sinks_evol.dat_cleaned' written. 58 lines.
# ************ Python Pipeline finished ************
# Start time:    2016-04-25  13:54.50
# Endtime time:  2016-04-25  13:54.50
# Operation time in seconds: 0.0  seconds
# Operation time in hours  : 0.0  hours
# ************ Python Script finished ************
#
# > diff3 sinks_evol.dat          sinks_evol.dat_cleaned sinks_evol.dat_sav
#
#
# Okay the python script is kind of useless, it didn't do anything even though it spitted out the "cleaned files'

# %% [markdown]
# So I need to analyze sinks_evol.dat on my own, thankfully this is not in HDF5

# %%
data =np.loadtxt("sinks_evol.dat",skiprows=1)

# %%
! sed -n '1{p;q}' sinks_evol.dat
# Out:
#      [00]part_tag         [01]time         [02]posx         [03]posy         [04]posz         [05]velx         [06]vely         [07]velz       [08]accelx       [09]accely       [10]accelz        [11]anglx        [12]angly        [13]anglz         [14]mass         [15]mdot        [16]ptime

# %%
t = data[:,1]
mdot = data[:,15]
plt.semilogy(t,mdot)

# %% [markdown]
# I looked at thee MRPlots and decided that it would be better to use the fattening_factor = 100 run so I reran this but it crashed at segfault and warn:
#
#  pt_sinkAccelSinksOnSinks: grav softening type = spline
#  Particles_sinkAdvanceParticles: #subcycles:           1
# SinkParticles: You have set the sink particle accretion radius to   2.50 * (1+redshift) cells at the highest level of refinement.
#
# The only thing that I changed was the fattening factor and the plot output times by a factor of 10 (that should not affect it)
#
# ---> possibly because this density difference changes what we should be putting down as acccretion radius or accretion threshold density
#
# Now changing it back to factor   = 1000 again it works . So i simply increased the timestepping here to see if I could get to the time of core formation

# %%
for i in np.arange(14):
    plot_dens(i)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# ## Understanding Sink parameters

# %% [markdown]
# - When I change the density enhancement inside flash.par for the same problem, the code crashes (segfaults): (See 371146.out)
#
#
#     pt_sinkAccelSinksOnSinks: grav softening type = spline Particles_sinkAdvanceParticles: #subcycles: 1 SinkParticles: You have set the sink particle accretion radius to 2.50 * (1+redshift) cells at the highest level of refinement.

# %%
FAT_FACTOR = 1000
ds = yt.load("../../FLASH4.3_2/object/fat{}/sod_hdf5_chk_0000".format(FAT_FACTOR))
dim = 256
all_data = ds.covering_grid(level=5, left_edge=[0,0.0,0.0],dims=[dim,dim,dim])
rho  = np.max(np.array(all_data["density"]))
print "central density is : ", rho
# Out:
# central density is :  1.0145485398e-16

# %%
# Simple script for calculating sink parameters 
rho = 1.0e-16
G = 6.67e-8
c_s  = 28730.5 #cm/s (based on T = 10K) 
jeans_length = sqrt(pi*c_s**2/(G*rho))
boxlen =1e19
lev_max = 5
cell_size = boxlen/(2**(lev_max+2))
rho_threshold = pi*c_s**2/(4*G*jeans_length**2)
r_acc = 2.5*cell_size
rho_threshold=  pi*c_s**2/(4*G*r_acc**2)
print "sink_density_thresh = ", rho_threshold
print "sink_accretion_radius = ", r_acc
print "sink_softening_radius = ", r_acc
# Out:
# sink_density_thresh =  2.54794669312e-19
# sink_accretion_radius =  1.953125e+17
# sink_softening_radius =  1.953125e+17

# %% [markdown]
# so what if  I want to look at the FACTOR = 100 sphere

# %%
FAT_FACTOR = 100
ds = yt.load("../../FLASH4.3_2/object/fat{}/sod_hdf5_chk_0000".format(FAT_FACTOR))
dim = 256
all_data = ds.covering_grid(level=5, left_edge=[0,0.0,0.0],dims=[dim,dim,dim])
rho  = np.max(np.array(all_data["density"]))
print "central density is : ", rho

G = 6.67e-8
c_s  = 28730.5 #cm/s (based on T = 10K) 
jeans_length = sqrt(pi*c_s**2/(G*rho))
boxlen =1e19
lev_max = 5
cell_size = boxlen/(2**(lev_max+2))
rho_threshold = pi*c_s**2/(4*G*jeans_length**2)
r_acc = 2.5*cell_size
rho_threshold=  pi*c_s**2/(4*G*r_acc**2)
print "sink_density_thresh = ", rho_threshold
print "sink_accretion_radius = ", r_acc
print "sink_softening_radius = ", r_acc
# Out:
# central density is :  1.0145485398e-17
# sink_density_thresh =  2.54794669312e-19
# sink_accretion_radius =  1.953125e+17
# sink_softening_radius =  1.953125e+17

# %%
for i in np.arange(18):
    plot_dens(i)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
pwd
# Out:
# u'/global/project/projectdirs/astro250/doris/FLASH4.3_3/object'

# %%
data =np.loadtxt("sinks_evol.dat",skiprows=1)
t = data[:,1]
mdot = data[:,15]
plt.semilogy(t,mdot)

# %% [markdown]
# This is good, this confirms that the code is crashing because of the wrong density threshold being set. Once we recalculate the right density threshold the code runs sucessfully until Rieman Noncovergence

# %% [markdown]
# slc.annotate_particles((1,'pcs')) still doesn't work, but I'm curious to know what actually happens to the cell that contains the sink. from this picture it looks like the density is something different. This is different from previous runs without sink where center is just central density

# %% [markdown]
# ## Sink Questions :
#
# -  Right now we place one sink particle by putting this inside Simulation_init.f90. How to put in the sink after t= 0 at some arbitrary specified time during the simulation (not triggered by density threshold)?
#
# - Is the information inside sinks_evol.dat same as what's inside the *_part_hdf5* files?
# - Inside sinks_evol.dat,
#     - how is it possible to have one sink particle in the beginning, but that particle only show up in the initial timestep, disappears at later times (merging?)
#     - what is ptime?
#
# - What actually happens to the cell that contains the sink? When we plot a SlicePlot density, we see that the density at the cell location of the sink is not the density that its supposed to be.
#
# - How is mdot computed? Mass flow into anything beyond r<r_accretion?
