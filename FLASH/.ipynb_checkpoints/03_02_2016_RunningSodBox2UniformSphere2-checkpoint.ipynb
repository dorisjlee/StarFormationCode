# %%
import yt
# yt.mylog.setLevel(50)
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ~/project/FLASH4.3/object/
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3/object

# %%
i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
# slc.set_log("all", False)
# slc.set_zlim(physical_quantity,0,1)
slc.show()

ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
#59.6525
slc.set_zlim(physical_quantity,58,60)
slc.show()

ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="temperature"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
# slc.set_log("all", False)
# slc.set_zlim(physical_quantity,5e-8,5e-9)
slc.show()
# sim_rhoLeft    = 2.386E6 #1.
# sim_rhoRight   = 23861.3108 #0.125
# Out:
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:645: RuntimeWarning: divide by zero encountered in double_scalars
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:645: RuntimeWarning: invalid value encountered in multiply
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:701: RuntimeWarning: invalid value encountered in less
#   short = np.repeat(length < minsh, 8, axis=1)
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:711: RuntimeWarning: invalid value encountered in less
#   tooshort = length < self.minlength
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
i = 1
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
# slc.set_log("all", False)
# slc.set_zlim(physical_quantity,0,1)
slc.show()

ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
#59.6525
slc.set_zlim(physical_quantity,58,60)
slc.show()

ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="temperature"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
# slc.set_log("all", False)
# slc.set_zlim(physical_quantity,5e-8,5e-9)
slc.show()
# sim_rhoLeft    = 2.386E6 #1.
# sim_rhoRight   = 23861.3108 #0.125
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# sqrt(3*pi/(32*G*2.38e6 g/cm^3)) = 1.362 seconds

# %%
i = 1
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
# slc.set_log("all", False)
# slc.set_zlim(physical_quantity,0,1)
slc.show()

ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
#59.6525
slc.set_zlim(physical_quantity,58,60)
slc.show()

ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="temperature"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
# slc.set_log("all", False)
# slc.set_zlim(physical_quantity,5e-8,5e-9)
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
cd sod_data2/
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3/object/sod_data2

# %%
i = 5
ds = yt.load("sod_hdf5_plt_cnt_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
# slc.annotate_velocity()
# slc.annotate_grids()
# slc.set_log("all", False)
# slc.set_zlim(physical_quantity,0,1)
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
i = 9
ds = yt.load("sod_hdf5_plt_cnt_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.zoom(2)
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
i = 11
ds = yt.load("sod_hdf5_plt_cnt_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.zoom(2)
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
i = 12
ds = yt.load("sod_hdf5_plt_cnt_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.zoom(2)
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
cd ..
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3/object

# %% [markdown]
# More fine grained timesteps

# %%
i = 9
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
# slc.zoom(2)
slc.show()
# Out:
# yt : [INFO     ] 2016-03-03 01:36:12,196 integer runtime parameter checkpointfilenumber overwrites a simulation scalar of the same name
# yt : [INFO     ] 2016-03-03 01:36:12,197 integer runtime parameter plotfilenumber overwrites a simulation scalar of the same name
# yt : [INFO     ] 2016-03-03 01:36:12,209 Parameters: current_time              = 0.909009115553
# yt : [INFO     ] 2016-03-03 01:36:12,209 Parameters: domain_dimensions         = [8 8 8]
# yt : [INFO     ] 2016-03-03 01:36:12,210 Parameters: domain_left_edge          = [ 0.  0.  0.]
# yt : [INFO     ] 2016-03-03 01:36:12,211 Parameters: domain_right_edge         = [ 1.  1.  1.]
# yt : [INFO     ] 2016-03-03 01:36:12,212 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2016-03-03 01:36:17,108 Loading field plugins.
# yt : [INFO     ] 2016-03-03 01:36:17,109 Loaded angular_momentum (8 new fields)
# yt : [INFO     ] 2016-03-03 01:36:17,110 Loaded astro (15 new fields)
# yt : [INFO     ] 2016-03-03 01:36:17,111 Loaded cosmology (22 new fields)
# yt : [INFO     ] 2016-03-03 01:36:17,113 Loaded fluid (62 new fields)
# yt : [INFO     ] 2016-03-03 01:36:17,114 Loaded fluid_vector (94 new fields)
# yt : [INFO     ] 2016-03-03 01:36:17,115 Loaded geometric (110 new fields)
# yt : [INFO     ] 2016-03-03 01:36:17,116 Loaded local (110 new fields)
# yt : [INFO     ] 2016-03-03 01:36:17,117 Loaded magnetic_field (118 new fields)
# yt : [INFO     ] 2016-03-03 01:36:17,118 Loaded my_plugins (118 new fields)
# yt : [INFO     ] 2016-03-03 01:36:17,119 Loaded species (120 new fields)
# yt : [INFO     ] 2016-03-03 01:36:20,325 xlim = 0.000000 1.000000
# yt : [INFO     ] 2016-03-03 01:36:20,326 ylim = 0.000000 1.000000
# yt : [INFO     ] 2016-03-03 01:36:20,329 xlim = 0.000000 1.000000
# yt : [INFO     ] 2016-03-03 01:36:20,329 ylim = 0.000000 1.000000
# yt : [INFO     ] 2016-03-03 01:36:20,331 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
i = 10
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
# slc.zoom(2)
slc.show()
# Out:
# yt : [INFO     ] 2016-03-03 01:35:40,964 integer runtime parameter checkpointfilenumber overwrites a simulation scalar of the same name
# yt : [INFO     ] 2016-03-03 01:35:40,965 integer runtime parameter plotfilenumber overwrites a simulation scalar of the same name
# yt : [INFO     ] 2016-03-03 01:35:40,988 Parameters: current_time              = 1.01611428519
# yt : [INFO     ] 2016-03-03 01:35:40,989 Parameters: domain_dimensions         = [8 8 8]
# yt : [INFO     ] 2016-03-03 01:35:40,990 Parameters: domain_left_edge          = [ 0.  0.  0.]
# yt : [INFO     ] 2016-03-03 01:35:40,991 Parameters: domain_right_edge         = [ 1.  1.  1.]
# yt : [INFO     ] 2016-03-03 01:35:40,991 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2016-03-03 01:35:45,392 Loading field plugins.
# yt : [INFO     ] 2016-03-03 01:35:45,394 Loaded angular_momentum (8 new fields)
# yt : [INFO     ] 2016-03-03 01:35:45,395 Loaded astro (15 new fields)
# yt : [INFO     ] 2016-03-03 01:35:45,396 Loaded cosmology (22 new fields)
# yt : [INFO     ] 2016-03-03 01:35:45,397 Loaded fluid (62 new fields)
# yt : [INFO     ] 2016-03-03 01:35:45,399 Loaded fluid_vector (94 new fields)
# yt : [INFO     ] 2016-03-03 01:35:45,400 Loaded geometric (110 new fields)
# yt : [INFO     ] 2016-03-03 01:35:45,401 Loaded local (110 new fields)
# yt : [INFO     ] 2016-03-03 01:35:45,402 Loaded magnetic_field (118 new fields)
# yt : [INFO     ] 2016-03-03 01:35:45,403 Loaded my_plugins (118 new fields)
# yt : [INFO     ] 2016-03-03 01:35:45,404 Loaded species (120 new fields)
# yt : [INFO     ] 2016-03-03 01:35:47,698 xlim = 0.000000 1.000000
# yt : [INFO     ] 2016-03-03 01:35:47,699 ylim = 0.000000 1.000000
# yt : [INFO     ] 2016-03-03 01:35:47,702 xlim = 0.000000 1.000000
# yt : [INFO     ] 2016-03-03 01:35:47,702 ylim = 0.000000 1.000000
# yt : [INFO     ] 2016-03-03 01:35:47,703 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
i = 12
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.zoom(2)
slc.show()
# Out:
# yt : [INFO     ] 2016-03-03 01:35:49,506 integer runtime parameter checkpointfilenumber overwrites a simulation scalar of the same name
# yt : [INFO     ] 2016-03-03 01:35:49,508 integer runtime parameter plotfilenumber overwrites a simulation scalar of the same name
# yt : [INFO     ] 2016-03-03 01:35:49,518 Parameters: current_time              = 1.20716613502
# yt : [INFO     ] 2016-03-03 01:35:49,519 Parameters: domain_dimensions         = [8 8 8]
# yt : [INFO     ] 2016-03-03 01:35:49,520 Parameters: domain_left_edge          = [ 0.  0.  0.]
# yt : [INFO     ] 2016-03-03 01:35:49,520 Parameters: domain_right_edge         = [ 1.  1.  1.]
# yt : [INFO     ] 2016-03-03 01:35:49,521 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2016-03-03 01:35:54,163 Loading field plugins.
# yt : [INFO     ] 2016-03-03 01:35:54,165 Loaded angular_momentum (8 new fields)
# yt : [INFO     ] 2016-03-03 01:35:54,166 Loaded astro (15 new fields)
# yt : [INFO     ] 2016-03-03 01:35:54,167 Loaded cosmology (22 new fields)
# yt : [INFO     ] 2016-03-03 01:35:54,168 Loaded fluid (62 new fields)
# yt : [INFO     ] 2016-03-03 01:35:54,169 Loaded fluid_vector (94 new fields)
# yt : [INFO     ] 2016-03-03 01:35:54,170 Loaded geometric (110 new fields)
# yt : [INFO     ] 2016-03-03 01:35:54,171 Loaded local (110 new fields)
# yt : [INFO     ] 2016-03-03 01:35:54,172 Loaded magnetic_field (118 new fields)
# yt : [INFO     ] 2016-03-03 01:35:54,173 Loaded my_plugins (118 new fields)
# yt : [INFO     ] 2016-03-03 01:35:54,174 Loaded species (120 new fields)
# yt : [INFO     ] 2016-03-03 01:35:56,479 xlim = 0.000000 1.000000
# yt : [INFO     ] 2016-03-03 01:35:56,480 ylim = 0.000000 1.000000
# yt : [INFO     ] 2016-03-03 01:35:56,483 xlim = 0.000000 1.000000
# yt : [INFO     ] 2016-03-03 01:35:56,483 ylim = 0.000000 1.000000
# yt : [INFO     ] 2016-03-03 01:35:56,484 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [INFO     ] 2016-03-03 01:35:57,546 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
i = 23
ds = yt.load("sod_hdf5_plt_cnt_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
# slc.zoom(2)
slc.show()
# Out:
# yt : [INFO     ] 2016-03-03 01:40:47,715 integer runtime parameter checkpointfilenumber overwrites a simulation scalar of the same name
# yt : [INFO     ] 2016-03-03 01:40:47,716 integer runtime parameter plotfilenumber overwrites a simulation scalar of the same name
# yt : [INFO     ] 2016-03-03 01:40:47,728 Parameters: current_time              = 0.990846879508
# yt : [INFO     ] 2016-03-03 01:40:47,728 Parameters: domain_dimensions         = [8 8 8]
# yt : [INFO     ] 2016-03-03 01:40:47,729 Parameters: domain_left_edge          = [ 0.  0.  0.]
# yt : [INFO     ] 2016-03-03 01:40:47,730 Parameters: domain_right_edge         = [ 1.  1.  1.]
# yt : [INFO     ] 2016-03-03 01:40:47,730 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2016-03-03 01:40:52,745 Loading field plugins.
# yt : [INFO     ] 2016-03-03 01:40:52,747 Loaded angular_momentum (8 new fields)
# yt : [INFO     ] 2016-03-03 01:40:52,747 Loaded astro (15 new fields)
# yt : [INFO     ] 2016-03-03 01:40:52,748 Loaded cosmology (22 new fields)
# yt : [INFO     ] 2016-03-03 01:40:52,750 Loaded fluid (62 new fields)
# yt : [INFO     ] 2016-03-03 01:40:52,751 Loaded fluid_vector (94 new fields)
# yt : [INFO     ] 2016-03-03 01:40:52,752 Loaded geometric (110 new fields)
# yt : [INFO     ] 2016-03-03 01:40:52,753 Loaded local (110 new fields)
# yt : [INFO     ] 2016-03-03 01:40:52,755 Loaded magnetic_field (118 new fields)
# yt : [INFO     ] 2016-03-03 01:40:52,756 Loaded my_plugins (118 new fields)
# yt : [INFO     ] 2016-03-03 01:40:52,757 Loaded species (120 new fields)
# yt : [INFO     ] 2016-03-03 01:40:54,269 xlim = 0.000000 1.000000
# yt : [INFO     ] 2016-03-03 01:40:54,270 ylim = 0.000000 1.000000
# yt : [INFO     ] 2016-03-03 01:40:54,272 xlim = 0.000000 1.000000
# yt : [INFO     ] 2016-03-03 01:40:54,273 ylim = 0.000000 1.000000
# yt : [INFO     ] 2016-03-03 01:40:54,275 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
i = 24
ds = yt.load("sod_hdf5_plt_cnt_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
# slc.zoom(2)
slc.show()
# Out:
# yt : [INFO     ] 2016-03-03 01:40:38,034 integer runtime parameter checkpointfilenumber overwrites a simulation scalar of the same name
# yt : [INFO     ] 2016-03-03 01:40:38,036 integer runtime parameter plotfilenumber overwrites a simulation scalar of the same name
# yt : [INFO     ] 2016-03-03 01:40:38,046 Parameters: current_time              = 1.01611428519
# yt : [INFO     ] 2016-03-03 01:40:38,047 Parameters: domain_dimensions         = [8 8 8]
# yt : [INFO     ] 2016-03-03 01:40:38,048 Parameters: domain_left_edge          = [ 0.  0.  0.]
# yt : [INFO     ] 2016-03-03 01:40:38,048 Parameters: domain_right_edge         = [ 1.  1.  1.]
# yt : [INFO     ] 2016-03-03 01:40:38,049 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2016-03-03 01:40:44,500 Loading field plugins.
# yt : [INFO     ] 2016-03-03 01:40:44,502 Loaded angular_momentum (8 new fields)
# yt : [INFO     ] 2016-03-03 01:40:44,503 Loaded astro (15 new fields)
# yt : [INFO     ] 2016-03-03 01:40:44,503 Loaded cosmology (22 new fields)
# yt : [INFO     ] 2016-03-03 01:40:44,505 Loaded fluid (62 new fields)
# yt : [INFO     ] 2016-03-03 01:40:44,506 Loaded fluid_vector (94 new fields)
# yt : [INFO     ] 2016-03-03 01:40:44,507 Loaded geometric (110 new fields)
# yt : [INFO     ] 2016-03-03 01:40:44,508 Loaded local (110 new fields)
# yt : [INFO     ] 2016-03-03 01:40:44,510 Loaded magnetic_field (118 new fields)
# yt : [INFO     ] 2016-03-03 01:40:44,511 Loaded my_plugins (118 new fields)
# yt : [INFO     ] 2016-03-03 01:40:44,512 Loaded species (120 new fields)
# yt : [INFO     ] 2016-03-03 01:40:46,028 xlim = 0.000000 1.000000
# yt : [INFO     ] 2016-03-03 01:40:46,029 ylim = 0.000000 1.000000
# yt : [INFO     ] 2016-03-03 01:40:46,031 xlim = 0.000000 1.000000
# yt : [INFO     ] 2016-03-03 01:40:46,032 ylim = 0.000000 1.000000
# yt : [INFO     ] 2016-03-03 01:40:46,034 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
