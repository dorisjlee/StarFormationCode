# %%
# %pylab inline
from matplotlib.colors import LogNorm
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ~/project/FLASH4.3_3/object/
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3_3/object

# %%
yt.mylog.setLevel(50)

# %%
import yt
from yt.units import second, g, cm ,dyne
G = 6.674e-8*cm**3/second**2/g
ctr = 5e18*cm

# %%
def plot_var(i,physical_quantity,velocity=False,grid=False,zmin ="",zmax="",particle=False):
    ds = yt.load("mhd_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_figure_size(5)
    if grid: slc.annotate_grids()
    if velocity: slc.annotate_velocity()
    slc.set_cmap("all","rainbow")
    if zmin!="" and zmax!="": slc.set_zlim(physical_quantity,zmin,zmax)
    slc.show()

# %% [markdown]
# # With HLLC solver

# %%
cd ../mhd_nosink/
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3_3/mhd_nosink

# %%
plot_var(0,'magnetic_field_strength')
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_var(1,'magnetic_field_strength')
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# # With the HLLD solver instead

# %%
cd ../object/
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3_3/object

# %%
plot_var(0,'magnetic_field_strength')
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_var(1,'magnetic_field_strength')
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
END_TIME = 565
for t in np.arange(END_TIME):
    if t%20 ==0:
        plot_var(t,"magnetic_field_z")
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# YTOutputNotIdentifiedTraceback (most recent call last)
# <ipython-input-15-f381e5df1824> in <module>()
#       2 for t in np.arange(END_TIME):
#       3     if t%20 ==0:
# ----> 4         plot_var(t,"magnetic_field_z")
#
# <ipython-input-7-8174e07e9b9a> in plot_var(i, physical_quantity, velocity, grid, zmin, zmax, particle)
#       1 def plot_var(i,physical_quantity,velocity=False,grid=False,zmin ="",zmax="",particle=False):
# ----> 2     ds = yt.load("mhd_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
#       3     slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
#       4     slc.set_figure_size(5)
#       5     if grid: slc.annotate_grids()
#
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/yt/convenience.pyc in load(*args, **kwargs)
#      72         mylog.error("None of the arguments provided to load() is a valid file")
#      73         mylog.error("Please check that you have used a correct path")
# ---> 74         raise YTOutputNotIdentified(args, kwargs)
#      75     for n, c in output_type_registry.items():
#      76         if n is None: continue
#
# YTOutputNotIdentified: Supplied ('mhd_sphere_hdf5_chk_0080',) {}, but could not load!

# %%
i= 0 
ds = yt.load("mhd_sphere_hdf5_chk_{}".format(str(i).zfill(4)))

# %%
def _B_mag(field,data):
    return sqrt(data['magnetic_field_x']**2+data['magnetic_field_y']**2+data['magnetic_field_z']**2)
yt.add_field("B_mag",function= _B_mag,units="g**0.5/(cm**0.5*s)")

# %%
plot_var(1,"B_mag")
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
cd ../object/
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3_3/object

# %%
def plot_var(i,physical_quantity,velocity=False,grid=False,zmin ="",zmax="",particle=False):
    ds = yt.load("torus_mhd_2d_hdf5_chk_{}".format(str(i).zfill(4)))
    #slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc = yt.ProjectionPlot(ds,physical_quantity)
    slc.set_figure_size(5)
    if grid: slc.annotate_grids()
    if velocity: slc.annotate_velocity()
    slc.set_cmap("all","rainbow")
    if zmin!="" and zmax!="": slc.set_zlim(physical_quantity,zmin,zmax)
    slc.show()

# %% [markdown]
# # MHD_Torus

# %%
cd ../torus/
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3_3/torus

# %%
ds.domain_left_edge
# Out:
# YTArray([ 1.5, -7. ,  0. ]) code_length

# %%
i=1
ds = yt.load("torus_mhd_2d_hdf5_chk_{}".format(str(i).zfill(4)))

# %%
ds.all_data()["density"]
# Out:
# YTArray([ 0.00066335,  0.00066335,  0.00066335, ...,  0.00057972,
#         0.00057972,  0.00057972]) g/cm**3

# %%
data["magnetic_field_strength"]
# Out:
# YTArray([ 0.,  0.,  0., ...,  0.,  0.,  0.]) gauss

# %%
plt.imshow(data["magnetic_field_strength"])
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-48-43c154a4ff20> in <module>()
# ----> 1 plt.imshow(data["magnetic_field_strength"])
#
# /anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3020                         filternorm=filternorm, filterrad=filterrad,
#    3021                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3022                         **kwargs)
#    3023     finally:
#    3024         ax.hold(washold)
#
# /anaconda2/lib/python2.7/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
#    1811                                   RuntimeWarning, stacklevel=2)
# -> 1812             return func(ax, *args, **kwargs)
#    1813         pre_doc = inner.__doc__
#    1814         if pre_doc is None:
#
# /anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    4945                               resample=resample, **kwargs)
#    4946
# -> 4947         im.set_data(X)
#    4948         im.set_alpha(alpha)
#    4949         if im.get_clip_path() is None:
#
# /anaconda2/lib/python2.7/site-packages/matplotlib/image.py in set_data(self, A)
#     451         if (self._A.ndim not in (2, 3) or
#     452                 (self._A.ndim == 3 and self._A.shape[-1] not in (3, 4))):
# --> 453             raise TypeError("Invalid dimensions for image data")
#     454
#     455         self._imcache = None
#
# TypeError: Invalid dimensions for image data

# %%
ls torus_mhd_2d*
# Out:
# torus_mhd_2d.dat            torus_mhd_2d_hdf5_plt_cnt_0000
# torus_mhd_2d_hdf5_chk_0000  torus_mhd_2d_hdf5_plt_cnt_0001
# torus_mhd_2d_hdf5_chk_0001  torus_mhd_2d_hdf5_plt_cnt_0002
# torus_mhd_2d_hdf5_chk_0002  torus_mhd_2d_hdf5_plt_cnt_0003
# torus_mhd_2d_hdf5_chk_0003  torus_mhd_2d_hdf5_plt_cnt_0004
# torus_mhd_2d_hdf5_chk_0004  torus_mhd_2d_hdf5_plt_cnt_0005
# torus_mhd_2d_hdf5_chk_0005  torus_mhd_2d_hdf5_plt_cnt_0006
# torus_mhd_2d_hdf5_chk_0006  torus_mhd_2d_hdf5_plt_cnt_0007
# torus_mhd_2d_hdf5_chk_0007  torus_mhd_2d.log

# %%
ds.
# Out:
# torus_mhd_2d_hdf5_chk_0001

# %%
plot_var(2,"magnetic_field_strength")
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
