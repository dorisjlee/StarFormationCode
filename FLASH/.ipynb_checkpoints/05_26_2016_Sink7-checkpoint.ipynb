# %%
import yt 
yt.mylog.setLevel(50)
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ~/project/FLASH4.3_3/object/
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3_3/object

# %% [markdown]
# ### Plotting Particle Position

# %%
import yt
from yt.mods import *
yt.funcs.mylog.setLevel(50) #coerce output null
def plot_dens(i,velocity=False,grid=False,zmin ="",zmax="",particle=False):
    ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
    physical_quantity="density"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_figure_size(5)
    if grid: slc.annotate_grids()
    if velocity: slc.annotate_velocity()
    slc.set_cmap("all","rainbow")
    if zmin!="" and zmax!="": slc.set_zlim(physical_quantity,zmin,zmax)
    if particle : 
        data =np.loadtxt("sinks_evol.dat_cleaned",skiprows=1)
        pcl_indx_at_t = np.where(np.isclose(int(ds.current_time.in_cgs()),data[:,1]))[0]
        print "Number of sink particles: " , len(pcl_indx_at_t)
        pcl_pos_at_t = data[pcl_indx_at_t,2:5]
        for pos in pcl_pos_at_t:
            slc.annotate_marker(pos, coord_system='data',marker='.',plot_args={'color':'black','s':3})
    slc.show()

# %% [markdown]
# For the FACTOR = 100 sphere, core formation seemed to happen at t = 9.60E+11 s. So we want to introduce a sink particle at that time.

# %%
! sed -n '1{p;q}' sinks_evol.dat
# Out:
#      [00]part_tag         [01]time         [02]posx         [03]posy         [04]posz         [05]velx         [06]vely         [07]velz       [08]accelx       [09]accely       [10]accelz        [11]anglx        [12]angly        [13]anglz         [14]mass         [15]mdot        [16]ptime

# %%
i=35
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
pcl_indx_at_t = np.where(np.isclose(int(ds.current_time.in_cgs()),data[:,1]))[0]
print len(pcl_indx_at_t)
pcl_pos_at_t = data[pcl_indx_at_t,2:5]
pcl_pos_at_t
# Out:
# 8
# array([[  1.99629757e+18,   1.99629749e+18,   1.99629741e+18],
#        [  2.00370243e+18,   1.99629749e+18,   1.99629741e+18],
#        [  1.99629757e+18,   2.00370251e+18,   1.99629741e+18],
#        [  2.00370243e+18,   2.00370251e+18,   1.99629741e+18],
#        [  1.99629757e+18,   1.99629749e+18,   2.00370259e+18],
#        [  2.00370243e+18,   1.99629749e+18,   2.00370259e+18],
#        [  1.99629757e+18,   2.00370251e+18,   2.00370259e+18],
#        [  2.00370243e+18,   2.00370251e+18,   2.00370259e+18]])

# %%
plot_dens(35,grid=False,particle=True)
# Out:
# Number of sink particles:  8
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
FINAL_STEP = 51
for i in np.arange(FINAL_STEP):
    if i%5==0:
        plot_dens(i,grid=False,particle=True)
# Out:
# Number of sink particles:  0
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# Number of sink particles:  0
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# Number of sink particles:  0
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# Number of sink particles:  0
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# Number of sink particles:  0
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# Number of sink particles:  0
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# Number of sink particles:  0
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# Number of sink particles:  8
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# Number of sink particles:  1
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# Number of sink particles:  1
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# Number of sink particles:  1
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
