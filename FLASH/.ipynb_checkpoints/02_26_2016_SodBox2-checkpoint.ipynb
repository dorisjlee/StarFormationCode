# %%
import yt
yt.mylog.setLevel(50)
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ~/project/FLASH4.3/object/
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3/object

# %%
i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,1)
slc.show()


i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,1)
slc.show()

i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="temperature"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,5e-8,5e-9)
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,5)
slc.show()


i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,1)
slc.show()

i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="temperature"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,5e-8,5e-9)
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# Why is the density 1.0 rather than 0.1 as specified?

# %% [markdown]
# cleaned up some stuff and recompiled

# %%
i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,5)
slc.show()


i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,1)
slc.show()

i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="temperature"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,5e-8,5e-9)
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# density is still off my an order of magnitude but now pressure is correct

# %% [markdown]
# I suspect this is an EOS issue maybe I should switch gamma back to 1.4 , and really do setup, maybe the change was never implemented because I didn't do setup after changing the gamma '

# %%
i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,2)
slc.show()


i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,1)
slc.show()

i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="temperature"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,5e-8,5e-9)
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# still same density

# %%
gamma           = 1.001
 changed to gamme = 1.4

# %%
i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="density"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,2)
slc.show()


i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="pressure"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,0,1)
slc.show()

i = 0
ds = yt.load("sod_hdf5_chk_{}".format(str(i).zfill(4)))
physical_quantity="temperature"
slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
slc.set_figure_size(5)
slc.annotate_velocity()
slc.annotate_grids()
slc.set_log("all", False)
slc.set_zlim(physical_quantity,5e-8,5e-9)
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# okay even changing gamma back to 1.4 didn't help apparently, so now I need to go back to recopied version and redo this whole thing again, remember to git commit the stuff that actually works and do ./setup everytime!!!
