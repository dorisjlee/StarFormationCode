# %%
# %pylab inline
import yt
yt.funcs.mylog.setLevel(50) #coerce output null
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ~/project/FLASH4.3/object
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3/object

# %%
ls -d */
# Out:
# cold_fc_sphere_fullrun//  fcsphere_good//           USrhoOut_1E-31//
# fc_sink//                 fc_sphere_lev6uni_1tff//  US_small_floor//
# fc_sphere_amr_1tff//      uniform_sphere2//         US_small_floor2//
# fc_sphere_amr_5tff//      uniform_sphere_unigrid//

# %%
def plot_dens(i):
    ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
    physical_quantity="density"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_figure_size(5)
#     slc.annotate_grids()
    slc.annotate_velocity()
    slc.set_cmap("all","rainbow")
#     slc.set_zlim(physical_quantity, 5.5e-26,1.1e-19)
    slc.show()
def plot_all(i):
    ds = yt.load("uniform_sphere_hdf5_chk_{}".format(str(i).zfill(4)))
    physical_quantity="density"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_figure_size(5)
    slc.annotate_grids()
#     slc.set_log("all", False)
    slc.set_cmap("all","rainbow")
    slc.show()

    physical_quantity="pressure"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_cmap("all","rainbow")
    slc.set_figure_size(5)
    slc.set_log("all", False)
    # slc.set_zlim(physical_quantity,58,60)
    slc.show()

    physical_quantity="temperature"
    slc = yt.SlicePlot(ds, "z",physical_quantity)#,center=(0.5,0.5,0.5))
    slc.set_cmap("all","rainbow")
    slc.set_figure_size(5)
#     slc.set_zlim(physical_quantity,58,60)
#     slc.set_log("all", False)
    slc.show()

# %%
plot_all(0)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_dens(1)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_dens(2)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_dens(3)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_dens(4)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# vim 300929.out

# %% [markdown]
# no wonder there was flooring mesages but wtf??

# %% [markdown]
# This was done with the +unsplithydro solver with HLLC option, but now I turn that option off see what happens

# %%
plot_dens(3)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# Then it just hits Rieman non convergence after this not sure why ...

# %% [markdown]
# I tried copying over the more updated files that I made for UniformSphere_small_rho over to UniformSphere2 and changing the flash.par to the correct densities. But I found the same result , I tried both with unsplithydro and without unsplithydro

# %%
plot_dens(0)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_dens(1)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# Now I'm lowering the cfl number from 0.8 to 0.5 to see if taking smaller timesteps would help. But that didn't help either. So not sure what happened there....

# %%
# for i in np.arange(11):
#     plot_dens(i)

# %%
pwd
# Out:
# u'/global/project/projectdirs/astro250/doris/FLASH4.3/object'

# %%
plot_dens(1)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_dens(4)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
tryign with the old code for Config didn't work for the unsplithydro case, now trying the no unsplithydro case
