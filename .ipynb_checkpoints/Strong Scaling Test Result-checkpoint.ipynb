# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
0.117*60
# Out:
# 7.0200000000000005

# %% [markdown]
# ### Using levelmin =8 and levelmax =10 , Courant number = 0.15

# %%
t = [2032.98427891731,1219.13045811653,9.96,7.92,6.54,6.12,7.020,8.7,11.64] #Total elapsed time from Job start to finish (The ones after 8 is retreieve from the "Wall hours used" in myNERSC)
nproc =[4,8,24,48,72,96,120,144,168]
plt.plot(nproc,t,'o',color="red")
plt.plot(nproc,t,'-')
# plt.ylim(0,100)

# %% [markdown]
# ^ Bad run, I/O issues

# %% [markdown]
# Run #2

# %%
#######Run #2 Result######
t_ed2 = [3819.65508008003, 2042.96866011620,1224.78545498848,710.632806777954, 588.973438024521,464.104250907898, 539.256070852280,338.750422954559, 501.057538986206, 458.647161960602,346.335978031158] #Total elapsed time from Job start to finish
plt.plot(nproc,t_ed2,'o',color="red",label="Run#2")
plt.plot(nproc,t_ed2,'-',color="red",)
# plt.xlim(0,40)

#######Run #3 Result######
t_ed8 = [0,5299.89402318001,3000.712,1654.74100589752,1310.51329112053,855.093368053436,724.745522022247,930.650528907776,647.002765893936,755.831817865372,654.320645093918]
plt.plot(nproc,t_ed8,'o',color="blue",label="Run#3")
plt.plot(nproc,t_ed8,'-',color="blue")
# plt.xlim(0,40)
plt.xlabel("Number of cores",fontsize=12)
plt.ylabel("Time required [s]",fontsize=12)
plt.title("Strong Scaling Test on RAMSES",fontsize=13)
from matplotlib.legend_handler import HandlerLine2D
plt.legend(loc='upper right',prop={'size':12},numpoints=1)

# %% [markdown]
# Note that the test2/ run out of wall time when 01:30:00 set.

# %% [markdown]
# ### Using levelmin =9 and levelmax =10 , Courant number = 0.15

# %%
t_ed9 = [0,5291.46367192268,2994.87785410881,1650.38760018349,1280.42700481415,942.927964925766,737.289843082428,648.396118879318,743.114267110825,880.578519105911,657.059722900391]
nproc =[2,4,8,16,24,48,72,96,120,144,168]
plt.plot(nproc,t_ed9,'o',color="red",label="levelmin=9")
plt.plot(nproc,t_ed9,'-',color="red")
# plt.xlim(0,40)
plt.xlabel("Number of cores",fontsize=12)
plt.ylabel("Time required [s]",fontsize=12)
plt.title("Strong Scaling Test on RAMSES",fontsize=13)
from matplotlib.legend_handler import HandlerLine2D
plt.legend(loc='upper right',prop={'size':12},numpoints=1)
plt.plot(nproc,t_ed8,'o',color="blue",label="levelmin=8")
plt.plot(nproc,t_ed8,'-',color="blue")
# plt.xlim(0,40)
plt.xlabel("Number of cores",fontsize=12)
plt.ylabel("Time required [s]",fontsize=12)
plt.title("Strong Scaling Test on RAMSES",fontsize=13)
from matplotlib.legend_handler import HandlerLine2D
plt.legend(loc='upper right',prop={'size':12},numpoints=1)

# %% [markdown]
# Surprisingly, there isn't a whole big difference in the changing levelmin from 8 to 9

# %% [markdown]
# # Hopper

# %% [markdown]
# On a single thread (no MPI): total runtime is
#
# real	354m3.531s
# user	353m8.028s
# sys	0m49.407s
#
# So 21243.531 s
#
#
# On average, the MPI speedup is about a factor of 10 better compared to single thread processes.

# %% [markdown]
# ### Using levelmin =8 and levelmax =10 , Courant number = 0.15

# %%
t_hp8 = [0, 4782.97428393364,2748.53488492966,1535.0110650062,1286.88882803917,910.130939960480,798.035315990448,674.846395969391,648.973379135132,612.291826009750,602.529850959778] #Total elapsed time from Job start to finish
plt.plot(nproc,t_hp8,'o',color="red")
plt.plot(nproc,t_hp8,'-')
plt.xlabel("Number of cores",fontsize=12)
plt.ylabel("Time required [s]",fontsize=12)
plt.title("Strong Scaling Test on RAMSES",fontsize=13)

# %% [markdown]
# ### Using levelmin =9 and levelmax =10 , Courant number = 0.15

# %%
plt.plot(nproc,t_hp8,'o',color="red",label="levelmin=8")
plt.plot(nproc,t_hp8,'-',color="red")
# plt.xlim(0,40)
plt.xlabel("Number of cores",fontsize=12)
plt.ylabel("Time required [s]",fontsize=12)
plt.title("Strong Scaling Test on RAMSES",fontsize=13)
from matplotlib.legend_handler import HandlerLine2D
plt.legend(loc='upper right',prop={'size':12},numpoints=1)
####### Larger level min result ######
t_hp9 = [0, 0,6660.61258697510,3612.39768004417,2807.24373006821,1849.01880598068,1554.94762992859,1324.28459596634,1270.21670985222,1194.01984,1188.1286]
plt.plot(nproc,t_hp9,'o',color="blue",label="levelmin=9")
plt.plot(nproc,t_hp9,'-',color="blue")
# plt.xlim(0,40)
from matplotlib.legend_handler import HandlerLine2D
plt.legend(loc='upper right',prop={'size':12},numpoints=1)

# %% [markdown]
# # Machine- Comparison

# %%
plt.plot(nproc,t_ed8,'o',color="blue",label="Edison")
plt.plot(nproc,t_ed8,'-',color="blue")
t = [3819.65508008003, 2042.96866011620,1224.78545498848,710.632806777954, 588.973438024521,464.104250907898, 539.256070852280,338.750422954559, 501.057538986206, 458.647161960602,346.335978031158] #Total elapsed time from Job start to finish
nproc =[2,4,8,16,24,48,72,96,120,144,168]
plt.plot(nproc,t_hp8,'o',color="red",label="Hopper")
plt.plot(nproc,t_hp8,'-',color="red")
plt.xlabel("Number of cores",fontsize=12)
plt.ylabel("Time required [s]",fontsize=12)
plt.title("Strong Scaling Test on RAMSES",fontsize=13)
from matplotlib.legend_handler import HandlerLine2D
plt.legend(loc='upper right',prop={'size':12},numpoints=1)

# %%
plt.plot(nproc,t_ed9,'o',color="blue",label="Edison")
plt.plot(nproc,t_ed9,'-',color="blue")
plt.plot(nproc,t_hp9,'o',color="red",label="Hopper")
plt.plot(nproc,t_hp9,'-',color="red")
plt.xlabel("Number of cores",fontsize=12)
plt.ylabel("Time required [s]",fontsize=12)
plt.title("Strong Scaling Test on RAMSES",fontsize=13)
from matplotlib.legend_handler import HandlerLine2D
plt.legend(loc='upper right',prop={'size':12},numpoints=1)

# %% [markdown]
# Interestingly, RAMSES seems to perform better on Hopper than on Edison

# %% [markdown]
# ##### I will not attempt to do this on Carver since RAMSES doesn't really compile properly on Carver . Also I think Carver is retiring soon.
