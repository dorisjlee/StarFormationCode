# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import plot_is

# %%
cd /project/projectdirs/astro250/doris/ramses3/trunk/ramses/bin/
# Out:
# /global/project/projectdirs/astro250/doris/ramses3/trunk/ramses/bin

# %%
# for i in np.arange(1,50):
#     if i%10==0:
#         plot_is.plot_time_slice("density",i,zmin=1e-26,zmax=1e-19)

# %% [markdown]
# # Correctly setting external pressure and density profile

# %%
dens_arr = np.loadtxt("../patch/hydro/isothermal_sphere/density.txt")

# %%
rho_c = 0.02806
scale_d = 3.92e-18
rho_min = min(dens_arr)*rho_c*scale_d
print rho_min
# Out:
# 6.43260980602e-21

# %%
T_out = 1e7#K
k = 1.38e-16 #cgs
mp = 1.6726219e-24 #grams
scale_p =  2.51e-9 
P_out = (rho_min*k*T_out/mp)/scale_p 
print P_out , "code units"
print P_out*scale_p , "cgs"
# Out:
# 2114.43721796 code units
# 5.30723741708e-06 cgs

# %%
rho_out = ((P_out*scale_p)*mp/k/T_out)/scale_d
print rho_out , "code units"
# Out:
# 0.00164097188929 code units

# %% [markdown]
# Just checking that it is the same

# %%
print min(dens_arr)*rho_c , "code units"
# Out:
# 0.00164097188929 code units

# %% [markdown]
# # Checking Pressure profile in cgs

# %%
print "density inside :",rho_c * scale_d , "cgs "
# Out:
# density inside : 1.099952e-19 cgs

# %%
print "pressure inside: ",(rho_c*scale_d)*k*10/mp, "cgs"
# Out:
# pressure inside:  9.07517568675e-11 cgs

# %%
print "density outside: " , rho_min, "cgs"
# Out:
# density outside:  6.43260980602e-21 cgs

# %%
print "pressure outside : ", rho_min*k*T_out/mp ,"cgs"
# Out:
#  pressure outside :  5.30723741708e-06 cgs

# %%
print "density outside" ,0.00164097*scale_d,"cgs"
# Out:
# density outside 6.4326024e-21 cgs

# %%
print "pressure outside",2114*scale_p,"cgs"
# Out:
# pressure outside 5.30614e-06 cgs

# %%
plot_is.plot_time_slice("density",1)#,1,zmin=1e-26,zmax=1e-19)
plot_is.plot_time_slice("pressure",1)
plot_is.plot_time_slice("temperature",1)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_is.plot_time_slice("density",10)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_is.plot_time_slice("density",18)#,zmin=1e-26,zmax=1e-19)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
