# %%
# %pylab inline 
import plot_is
import yt
yt.funcs.mylog.setLevel(50)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd /project/projectdirs/astro250/doris/uniform_sphere/trunk/ramses/bin
# Out:
# /global/project/projectdirs/astro250/doris/uniform_sphere/trunk/ramses/bin

# %%
plot_is.check_IC_profiles()
# Out:
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:645: RuntimeWarning: divide by zero encountered in double_scalars
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:645: RuntimeWarning: invalid value encountered in multiply
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:701: RuntimeWarning: invalid value encountered in less
#   short = np.repeat(length < minsh, 8, axis=1)
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:711: RuntimeWarning: invalid value encountered in less
#   tooshort = length < self.minlength

# %%
def plot_time_slice(physical_quantity,timestep,zmin="",zmax="" ,text="",title="",zoom_factor="",velocity=True,grid=False,save=False,log=True,plot_size=5):
    ds= yt.load("output_{0}/info_{0}.txt".format(str(timestep).zfill(5)))
    slc = yt.SlicePlot(ds, "y",physical_quantity)
#     if axes_unit!="":
#         slc.set_axes_unit(axes_unit)
    slc.set_cmap("all","Paired")
    slc.set_figure_size(plot_size)
    slc.set_font_size(plot_size*2.5)
    if (log==False):
        slc.set_log(physical_quantity, False)
    if zoom_factor!="":
        slc.zoom(zoom_factor)
    if zmin!="" and zmax!="":
        slc.set_zlim(physical_quantity, zmin,zmax)
    if title!="":
    	slc.annotate_title(title)
    slc.annotate_text((0.05, 0.05),"timestep: {}".format(timestep-1), coord_system='axis')
    if (velocity):
        slc.annotate_velocity()
    if(grid): 
        slc.annotate_grids()
    if (save):
       name  =str(timestep)#physical_quantity[:3]+str(timestep)
       slc.save(name)
    else:
       slc.show()

# %%
plot_time_slice("density",1,grid=True, velocity=False,plot_size=5,log=False)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_time_slice("density",4, velocity=False,plot_size=5,log=False)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_time_slice("density",6, velocity=False,plot_size=5,log=False)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# # Unigrid (level=4)

# %%
cd /project/projectdirs/astro250/doris/uniform_sphere2/trunk/ramses/bin
# Out:
# /global/project/projectdirs/astro250/doris/uniform_sphere2/trunk/ramses/bin

# %%
plot_time_slice("density",i,grid=True,velocity=False, plot_size=5)
# Out:
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/yt/units/yt_array.py:795: RuntimeWarning: invalid value encountered in divide
#   return YTArray(super(YTArray, self).__div__(ro))
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
for i in np.arange(1,12):
    plot_time_slice("density",i,velocity=False, plot_size=5)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# # Unigrid (level =6 )

# %%
plot_time_slice("density",1,grid=True,velocity=False, plot_size=5)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
for i in np.arange(1,16):
    plot_time_slice("radial_velocity",i,velocity=False, plot_size=5)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# ...

# %%
for i in np.arange(1,16):
    plot_time_slice("density",i,velocity=False, plot_size=5)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# ...

# %%
plot_time_slice("density",15,velocity=False, plot_size=5)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# # Unigrid (level =7 )

# %%
plot_time_slice("density",1,grid=True,velocity=False, plot_size=5)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_time_slice("density",1,grid=False,velocity=False, plot_size=5)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_time_slice("density",5,grid=False,velocity=False, plot_size=5)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_time_slice("density",7,grid=False,velocity=False, plot_size=5)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_time_slice("density",8,zoom_factor=2,grid=False,velocity=False, plot_size=5)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_time_slice("density",8,grid=False,velocity=True, plot_size=5)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_time_slice("radial_velocity",8,grid=False,velocity=False, plot_size=5)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_time_slice("density",14,grid=False,velocity=True, plot_size=5)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_time_slice("density",14,grid=False,velocity=False, plot_size=5)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_time_slice("density",15,grid=False,velocity=False, plot_size=5)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
cd lev7/
# Out:
# /global/project/projectdirs/astro250/doris/uniform_sphere2/trunk/ramses/bin/lev7

# %%
plot_time_slice("radial_velocity",15,grid=False,velocity=False, plot_size=5,zmin=-0.5, zmax=0)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
