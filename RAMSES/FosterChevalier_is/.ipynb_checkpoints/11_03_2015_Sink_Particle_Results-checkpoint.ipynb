# %%
# %pylab inline
import yt
import plot_is
yt.funcs.mylog.setLevel(50)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd /project/projectdirs/astro250/doris/ramses3/trunk/ramses/bin/
# Out:
# /global/project/projectdirs/astro250/doris/ramses3/trunk/ramses/bin

# %%
for i in np.arange(1,7):
    plot_is.plot_time_slice("density",i)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
for timestep in np.arange(1,7):
    ds= yt.load("output_{0}/info_{0}.txt".format(str(timestep).zfill(5)))
    slc = yt.SlicePlot(ds,"x","radial_velocity")
    slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# Weird bounary effect (squarish) This is because I accidentally used the reflexive boundary condition, when I should really be using outflow

# %% [markdown]
# But after the 7th timestep it just dies..

# %% [raw]
#    Entering build_comm for level  8
#    Entering make_boundary_hydro for level  8
#    Entering make_boundary_force for level  8
#    Entering build_comm for level  9
#    Entering make_boundary_hydro for level  9
#    Entering make_boundary_force for level  9
#    Entering build_comm for level 10
#    Entering make_boundary_hydro for level 10
#    Entering make_boundary_force for level 10
#    Entering update_cloud for level  7
#  sink drift due to accretion relative to grid size at level            7
#  #sink:            1  drift:    0.0000000000000000        0.0000000000000000        0.0000000000000000
#  #sink:            2  drift:    0.0000000000000000        0.0000000000000000        0.0000000000000000
#    Entering make_tree_fine for level  7
# Problem in check_tree at level            7
#  A particle has moved outside allowed boundaries
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#    93.609388349053177        1.4843750000000000
#
# Program received signal SIGSEGV: Segmentation fault - invalid memory reference.
#
# Backtrace for this error:

# %% [markdown]
# Checking again if MPI works now

# %% [raw]
# Entering amr_step1 for level 8
#    Entering refine_fine for level  8
#    Entering authorize_fine for level  8
#    Entering init_boundary_fine for level  8
#    Entering make_boundary_flag for level  8
#    ==> Make      0 sub-grids
#    ==> Kill      0 sub-grids
#    Entering build_comm for level  9
#    Entering make_boundary_hydro for level  9
#    Entering make_boundary_force for level  9
#    Entering build_comm for level 10
#    Entering make_boundary_hydro for level 10
#    Entering make_boundary_force for level 10
#    Entering update_cloud for level  8
#  sink drift due to accretion relative to grid size at level            8
#  #sink:            1  drift:    0.0000000000000000        0.0000000000000000        0.0000000000000000
#    Entering make_tree_fine for level  8
#  Problem in check_tree at level            8
#  A particle has moved outside allowed boundaries
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#    101.91668782830047        1.4921875000000000
#
# Program received signal SIGSEGV: Segmentation fault - invalid memory reference.
