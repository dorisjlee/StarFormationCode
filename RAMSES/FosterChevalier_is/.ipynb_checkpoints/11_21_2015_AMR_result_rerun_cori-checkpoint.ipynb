# %% [markdown]
# Since yt keep failing in notebook , I wrote a script to do this in terminal

# %%
cd /project/projectdirs/astro250/doris/ramses3/trunk/ramses/bin/
# Out:
# /global/project/projectdirs/astro250/doris/ramses3/trunk/ramses/bin

# %%
import IPython.core.display

# %%
IPython.display.Image("1_Slice_z_density.png")

# %%
ls *.png
# Out:
# 1_Slice_z_density.png  den1_Slice_z_density.png

# %%
IPython.display.Image("100_Slice_z_density.png")

# %% [markdown]
# Oops I made the mistake this is misleading this is actually 0.6 Myr because my dt is set as 1e-3, also I should just rerun this whol thing to make use of the whole cori node of 32 cores, actually lets try 64 cores

# %% [markdown]
# -----------------------

# %% [markdown]
# Okay now yt is working I can plot stuff

# %% [markdown]
# The amr job takes a very long time 30 hours for timestep 22--> 27 using 72 cores! (this is faster on cori because icc, but the cori wait time is bad.)

# %%
import plot_is

# %%
cd /project/projectdirs/astro250/doris/ramses3/trunk/ramses/bin/
# Out:
# /global/project/projectdirs/astro250/doris/ramses3/trunk/ramses/bin

# %%
plot_is.plot_time_slice("density",1)
# Out:
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:645: RuntimeWarning: divide by zero encountered in double_scalars
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:645: RuntimeWarning: invalid value encountered in multiply
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:701: RuntimeWarning: invalid value encountered in less
#   short = np.repeat(length < minsh, 8, axis=1)
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:711: RuntimeWarning: invalid value encountered in less
#   tooshort = length < self.minlength
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_is.plot_time_slice("density",27)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_is.plot_time_slice("density",27,grid=True)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
