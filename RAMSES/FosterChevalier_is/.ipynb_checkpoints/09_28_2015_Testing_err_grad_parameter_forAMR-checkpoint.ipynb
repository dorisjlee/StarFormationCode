# %%
# %pylab inline 
import yt 
import plot_is
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd /project/projectdirs/astro250/doris/ramses/trunk/ramses/bin/
# Out:
# /global/project/projectdirs/astro250/doris/ramses/trunk/ramses/bin

# %% [markdown]
# No AMR at work on the previous simulation because the d,p , u criterion is one fold by default, I've lowered that threshold so that the AMR will be at work now.

# %% [markdown]
# for d, u , p : err_grad_d=-0.1

# %%
plot_is.plot_time_slice("density",3)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# Changed refinement criteria to 1e-5 and so any fluctuation above that level should increase AMR level refinement

# %%
plot_is.plot_time_slice("density",5)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# actually a better way to test this if I have just free fall collapse , large pressure on the outside ..etc.
# so I set the pressure as 100 outside so it has to collapse continuously.

# %%
ls
# Out:
# adaptive_loop.o         hydro_flag.o              physical_boundaries.o
# add_list.o              hydro_parameters.mod      pm_commons.mod
# amr_commons.mod         hydro_parameters.o        pm_commons.o
# amr_commons.o           init_amr.o                pm_parameters.mod
# amr_parameters.mod      init_flow_fine.o          pm_parameters.o
# amr_parameters.o        init_hydro.o              poisson_commons.mod
# amr_step.o              init_part.o               poisson_commons.o
# bisection.mod           init_poisson.o            poisson_parameters.mod
# bisection.o             init_refine.o             poisson_parameters.o
# boundana.o              init_sink.o               ramses3d*
# boundary_potential.o    init_time.o               ramses.o
# clfind_commons.mod      interpol_hydro.o          random.mod
# clfind_commons.o        interpol_phi.o            random.o
# clump_finder.o          light_cone.o              read_hydro_params.o
# ...

# %%
plot_is.plot_time_slice("density",2)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_is.plot_time_slice("pressure",2)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_is.plot_time_slice("pressure",4)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# This doesn't make sense, AMR shold have been at work because the orange and the blue is more than two orders of magnitude different, the refinmenet criterion is 1e-5 so not too sure why its not doing it..'

# %%
plot_is.plot_time_slice("pressure",24)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
