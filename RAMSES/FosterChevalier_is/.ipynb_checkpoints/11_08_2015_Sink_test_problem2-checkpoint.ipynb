# %% [markdown]
# Make the peak regions where sink criterion is satisfied smaller

# %%
import plot_is
import yt
yt.funcs.mylog.setLevel(50)

# %%
cd /project/projectdirs/astro250/doris/ramses/trunk/ramses/bin/
# Out:
# /global/project/projectdirs/astro250/doris/ramses/trunk/ramses/bin

# %%
plot_is.plot_time_slice("density",2)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_is.plot_time_slice("density",10)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
cat output_00024/sink_00024.info
# Out:
#  Number of sink =            0
# ...
#         Id       Mass(Msol)             x                y                z               vx               vy               vz
# ...

# %% [markdown]
# Going back to the original definition
