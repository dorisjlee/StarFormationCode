# %% [markdown]
# # Simple Visualizations of Data
#
# Just like in our first notebook, we have to load yt and then some data.

# %%
import yt
ds = yt.load("data.0002.3d.hdf5")
# Out:
# yt : [WARNING  ] 2015-01-30 18:46:50,894 Setting code length to be 1.0 cm
# yt : [WARNING  ] 2015-01-30 18:46:50,894 Setting code mass to be 1.0 g
# yt : [WARNING  ] 2015-01-30 18:46:50,895 Setting code time to be 1.0 s
# yt : [INFO     ] 2015-01-30 18:46:50,922 Parameters: current_time              = 26355494818.1
# yt : [INFO     ] 2015-01-30 18:46:50,923 Parameters: domain_dimensions         = [128 128 128]
# yt : [INFO     ] 2015-01-30 18:46:50,925 Parameters: domain_left_edge          = [ -1.23427103e+18  -1.23427103e+18  -1.23427103e+18]
# yt : [INFO     ] 2015-01-30 18:46:50,926 Parameters: domain_right_edge         = [  1.23427103e+18   1.23427103e+18   1.23427103e+18]

# %% [markdown]
# For this notebook, we'll load up a cosmology dataset.

# %% [markdown]
# In the terms that yt uses, a projection is a line integral through the domain.  This can either be unweighted (in which case a column density is returned) or weighted, in which case an average value is returned.  Projections are, like all other data objects in yt, full-fledged data objects that churn through data and present that to you.  However, we also provide a simple method of creating Projections and plotting them in a single step.  This is called a Plot Window, here specifically known as a `ProjectionPlot`.  One thing to note is that in yt, we project all the way through the entire domain at a single time.  This means that the first call to projecting can be somewhat time consuming, but panning, zooming and plotting are all quite fast.
#
# yt is designed to make it easy to make nice plots and straightforward to modify those plots directly.  The cookbook in the documentation includes detailed examples of this.

# %%
ds.field_list
# Out:
# [('chombo', 'density'),
#  ('chombo', 'X-momentum'),
#  ('chombo', 'tracer3'),
#  ('chombo', 'gravitational-potential'),
#  ('chombo', 'Y-momentum'),
#  ('chombo', 'Z-momentum'),
#  ('chombo', 'X-magnfield'),
#  ('chombo', 'Y-magnfield'),
#  ('chombo', 'Z-magnfield'),
#  ('chombo', 'energy-density'),
#  ('chombo', 'tracer1'),
#  ('chombo', 'tracer2')]

# %%
p = yt.ProjectionPlot(ds, "y", "density")
p.show()
# Out:
# yt : [INFO     ] 2015-01-30 22:23:28,176 Projection completed
# yt : [INFO     ] 2015-01-30 22:23:28,187 xlim = -1234271030000000000.000000 1234271030000000000.000000
# yt : [INFO     ] 2015-01-30 22:23:28,187 ylim = -1234271030000000000.000000 1234271030000000000.000000
# yt : [INFO     ] 2015-01-30 22:23:28,188 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [INFO     ] 2015-01-30 22:23:28,206 xlim = -1234271030000000000.000000 1234271030000000000.000000
# yt : [INFO     ] 2015-01-30 22:23:28,206 ylim = -1234271030000000000.000000 1234271030000000000.000000
# yt : [INFO     ] 2015-01-30 22:23:28,209 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [INFO     ] 2015-01-30 22:23:28,225 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img src="data:image/png;base64,..."><br>

# %% [markdown]
# The `show` command simply sends the plot to the IPython notebook.  You can also call `p.save()` which will save the plot to the file system.  This function accepts an argument, which will be pre-prended to the filename and can be used to name it based on the width or to supply a location.
#
# Now we'll zoom and pan a bit.

# %%
p.zoom(2.0)
# Out:
# yt : [INFO     ] 2015-01-30 22:30:12,702 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img src="data:image/png;base64,..."><br>

# %% [markdown]
# If we specify multiple fields, each time we call `show` we get multiple plots back.  Same for `save`!

# %%
p = yt.ProjectionPlot(ds, "z", ["density", "gravitational-potential"], weight_field="density")
p.show()
# Out:
# yt : [INFO     ] 2015-01-30 23:16:22,505 Projection completed
# yt : [INFO     ] 2015-01-30 23:16:22,520 xlim = -1234271030000000000.000000 1234271030000000000.000000
# yt : [INFO     ] 2015-01-30 23:16:22,521 ylim = -1234271030000000000.000000 1234271030000000000.000000
# yt : [INFO     ] 2015-01-30 23:16:22,524 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [INFO     ] 2015-01-30 23:16:22,546 Making a fixed resolution buffer of (('chombo', 'gravitational-potential')) 800 by 800
# yt : [INFO     ] 2015-01-30 23:16:22,575 xlim = -1234271030000000000.000000 1234271030000000000.000000
# yt : [INFO     ] 2015-01-30 23:16:22,575 ylim = -1234271030000000000.000000 1234271030000000000.000000
# yt : [INFO     ] 2015-01-30 23:16:22,589 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [INFO     ] 2015-01-30 23:16:22,609 Making a fixed resolution buffer of (('chombo', 'gravitational-potential')) 800 by 800
# yt : [INFO     ] 2015-01-30 23:16:22,641 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [INFO     ] 2015-01-30 23:16:22,665 Making a fixed resolution buffer of (('chombo', 'gravitational-potential')) 800 by 800
# yt : [WARNING  ] 2015-01-30 23:16:22,900 Plot image for field ('chombo', 'gravitational-potential') has both positive and negative values. Min = -0.000000, Max = 0.000000.
# yt : [WARNING  ] 2015-01-30 23:16:22,900 Switching to symlog colorbar scaling unless linear scaling is specified later
# <img src="data:image/png;base64,..."><br><img src="data:image/png;base64,..."><br>

# %% [markdown]
# We can adjust the colormap on a field-by-field basis.

# %%
p.set_cmap("density", "hot")
# Out:
# <img src="data:image/png;base64,..."><br><img src="data:image/png;base64,..."><br>

# %% [markdown]
# And, we can re-center the plot on different locations.  One possible use of this would be to make a single `ProjectionPlot` which you move around to look at different regions in your simulation, saving at each one.

# %%
v, c = ds.find_max("density")
p.set_center((c[0], c[1]))
p.zoom(10)
# Out:
# yt : [INFO     ] 2015-01-29 07:07:45,737 Max Value is 2.56947e-25 at 0.5551757812500000 0.6635742187500000 0.8588867187500000
# yt : [INFO     ] 2015-01-29 07:07:45,740 xlim = 0.055176 1.055176
# yt : [INFO     ] 2015-01-29 07:07:45,740 ylim = 0.163574 1.163574
# yt : [INFO     ] 2015-01-29 07:07:45,745 Making a fixed resolution buffer of (('gas', 'temperature')) 800 by 800
# yt : [INFO     ] 2015-01-29 07:07:45,765 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [INFO     ] 2015-01-29 07:07:46,108 Making a fixed resolution buffer of (('gas', 'temperature')) 800 by 800
# yt : [INFO     ] 2015-01-29 07:07:46,125 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [INFO     ] 2015-01-29 07:07:46,470 Making a fixed resolution buffer of (('gas', 'temperature')) 800 by 800
# yt : [INFO     ] 2015-01-29 07:07:46,486 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img src="data:image/png;base64,..."><br><img src="data:image/png;base64,..."><br>

# %%
# ds.derived_field_list

# %%
s = yt.SlicePlot(ds, "z", ["density", "velocity_x"], center="max")
s.set_cmap("velocity_x", "kamae")
s.zoom(10.0)
# Out:
# yt : [INFO     ] 2015-01-31 01:54:50,564 Max Value is 1.66903e-16 at -16874799238281248.0000000000000000 -26517541660156248.0000000000000000 -7232056816406248.0000000000000000
# yt : [INFO     ] 2015-01-31 01:54:52,998 xlim = -1251145829238281216.000000 1217396230761718784.000000
# yt : [INFO     ] 2015-01-31 01:54:52,998 ylim = -1260788571660156160.000000 1207753488339843840.000000
# yt : [INFO     ] 2015-01-31 01:54:53,001 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [INFO     ] 2015-01-31 01:54:53,254 Making a fixed resolution buffer of (('gas', 'velocity_x')) 800 by 800
# yt : [INFO     ] 2015-01-31 01:54:53,289 xlim = -1251145829238281216.000000 1217396230761718784.000000
# yt : [INFO     ] 2015-01-31 01:54:53,290 ylim = -1260788571660156160.000000 1207753488339843840.000000
# yt : [INFO     ] 2015-01-31 01:54:53,294 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [INFO     ] 2015-01-31 01:54:53,316 Making a fixed resolution buffer of (('gas', 'velocity_x')) 800 by 800
# yt : [INFO     ] 2015-01-31 01:54:53,339 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [INFO     ] 2015-01-31 01:54:53,361 Making a fixed resolution buffer of (('gas', 'velocity_x')) 800 by 800
# yt : [WARNING  ] 2015-01-31 01:54:53,622 Plot image for field ('gas', 'velocity_x') has both positive and negative values. Min = -384828.867516, Max = 323344.753485.
# yt : [WARNING  ] 2015-01-31 01:54:53,622 Switching to symlog colorbar scaling unless linear scaling is specified later
# yt : [INFO     ] 2015-01-31 01:54:54,024 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [INFO     ] 2015-01-31 01:54:54,039 Making a fixed resolution buffer of (('gas', 'velocity_x')) 800 by 800
# <img src="data:image/png;base64,..."><br><img src="data:image/png;base64,..."><br>

# %% [markdown]
# We can adjust the logging of various fields:

# %% [markdown]
# #(*) What's logging?

# %%
s.set_log("velocity_magnitude", True)
# Out:
# <img src="data:image/png;base64,..."><br><img src="data:image/png;base64,..."><br>

# %% [markdown]
# yt provides many different annotations for your plots.  You can see all of these in the documentation, or if you type `s.annotate_` and press tab, a list will show up here.  We'll annotate with velocity arrows.

# %%
s.annotate_velocity()
# Out:
# <img src="data:image/png;base64,..."><br><img src="data:image/png;base64,..."><br>

# %% [markdown]
# Contours can also be overlaid:

# %%
s = yt.SlicePlot(ds, "x", ["density"], center="max")
s.annotate_contour("temperature")
s.zoom(2.5)
# Out:
# yt : [INFO     ] 2015-01-29 07:10:47,513 Max Value is 6.27892e-27 at 0.2026367187500000 0.5463867187500000 0.1127929687500000
# yt : [INFO     ] 2015-01-29 07:10:47,601 xlim = 0.046387 1.046387
# yt : [INFO     ] 2015-01-29 07:10:47,601 ylim = -0.387207 0.612793
# yt : [INFO     ] 2015-01-29 07:10:47,602 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [INFO     ] 2015-01-29 07:10:47,629 xlim = 0.046387 1.046387
# yt : [INFO     ] 2015-01-29 07:10:47,630 ylim = -0.387207 0.612793
# yt : [INFO     ] 2015-01-29 07:10:47,632 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [INFO     ] 2015-01-29 07:10:47,649 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [INFO     ] 2015-01-29 07:10:48,117 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img src="data:image/png;base64,..."><br>

# %% [markdown]
# Finally, we can save out to the file system.

# %%
s.save()
# Out:
# yt : [INFO     ] 2015-01-29 07:11:05,930 Saving plot data0043_Slice_x_density.png
# ['data0043_Slice_x_density.png']

# %% [markdown]
# # Figure out where the AMR grids are and see whether it is most dense in the center of the core

# %%
# ds.derived_field_list

# %%
ds.derfield_info["velocity_x"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-0fba1f8ae085> in <module>()
# ----> 1 ds.derived_field_info["velocity_x"]
#
# AttributeError: 'Orion2Dataset' object has no attribute 'derived_field_info'
