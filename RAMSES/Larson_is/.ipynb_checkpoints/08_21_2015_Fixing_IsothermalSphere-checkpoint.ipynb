# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %pylab inline
import sys
sys.path.remove('/global/homes/d/dorislee/.local/lib/python2.7/site-packages/yt-3.2.dev0-py2.7-linux-x86_64.egg')
sys.path.remove('/global/homes/d/dorislee/.local/lib/python2.7/site-packages')
sys.path.append('/global/homes/d/dorislee/mypythonpackages')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import yt
yt.funcs.mylog.setLevel(50) #coerce output null

# %%
yt.funcs.mylog.setLevel(50) #coerce output null

# %%
cd ~/ramses/trunk/ramses/bin/
# Out:
# /global/u2/d/dorislee/ramses/trunk/ramses/bin

# %%
ds= yt.ddload("output_00001/info_00001.txt")
proj = yt.ProjectionPlot(ds, "z", "Density" ,window_size=5)
proj.set_cmap("density","rainbow")
proj.annotate_velocity()
proj.annotate_grids()
proj.show()
# Out:
# <img src="data:image/png;base64,..."><br>

# %%
ds= yt.load("output_00002/info_00002.txt")
proj = yt.ProjectionPlot(ds, "z", "Density" ,window_size=5)
proj.set_cmap("density","rainbow")
proj.annotate_velocity()
proj.annotate_grids()
proj.show()
# Out:
# <img src="data:image/png;base64,..."><br>

# %%
def plot_time_slice(physical_quantity,timestep):
    ds= yt.load("output_0000{0}/info_0000{0}.txt".format(timestep))
    proj = yt.SlicePlot(ds, "z",physical_quantity ,window_size=7)
    proj.set_cmap(physical_quantity,"rainbow")
    proj.annotate_velocity()
    proj.annotate_grids()
    proj.show()

# %%
plot_time_slice("density",1)
# Out:
# <img src="data:image/png;base64,..."><br>

# %%
plot_time_slice("density",2)
# Out:
# <img src="data:image/png;base64,..."><br>

# %% [markdown]
# ### Without self gravity

# %%
plot_time_slice("density",1)
# Out:
# <img src="data:image/png;base64,..."><br>

# %%
plot_time_slice("density",2)
# Out:
# <img src="data:image/png;base64,..."><br>

# %% [raw]
# &OUTPUT_PARAMS
# foutput=50
# fbackup=50
# noutput=4
# tout=0,0.2714,0.5428,0.691262,0.8142,1.0857,2.
# /

# %% [markdown]
# Now changed to

# %%
plot_time_slice("density",1)
# Out:
# <img src="data:image/png;base64,..."><br>

# %%
plot_time_slice("density",2)
# Out:
# <img src="data:image/png;base64,..."><br>

# %% [markdown]
# Need to set timestep bigger than what the code is stepping through

# %% [raw]
# &OUTPUT_PARAMS
# foutput=10000000
# delta_tout=10000000
# tend=1.36192e10
# /

# %%
for i in np.arange(1,10):
    plot_time_slice("density",i)
# Out:
# <img src="data:image/png;base64,..."><br>
# <img src="data:image/png;base64,..."><br>
# <img src="data:image/png;base64,..."><br>
# <img src="data:image/png;base64,..."><br>
# <img src="data:image/png;base64,..."><br>
# <img src="data:image/png;base64,..."><br>
# <img src="data:image/png;base64,..."><br>
# <img src="data:image/png;base64,..."><br>
# <img src="data:image/png;base64,..."><br>

# %%
for i in np.arange(1,40):
    plot_time_slice("density",i)
# Out:
# <img src="data:image/png;base64,..."><br>
# <img src="data:image/png;base64,..."><br>
# <img src="data:image/png;base64,..."><br>
# <img src="data:image/png;base64,..."><br>
# <img src="data:image/png;base64,..."><br>
# <img src="data:image/png;base64,..."><br>
# <img src="data:image/png;base64,..."><br>
# <img src="data:image/png;base64,..."><br>
# <img src="data:image/png;base64,..."><br>
# ---------------------------------------------------------------------------
# YTOutputNotIdentified                     Traceback (most recent call last)
# <ipython-input-25-b39ab7d78fee> in <module>()
#       1 for i in np.arange(1,40):
# ----> 2     plot_time_slice("density",i)
#
# <ipython-input-11-696764afabe7> in plot_time_slice(physical_quantity, timestep)
#       1 def plot_time_slice(physical_quantity,timestep):
# ----> 2     ds= yt.load("output_0000{0}/info_0000{0}.txt".format(timestep))
#       3     proj = yt.SlicePlot(ds, "z",physical_quantity ,window_size=7)
#       4     proj.set_cmap(physical_quantity,"rainbow")
#       5     proj.annotate_velocity()
#
# /global/homes/d/dorislee/mypythonpackages/yt/convenience.pyc in load(*args, **kwargs)
#      73         mylog.error("None of the arguments provided to load() is a valid file")
#      74         mylog.error("Please check that you have used a correct path")
# ---> 75         raise YTOutputNotIdentified(args, kwargs)
#      76     for n, c in output_type_registry.items():
#      77         if n is None: continue
#
# YTOutputNotIdentified: Supplied ('output_000010/info_000010.txt',) {}, but could not load!

# %%
ls
# Out:
# adaptive_loop.o           newdt_fine.o   output_00058/
# add_list.o                output_00001/  output_00059/
# amr_commons.mod           output_00002/  output_00060/
# amr_commons.o             output_00003/  output_00061/
# amr_parameters.mod        output_00004/  output_00062/
# amr_parameters.o          output_00005/  output_00063/
# amr_step.o                output_00006/  output_00064/
# bisection.mod             output_00007/  output_00065/
# bisection.o               output_00008/  output_00066/
# boundana.o                output_00009/  output_00067/
# boundary_potential.o      output_00010/  output_00068/
# clfind_commons.mod        output_00011/  output_00069/
# clfind_commons.o          output_00012/  output_00070/
# clump_finder.o            output_00013/  output_amr.o
# clump_merger.o            output_00014/  output_hydro.o
# condinit.o                output_00015/  output_part.o
# const.mod                 output_00016/  output_poisson.o
# cooling_fine.o            output_00017/  output_sink.o
# cooling_module.mod        output_00018/  particle_tree.o
# cooling_module.o          output_00019/  phi_fine_cg.o
# courant_fine.o            output_00020/  physical_boundaries.o
# feedback.o                output_00021/  pm_commons.mod
# flag_formation_sites.o    output_00022/  pm_commons.o
# flag_utils.o              output_00023/  pm_parameters.mod
# force_fine.o              output_00024/  pm_parameters.o
# gadgetreadfilemod.mod     output_00025/  poisson_commons.mod
# gadgetreadfile.o          output_00026/  poisson_commons.o
# godunov_fine.o            output_00027/  poisson_parameters.mod
# godunov_utils.o           output_00028/  poisson_parameters.o
# gravana.o                 output_00029/  ramses3d*
# hilbert.o                 output_00030/  ramses.o
# hydro_boundary.o          output_00031/  random.mod
# hydro_commons.mod         output_00032/  random.o
# hydro_commons.o           output_00033/  read_hydro_params.o
# hydro_flag.o              output_00034/  read_params.o
# hydro_parameters.mod      output_00035/  refine_utils.o
# hydro_parameters.o        output_00036/  remove_list.o
# init_amr.o                output_00037/  rho_ana.o
# init_flow_fine.o          output_00038/  rho_fine.o
# init_hydro.o              output_00039/  sink_particle.o
# init_part.o               output_00040/  sort.o
# init_poisson.o            output_00041/  sparse_mat.o
# init_refine.o             output_00042/  sparse_matrix.mod
# init_sink.o               output_00043/  star_formation.o
# init_time.o               output_00044/  synchro_fine.o
# interpol_hydro.o          output_00045/  synchro_hydro_fine.o
# interpol_phi.o            output_00046/  title.o
# light_cone.o              output_00047/  umuscl.o
# load_balance.o            output_00048/  units.o
# Makefile                  output_00049/  update_time.o
# Makefile.rt               output_00050/  uplmde.o
# move_fine.o               output_00051/  virtual_boundaries.o
# movie.o                   output_00052/  write_gitinfo.o
# multigrid_coarse.o        output_00053/  write_makefile.o
# multigrid_fine_coarse.o   output_00054/  write_patch.o
# multigrid_fine_commons.o  output_00055/  write_screen.o
# multigrid_fine_fine.o     output_00056/
# nbors_utils.o             output_00057/

# %% [markdown]
# # --------------------------------------------------------------------------------------------
