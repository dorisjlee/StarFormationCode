# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import plot_is

# %%
from matplotlib.legend_handler import HandlerLine2D
from scipy import integrate
from mpl_toolkits.axes_grid1 import AxesGrid
import yt
from yt.mods import *

# %%
yt.funcs.mylog.setLevel(50)

# %% [markdown]
# # Result from Foster and Chevalier's setup for $\xi_{max} = 6.451$

# %%
cd /project/projectdirs/astro250/doris/ramses4/trunk/ramses/bin
# Out:
# /global/project/projectdirs/astro250/doris/ramses4/trunk/ramses/bin

# %%
for i in np.arange(1,390):
    if i==1 or i%50 ==0: 
        plot_is.plot_time_slice("density",i,velocity=False)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
