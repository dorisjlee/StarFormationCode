# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
np.__version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8b93ebb06dfa> in <module>()
# ----> 1 np.__version__
#
# NameError: name 'np' is not defined

# %%
# sys.path.append('/global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/yt-3.2.2-py2.7-linux-x86_64.egg')

# %%
sys.path
sys.path.append('/global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/numpy-1.11.0.dev0_65aa24a-py2.7.egg-info')
sys.path.append('/global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/numpy-1.11.0.dev0+65aa24a-py2.7-linux-x86_64.egg')

# %%
import numpy as np
np.__version__
# Out:
# '1.9.2'

# %%
import yt
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-59dfcfe9846c> in <module>()
# ----> 1 import yt
#
# /global/homes/d/dorislee/mypackages/yt/__init__.py in <module>()
#     106     uunion1d
#     107
# --> 108 from yt.fields.api import \
#     109     field_plugins, \
#     110     DerivedField, \
#
# /global/homes/d/dorislee/mypackages/yt/fields/api.py in <module>()
#      17     field_plugins
#      18
# ---> 19 from . import angular_momentum
#      20 from . import astro_fields
#      21 from . import cosmology_fields
#
# /global/homes/d/dorislee/mypackages/yt/fields/angular_momentum.py in <module>()
#      29     register_field_plugin
#      30
# ---> 31 from .vector_operations import \
#      32      create_magnitude_field
#      33
#
# /global/homes/d/dorislee/mypackages/yt/fields/vector_operations.py in <module>()
#      29 from yt.funcs import just_one
# ...

# %%
import plot_is
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-050c8acc9697> in <module>()
# ----> 1 import plot_is
#
# /global/u2/d/dorislee/StarFormationCode/FosterChevalier_is/plot_is.py in <module>()
#      10 from pylab import *
#      11 from numpy import *
# ---> 12 import yt
#      13 yt.funcs.mylog.setLevel(50) #coerce output null
#      14
#
# /global/homes/d/dorislee/mypackages/yt/__init__.py in <module>()
#      97 from yt.utilities.logger import ytLogger as mylog
#      98
# ---> 99 import yt.utilities.physical_constants as physical_constants
#     100 import yt.units as units
#     101 from yt.units.yt_array import \
#
# AttributeError: 'module' object has no attribute 'utilities'

# %% [markdown]
# Doing this on the simple sink_test example

# %%
cd /project/projectdirs/astro250/doris/ramses/trunk/ramses/bin/
# Out:
# /global/project/projectdirs/astro250/doris/ramses/trunk/ramses/bin

# %%
import yt 
yt.funcs.mylog.setLevel(50)

# %%
plot_is.plot_time_slice("density", 1)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_is.plot_time_slice("density", 2)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# ### On the isothermal_sphere example

# %%
cd /project/projectdirs/astro250/doris/ramses3/trunk/ramses/bin/
# Out:
# /global/project/projectdirs/astro250/doris/ramses3/trunk/ramses/bin

# %%
plot_is.plot_time_slice("density", 1)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_is.plot_time_slice("density", 5)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# AMR working now, perhaps I need to lower the threshold

# %%
def plot_time_slice(physical_quantity,timestep,text="",title=""):
    ds= yt.load("output_{0}/info_{0}.txt".format(str(timestep).zfill(5)))
    slc = yt.SlicePlot(ds, "z",physical_quantity)
    slc.set_axes_unit('pc')
    slc.set_cmap(physical_quantity,"rainbow")
    slc.set_font_size(20)
    if title!="":
    	slc.annotate_title(title)
    if text!="":
	slc.annotate_text((0.1, 0.1),text, coord_system='axis')	
    slc.annotate_text((0.05, 0.05),"timestep: {}".format(timestep), coord_system='axis')
    slc.annotate_text((0.05, 0.02),"time: {} Myrs".format(timestep*61793.091/1000000.), coord_system='axis')
    slc.annotate_velocity()
#     slc.annotate_grids()
    slc.show()

# %%
plot_time_slice("radial_velocity",5)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_time_slice("density", 10)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
for i in np.arange(1,111):
    if i%10==0:
        plot_time_slice("density", i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-14c0967a35fe> in <module>()
#       1 for i in np.arange(1,111):
#       2     if i%10==0:
# ----> 3         plot_time_slice("density", i)
#
# NameError: name 'plot_time_slice' is not defined
