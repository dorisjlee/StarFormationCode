# %% [markdown]
# Since yt keep failing in notebook , I wrote a script to do this in terminal

# %%
cd /project/projectdirs/astro250/doris/ramses3/trunk/ramses/bin/
# Out:
# /global/project/projectdirs/astro250/doris/ramses3/trunk/ramses/bin

# %%
import IPython.core.display

# %%
IPython.display.Image("1_Slice_z_density.png")

# %%
ls *.png
# Out:
# 1_Slice_z_density.png  den1_Slice_z_density.png

# %%
IPython.display.Image("100_Slice_z_density.png")

# %% [markdown]
# Oops I made the mistake this is misleading this is actually 0.6 Myr because my dt is set as 1e-3, also I should just rerun this whol thing to make use of the whole cori node of 32 cores, actually lets try 64 cores
