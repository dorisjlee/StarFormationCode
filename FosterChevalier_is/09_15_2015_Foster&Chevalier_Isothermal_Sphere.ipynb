# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.remove('/global/homes/d/dorislee/.local/lib/python2.7/site-packages/yt-3.2.dev0-py2.7-linux-x86_64.egg')
sys.path.remove('/global/homes/d/dorislee/.local/lib/python2.7/site-packages')
sys.path.append('/global/homes/d/dorislee/mypythonpackages')
import yt
yt.funcs.mylog.setLevel(50) #coerce output null
# import plot_is

# %%
import plot_is

# %%
cd ~/ramses/trunk/ramses/bin/
# Out:
# /global/u2/d/dorislee/ramses/trunk/ramses/bin

# %%
plot_is.plot_time_slice("density",1)
# Out:
# //anaconda/lib/python2.7/site-packages/matplotlib/colorbar.py:839: RuntimeWarning: divide by zero encountered in true_divide
#   z = np.take(y, i0) + (xn - np.take(b, i0)) * dy / db
# <img src="data:image/png;base64,..."><br>

# %%
plot_is.plot_time_slice("density",2)
# Out:
# <img src="data:image/png;base64,..."><br>

# %% [markdown]
# changed dt =1e-3 to check what IC looks like

# %%
plot_is.plot_time_slice("density",2)
# Out:
# <img src="data:image/png;base64,..."><br>

# %%
plot_is.plot_time_slice("density",10)
# Out:
# <img src="data:image/png;base64,..."><br>

# %%
ds= yt.load("output_{0}/info_{0}.txt".format(str(2).zfill(5)))

# %%
all_data_level_0 = ds.covering_grid(level=0, left_edge=[0,0.0,0.0],dims=[64, 64, 64])

# %%
all_data_level_0['density'].shape
# Out:
# (64, 64, 64)

# %% [markdown]
# Right I forgot this needs to be done in 3D not 2D so my initialization was completely wrong because I only initialized a 32x32 slice and not a 32^3 simulation box !!

# %%
print frb1.data
# Out:
# {}

# %%
ds.all_data()
# Out:
# YTRegion (info_00002): center=[ 0.5  0.5  0.5] code_length, left_edge=[ 0.  0.  0.] code_length, right_edge=[ 1.  1.  1.] code_length
