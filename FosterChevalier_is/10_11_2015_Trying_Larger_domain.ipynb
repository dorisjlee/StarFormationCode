# %% [markdown]
# Looking at the resulting simulation I still see a bit of edge evffect even inthe levlmin=7 case so i went one level up again

# %%
import plot_is 
import yt

# %%
cd /project/projectdirs/astro250/doris/ramses2/trunk/ramses/bin/
# Out:
# /global/project/projectdirs/astro250/doris/ramses2/trunk/ramses/bin

# %%
# ls -d output_00*

# %%
plot_is.plot_time_slice("density",1)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_is.plot_time_slice("density",1,zoom_factor=2)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# Definitely need MPI here, 2 timesteps took 10 hours serially

# %%
plot_is.plot_time_slice("density",8)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
