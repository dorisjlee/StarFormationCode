# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import yt 
import plot_is

# %%
cd /project/projectdirs/astro250/doris/fc_is_data/
# Out:
# /global/project/projectdirs/astro250/doris/fc_is_data

# %%
plot_is.plot_time_slice?

# %%
plot_is.plot_time_slice("density",1,title='Density')
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
for i in np.arange(0,1800,100)[1:]: 
    plot_is.plot_time_slice("density",title='Density',i)
# Out:
#   File "<ipython-input-10-dc90adeccc01>", line 2
#     plot_is.plot_time_slice("density",title='Density',i)
# SyntaxError: non-keyword arg after keyword arg
