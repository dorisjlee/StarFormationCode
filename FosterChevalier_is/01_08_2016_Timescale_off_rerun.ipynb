# %%
# %pylab inline 
import plot_is
import yt
yt.funcs.mylog.setLevel(50)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd /project/projectdirs/astro250/doris/ramses7/trunk/ramses/bin
# Out:
# /global/project/projectdirs/astro250/doris/ramses7/trunk/ramses/bin

# %%
plot_is.check_IC_profiles()

# %%
plot_is.plot_time_slice("density",1,grid=True,plot_size=5)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_is.plot_time_slice("density",2,plot_size=5)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_is.plot_time_slice("density",15,plot_size=5)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_is.plot_time_slice("density",20,plot_size=5)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_is.plot_time_slice("density",30,plot_size=5)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_is.plot_time_slice("density",40,plot_size=5)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
timestep = 35
with open("output_{0}/info_{0}.txt".format(str(timestep).zfill(5)), 'r') as f:
    for i in f.readlines():
        if i[:4]=="time":
            print i
        if  i[:6]=="unit_t":
            print i
# Out:
# time        =  0.340000107107188E+02
#
# unit_t      =  0.195481556849940E+13

# %% [markdown]
# This is makes sense  because in my fc.nml file I had __delta_tout=1.0__

# %%
for i in np.arange(1,41):
    if i%10==0 :
        plot_is.plot_time_slice("radial_velocity",i,plot_size=5)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# This  whole run took up 100k hrs and took about 1 week to run

# %%
# for i in np.arange(1,180):
#     if i%20==0:
#         plot_is.plot_time_slice("density",i,plot_size=4)

# %%
0.06196*100.
# Out:
# 6.196

# %%
0.340000107107188E+02*0.195481556849940E+13 #equal to about 2.11 Myr
# Out:
# 66463750266459.45
