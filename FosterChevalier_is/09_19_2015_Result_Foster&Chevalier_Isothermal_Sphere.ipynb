# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.append('/global/homes/d/dorislee/mypackages')

# %%
import yt 
import plot_is

# %%
cd
# Out:
# /global/u2/d/dorislee

# %%
for i in np.arange(0,1100,100)[1:]: 
    plot_is.plot_time_slice("density",i)
# Out:
# /global/homes/d/dorislee/mypackages/yt/units/yt_array.py:795: RuntimeWarning: invalid value encountered in divide
#   return YTArray(super(YTArray, self).__div__(ro))
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
ds= yt.load("output_00234/info_00234.txt")
slc = yt.SlicePlot(ds, "z","density" ,window_size=7)
slc.set_font_size(20)
slc.annotate_title("Test")
slc.annotate_text((0.1, 0.1),"timestep :", coord_system='axis')
# slc = yt.SlicePlot(ds, 2, 'density')
# slc.set_font_size(22)
# slc.annotate_text((0.6, 0.6, 0.5), 'hello!')
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
ds= yt.load("output_00001/info_00001.txt")
slc = yt.SlicePlot(ds, "z","density" ,window_size=7)
slc.set_font_size(20)
title=yt.visualization.plot_modifications.TitleCallback("title")
title(slc)
# slc.annotate_title("Test")
slc.annotate_text((0,1),"timestep #:")
# Out:
# ---------------------------------------------------------------------------
# YTOutputNotIdentified                     Traceback (most recent call last)
# <ipython-input-9-fc5ce857c791> in <module>()
# ----> 1 ds= yt.load("output_00001/info_00001.txt")
#       2 slc = yt.SlicePlot(ds, "z","density" ,window_size=7)
#       3 slc.set_font_size(20)
#       4 title=yt.visualization.plot_modifications.TitleCallback("title")
#       5 title(slc)
#
# /global/homes/d/dorislee/mypackages/yt/convenience.pyc in load(*args, **kwargs)
#      72         mylog.error("None of the arguments provided to load() is a valid file")
#      73         mylog.error("Please check that you have used a correct path")
# ---> 74         raise YTOutputNotIdentified(args, kwargs)
#      75     for n, c in output_type_registry.items():
#      76         if n is None: continue
#
# YTOutputNotIdentified: Supplied ('output_00001/info_00001.txt',) {}, but could not load!

# %%
ds= yt.load("output_{0}/info_{0}.txt".format(str(2).zfill(5)))
all_data_level_6 = ds.covering_grid(level=6, left_edge=[0,0.0,0.0],dims=[32,32,32])
all_data_level_6['density'].shape
all_data_level_6['density']
# Out:
# (32, 32, 32)

# %% [markdown]
# Question
# - trouble compiling with MPI ?
