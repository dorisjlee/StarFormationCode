# %% [markdown]
# Setting up a uniform ambient box of low density gas

# %% [markdown]
# If use lev min =1 and lev max =2

# %% [raw]
#    ==> end step 3           0
#    Entering make_boundary_flag for level  1
#    Entering make_boundary_flag for level  1
#    Entering make_boundary_flag for level  1
#    ==> end step 4           0
#    ==> Flag      0 cells
#    Entering flag_coarse
#    ==> Flag      1 cells
#    Entering make_boundary_coarse
#  Initial mesh structure
#  Level  1 has          1 grids (       1,       1,       1,)
#  Starting time integration
#  Entering amr_step_coarse
#    Entering refine_coarse
#    Entering authorize_coarse
#    ==> Make      0 sub-grids
#    ==> Kill      0 sub-grids
#    Entering build_comm for level  1
#    Entering make_boundary_hydro for level  1
#  Entering amr_step1 for level 1
#    Entering refine_fine for level  1
#    Entering authorize_fine for level  1
#    Entering init_boundary_fine for level  1
#    Entering make_boundary_flag for level  1
#    ==> Make      0 sub-grids
#    ==> Kill      0 sub-grids
#    Entering build_comm for level  2
#    Entering make_boundary_hydro for level  2
#    Entering make_boundary_force for level  2
#    Entering update_cloud for level  1
#  sink drift due to accretion relative to grid size at level            1
#    Entering make_tree_fine for level  1
#  Defragmenting main memory...
#    Entering build_comm for level  1
#    Entering build_comm for level  2
#  Entering dump_all
#  Entering output_header
#  Entering output_info
#  Entering file_descriptor_hydro
#  Entering output_sink
#  Entering output_sink
#  Entering output_sink_csv
#  Entering backup_amr
#  Entering backup_hydro
#  Entering backup_part
#  Entering backup_sink
#  Entering backup_poisson
#    Entering rho_fine for level  1
#    Entering multipole_fine for level 1
#    Entering cic_from_multipole for level 1
#    Entering virtual_tree_fine for level  1
#    Entering synchro_hydro_fine for level 1
# Entering fine multigrid at level  1
#    Entering make_boundary_phi for level  1
#    Entering make_boundary_mask for level  1
#
# Program received signal SIGSEGV: Segmentation fault - invalid memory reference.
#
# Backtrace for this error:
# #0  0x2AAAAACE76C7
# #1  0x2AAAAACE7C94
# #2  0x2AAAAB6DB91F
# #3  0x4EC067 in restrict_residual_fine_reverse_ at multigrid_fine_fine.f90:509
# #4  0x4E9868 in multigrid_fine_ at multigrid_fine_commons.f90:198
# #5  0x42D18B in amr_step_ at amr_step.f90:215
# #6  0x42BA75 in adaptive_loop_ at adaptive_loop.f90:122
# #7  0x401B15 in ramses at ramses.f90:11
# #8  0x2AAAAB6C7C35
# Segmentation fault

# %%
import plot_is
import yt

# %% [raw]
#  Mesh structure
#  Level  1 has          1 grids (       1,       1,       1,)
#  Level  2 has          8 grids (       8,       8,       8,)
#  Level  3 has         64 grids (      64,      64,      64,)
#  Level  4 has        512 grids (     512,     512,     512,)
#  Level  5 has       4096 grids (    4096,    4096,    4096,)
#  Level  6 has      32768 grids (   32768,   32768,   32768,)
#  Main step=     9 mcons= 5.18E-10 econs= 2.53E-10 epot=-6.76E-14 ekin= 2.57E-01
#  Fine step=     9 t= 2.06759E-01 dt= 2.297E-02 a= 1.000E+00 mem= 0.2%  0.0%

# %%
cd /project/projectdirs/astro250/doris/ramses/trunk/ramses/bin/
# Out:
# /global/project/projectdirs/astro250/doris/ramses/trunk/ramses/bin

# %%
yt.funcs.mylog.setLevel(50)

# %%
plot_is.plot_time_slice("density",1)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_is.plot_time_slice("pressure",1)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# Adding one cell of rho_c

# %%
plot_is.plot_time_slice("density",1)
# Out:
# fmt = '=d' ; length = 4 ; size= 8
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-17-409fbf7c9434> in <module>()
# ----> 1 plot_is.plot_time_slice("density",1)
#
# plot_is.pyc in plot_time_slice(physical_quantity, timestep, text, title, zoom_factor)
#
# /global/homes/d/dorislee/mypackages/yt/visualization/plot_window.pyc in SlicePlot(ds, normal, fields, axis, *args, **kwargs)
#    2131             del kwargs['north_vector']
#    2132
# -> 2133         return AxisAlignedSlicePlot(ds, normal, fields, *args, **kwargs)
#
# /global/homes/d/dorislee/mypackages/yt/visualization/plot_window.pyc in __init__(self, ds, axis, fields, center, width, axes_unit, origin, fontsize, field_parameters, window_size, aspect, data_source)
#    1269         slc = ds.slice(axis, center[axis], field_parameters=field_parameters,
# ...

# %%
plot_is.plot_time_slice("density",3)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_is.plot_time_slice("density",1)
# Out:
# fmt = '=d' ; length = 4 ; size= 8
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-17-409fbf7c9434> in <module>()
# ----> 1 plot_is.plot_time_slice("density",1)
#
# plot_is.pyc in plot_time_slice(physical_quantity, timestep, text, title, zoom_factor)
#
# /global/homes/d/dorislee/mypackages/yt/visualization/plot_window.pyc in SlicePlot(ds, normal, fields, axis, *args, **kwargs)
#    2131             del kwargs['north_vector']
#    2132
# -> 2133         return AxisAlignedSlicePlot(ds, normal, fields, *args, **kwargs)
#
# /global/homes/d/dorislee/mypackages/yt/visualization/plot_window.pyc in __init__(self, ds, axis, fields, center, width, axes_unit, origin, fontsize, field_parameters, window_size, aspect, data_source)
#    1269         slc = ds.slice(axis, center[axis], field_parameters=field_parameters,
# ...

# %%
plot_is.plot_time_slice("density",5)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# No sink particle initiated

# %% [markdown]
# The cetral cell is not actually initiated , ``write(*,*)`` "central cell" is never called

# %% [raw]
# x,y,z:   0.703125000      0.859375000      -4.92187500
#  x,y,z:   -4.29687500      -4.14062500       7.81250000E-02
#  x,y,z:   0.703125000      -4.14062500       7.81250000E-02
#  x,y,z:   -4.29687500      0.859375000       7.81250000E-02
#  x,y,z:   0.703125000      0.859375000       7.81250000E-02
#  x,y,z:   -1.79687500      -4.14062500      -4.92187500
#  x,y,z:    3.20312500      -4.14062500      -4.92187500
#  x,y,z:   -1.79687500      0.859375000      -4.92187500
#  x,y,z:    3.20312500      0.859375000      -4.92187500

# %% [markdown]
# The xc,yc,zc are non integer values so the if condition we are using is bad

# %% [raw]
# dorislee@edison11:/project/projectdirs/astro250/doris/ramses/trunk/ramses/bin> ./ramses3d ../patch/hydro/sink_test/sink_test.nml
#  _/_/_/       _/_/     _/    _/    _/_/_/   _/_/_/_/    _/_/_/
#  _/    _/    _/  _/    _/_/_/_/   _/    _/  _/         _/    _/
#  _/    _/   _/    _/   _/ _/ _/   _/        _/         _/
#  _/_/_/     _/_/_/_/   _/    _/     _/_/    _/_/_/       _/_/
#  _/    _/   _/    _/   _/    _/         _/  _/               _/
#  _/    _/   _/    _/   _/    _/   _/    _/  _/         _/    _/
#  _/    _/   _/    _/   _/    _/    _/_/_/   _/_/_/_/    _/_/_/
#                          Version 3.0
#         written by Romain Teyssier (University of Zurich)
#                 (c) CEA 1999-2007, UZH 2008-2014
#
#  Working with nproc =    1 for ndim = 3
#  Using solver = hydro with nvar =  5
#
#  compile date = 11/07/15-17:10:04
#  patch dir    = ../patch/hydro/sink_test/
#  remote repo  = https://bitbucket.org/rteyssie/ramses
#  local branch = master
#  last commit  = fbfdbf1b291222e5b69d689c7069dcb9cfc9cf06
#
#  Found d_sink! Assuming code units
#  Building initial AMR grid
#  central cell
#  central cell
#  central cell
#  central cell
#  central cell
#  central cell
#  central cell
#  central cell
#  central cell
#  central cell
#  central cell
#  central cell
#  central cell
#  central cell
#  central cell
#  central cell
#  central cell
#  central cell
#  central cell
#  central cell
#  central cell
#  central cell
#  central cell
# ....(several thousands of the cells satisfies this ...)
#  central cell
#  central cell
#  central cell
#  central cell
#  central cell
#  Initial mesh structure
#  Level  1 has          1 grids (       1,       1,       1,)
#  Level  2 has          8 grids (       8,       8,       8,)
#  Level  3 has         64 grids (      64,      64,      64,)
#  Level  4 has        512 grids (     512,     512,     512,)
#  Level  5 has       4096 grids (    4096,    4096,    4096,)
#  Level  6 has      32768 grids (   32768,   32768,   32768,)
#  Starting time integration
#    ==> Level=    6 Step=    4 Error= 5.170E-05
#  Fine step=     0 t= 0.00000E+00 dt= 2.296E-02 a= 1.000E+00 mem= 0.2%  0.0%
#  Inside count_peaks in clump_finder ntest:          1728
#  Total number of density peaks found=      1000
#  Finding peak patches
#  Found        1000  relevant peaks
#  Found           1  halos
#  cpu            1  produces a new sink for clump number          551
#  cpu            1  produces a new sink for clump number          552
#  cpu            1  produces a new sink for clump number          553
#  cpu            1  produces a new sink for clump number          554
#  cpu            1  produces a new sink for clump number          555
#  cpu            1  produces a new sink for clump number          556
#  cpu            1  produces a new sink for clump number          545
#  cpu            1  produces a new sink for clump number          546
#  cpu            1  produces a new sink for clump number          547
#  cpu            1  produces a new sink for clump number          548
#  cpu            1  produces a new sink for clump number          549
#  cpu            1  produces a new sink for clump number          550
#  cpu            1  produces a new sink for clump number          563
#  ....
#  cpu            1  produces a new sink for clump number          981
#  cpu            1  produces a new sink for clump number          982
#  cpu            1  produces a new sink for clump number          983
#  cpu            1  produces a new sink for clump number          984
#  cpu            1  produces a new sink for clump number          985
#  cpu            1  produces a new sink for clump number          986
#  cpu            1  produces a new sink for clump number          996
#  cpu            1  produces a new sink for clump number          995
#  cpu            1  produces a new sink for clump number          994
#  cpu            1  produces a new sink for clump number          993
#  cpu            1  produces a new sink for clump number          997
#  cpu            1  produces a new sink for clump number          998
#  cpu            1  produces a new sink for clump number          999
#  cpu            1  produces a new sink for clump number         1000
#  Level =      6 New sinks produced from clumps=    298 Total sinks =     298
#  merged            3  to            1
#  merged            4  to            1
#  merged            5  to            1
#  merged            6  to            1
#  merged            7  to            1
#  merged            8  to            1
#  merged           10  to            1
# ......
#  merged          255  to          213
#  merged          256  to          213
#  merged          257  to          213
#  merged          258  to          213
#  merged          290  sinks
#  No more free memory
#  in PE            1
#  Increase npartmax
#
#      seconds         %    STEP (rank=      1)
#        0.009       0.2    coarse levels
#        0.010       0.2    refine
#        2.816      56.4    io
#        0.842      16.9    poisson
#        0.042       0.8    courant
#        0.005       0.1    hydro - set unew
#        1.155      23.1    hydro - godunov
#        0.017       0.3    hydro - set uold
#        0.042       0.8    cooling
#        0.006       0.1    hydro - ghostzones
#        0.044       0.9    flag
#        4.994     100.0    TOTAL

# %%
plot_is.plot_time_slice("density",1)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# Putting in the new code forced for npart max

# %% [raw]
#  merged          232  to           65
#  merged          233  to           65
#  merged          234  to           65
#  merged          237  to           65
#  merged          239  to           65
#  merged          259  to           65
#  merged          260  to           65
#  merged          261  to           65
#  merged          262  to           65
#  merged          263  to           65
#  merged          264  to           65
#  merged          271  to           65
#  merged          272  to           65
#  merged          273  to           65
#  merged          274  to           65
#  merged          275  to           65
#  merged          276  to           65
#  merged          140  to          139
#  merged          141  to          139
#  merged          142  to          139
#  merged          143  to          139
#  merged          144  to          139
#  merged          145  to          139
#  merged          146  to          139
#  merged          147  to          139
#  merged          148  to          139
#  merged          149  to          139
#  merged          150  to          139
#  merged          151  to          139
#  merged          152  to          139
#  merged          153  to          139
#  merged          154  to          139
#  merged          155  to          139
#  merged          156  to          139
#  merged          157  to          139
#  merged          158  to          139
#  merged          159  to          139
#  merged          160  to          139
#  merged          162  to          139
#  merged          163  to          139
#  merged          164  to          139
#  merged          166  to          139
#  merged          167  to          139
#  merged          168  to          139
#  merged          169  to          139
#  merged          180  to          139
#  merged          181  to          139
#  merged          189  to          139
#  merged          190  to          139
#  merged          191  to          139
#  merged          192  to          139
#  merged          193  to          139
#  merged          194  to          139
#  merged          209  to          139
#  merged          175  to          174
#  merged          176  to          174
#  merged          177  to          174
#  merged          178  to          174
#  merged          179  to          174
#  merged          182  to          174
#  merged          183  to          174
#  merged          184  to          174
#  merged          185  to          174
#  merged          186  to          174
#  merged          187  to          174
#  merged          188  to          174
#  merged          201  to          174
#  merged          202  to          174
#  merged          265  to          174
#  merged          266  to          174
#  merged          267  to          174
#  merged          268  to          174
#  merged          269  to          174
#  merged          270  to          174
#  merged          214  to          213
#  merged          252  to          213
#  merged          253  to          213
#  merged          254  to          213
#  merged          255  to          213
#  merged          256  to          213
#  merged          257  to          213
#  merged          258  to          213
#  merged          290  sinks
#  Number of sink =            8
#  Total mass in sink =    7.6179098898219617E-013
#  simulation time =    2.2958711545303597E-002
#  ================================================================================================================================================
#    Id     M[Msol]          x             y             z            vx            vy            vz    acc_rate[Msol/y] acc_lum[Lsol]     age
#  ================================================================================================================================================
#     2   0.16105E-12   0.46267E+01   0.51264E+01   0.51407E+01   0.92080E-03  -0.41700E-03  -0.44977E-03   0.11317E-15   0.00000E+00   0.00000E+00
#     9   0.14316E-12   0.52126E+01   0.46186E+01   0.51535E+01  -0.63525E-03   0.93811E-03  -0.47330E-03   0.10059E-15   0.00000E+00   0.00000E+00
#     1   0.12782E-12   0.52648E+01   0.53131E+01   0.53261E+01  -0.74764E-03  -0.85752E-03  -0.89290E-03   0.89814E-16   0.00000E+00   0.00000E+00
#   139   0.97141E-13   0.51949E+01   0.53317E+01   0.45884E+01  -0.57664E-03  -0.91850E-03   0.10000E-02   0.68258E-16   0.00000E+00   0.00000E+00
#    65   0.94585E-13   0.51334E+01   0.46165E+01   0.45745E+01  -0.41978E-03   0.89866E-03   0.10489E-02   0.66462E-16   0.00000E+00   0.00000E+00
#    30   0.61352E-13   0.45233E+01   0.45563E+01   0.50629E+01   0.11472E-02   0.10512E-02  -0.23103E-03   0.43111E-16   0.00000E+00   0.00000E+00
#   174   0.53683E-13   0.45205E+01   0.51684E+01   0.45230E+01   0.11406E-02  -0.49833E-03   0.11265E-02   0.37722E-16   0.00000E+00   0.00000E+00
#   213   0.23007E-13   0.46424E+01   0.45206E+01   0.44857E+01   0.77386E-03   0.10626E-02   0.11807E-02   0.16166E-16   0.00000E+00   0.00000E+00
#  ================================================================================================================================================
# *** glibc detected *** ./ramses3d: double free or corruption (!prev): 0x0000000000b588e0 ***
# ======= Backtrace: =========
# /lib64/libc.so.6(+0x76b18)[0x2aaaab71fb18]
# /lib64/libc.so.6(cfree+0x6c)[0x2aaaab724b5c]
# ./ramses3d[0x44023d]
# ./ramses3d[0x42beda]
# ./ramses3d[0x401b16]
# /lib64/libc.so.6(__libc_start_main+0xe6)[0x2aaaab6c7c36]
# ./ramses3d[0x401b49]
# ======= Memory map: ========
# 00400000-0050b000 r-xp 00000000 00:23 561852759                          /global/project/projectdirs/astro250/doris/ramses/trunk/ramses/bin/ramses3d
# 0070b000-0070c000 r-xp 0010b000 00:23 561852759                          /global/project/projectdirs/astro250/doris/ramses/trunk/ramses/bin/ramses3d
# 0070c000-00717000 rwxp 0010c000 00:23 561852759                          /global/project/projectdirs/astro250/doris/ramses/trunk/ramses/bin/ramses3d
# 00717000-00e2a000 rwxp 00000000 00:00 0                                  [heap]
# 2aaaaaaab000-2aaaaaaca000 r-xp 00000000 08:05 36102430                   /lib64/ld-2.11.3.so
# 2aaaaaaca000-2aaaaaacb000 r-xp 00000000 00:00 0                          [vdso]
# 2aaaaaacb000-2aaaaaacc000 rwxp 00000000 00:00 0
# 2aaaaacc9000-2aaaaacca000 r-xp 0001e000 08:05 36102430                   /lib64/ld-2.11.3.so
# 2aaaaacca000-2aaaaaccb000 rwxp 0001f000 08:05 36102430                   /lib64/ld-2.11.3.so
# 2aaaaaccb000-2aaaaaccc000 rwxp 00000000 00:00 0
# 2aaaaaccc000-2aaaaade0000 r-xp 00000000 08:05 6791248                    /usr/lib64/libgfortran.so.3.0.0
# 2aaaaade0000-2aaaaafdf000 ---p 00114000 08:05 6791248                    /usr/lib64/libgfortran.so.3.0.0
# 2aaaaafdf000-2aaaaafe0000 r-xp 00113000 08:05 6791248                    /usr/lib64/libgfortran.so.3.0.0
# 2aaaaafe0000-2aaaaafe2000 rwxp 00114000 08:05 6791248                    /usr/lib64/libgfortran.so.3.0.0
# 2aaaaafe2000-2aaaaafe3000 rwxp 00000000 00:00 0
# 2aaaaafe3000-2aaaab03e000 r-xp 00000000 08:05 17211414                   /lib64/libm-2.11.3.so
# 2aaaab03e000-2aaaab23d000 ---p 0005b000 08:05 17211414                   /lib64/libm-2.11.3.so
# 2aaaab23d000-2aaaab23e000 r-xp 0005a000 08:05 17211414                   /lib64/libm-2.11.3.so
# 2aaaab23e000-2aaaab25c000 rwxp 0005b000 08:05 17211414                   /lib64/libm-2.11.3.so
# 2aaaab25c000-2aaaab271000 r-xp 00000000 08:05 17211419                   /lib64/libgcc_s.so.1
# 2aaaab271000-2aaaab470000 ---p 00015000 08:05 17211419                   /lib64/libgcc_s.so.1
# 2aaaab470000-2aaaab471000 r-xp 00014000 08:05 17211419                   /lib64/libgcc_s.so.1
# 2aaaab471000-2aaaab472000 rwxp 00015000 08:05 17211419                   /lib64/libgcc_s.so.1
# 2aaaab472000-2aaaab4a7000 r-xp 00000000 08:05 6776060                    /usr/lib64/libquadmath.so.0.0.0
# 2aaaab4a7000-2aaaab6a6000 ---p 00035000 08:05 6776060                    /usr/lib64/libquadmath.so.0.0.0
# 2aaaab6a6000-2aaaab6a7000 r-xp 00034000 08:05 6776060                    /usr/lib64/libquadmath.so.0.0.0
# 2aaaab6a7000-2aaaab6a8000 rwxp 00035000 08:05 6776060                    /usr/lib64/libquadmath.so.0.0.0
# 2aaaab6a8000-2aaaab6a9000 rwxp 00000000 00:00 0
# 2aaaab6a9000-2aaaab819000 r-xp 00000000 08:05 17211406                   /lib64/libc-2.11.3.so
# 2aaaab819000-2aaaaba18000 ---p 00170000 08:05 17211406                   /lib64/libc-2.11.3.so
# 2aaaaba18000-2aaaaba1c000 r-xp 0016f000 08:05 17211406                   /lib64/libc-2.11.3.so
# 2aaaaba1c000-2aaaaba1d000 rwxp 00173000 08:05 17211406                   /lib64/libc-2.11.3.so
# 2aaaaba1d000-2ab3ec9c2000 rwxp 00000000 00:00 0
# 2ab3f0000000-2ab3f0021000 rwxp 00000000 00:00 0
# 2ab3f0021000-2ab3f4000000 ---p 00000000 00:00 0
# 7ffffffd9000-7ffffffff000 rwxp 00000000 00:00 0                          [stack]
# ffffffffff600000-ffffffffff601000 r-xp 00000000 00:00 0                  [vsyscall]
#
# Program received signal SIGABRT: Process abort signal.
#
# Backtrace for this error:

# %% [markdown]
# The good news is that the sink particles looks like they are getting initiated at values very close to x,y,z =0 , and with a very small velocity so this is good

# %% [markdown]
# Actually setting n_part_max

# %% [raw]
# merged          257  to          213
#  merged          258  to          213
#  merged          290  sinks
#  numbp_free:            0
#  numbp_free:           -1
#  No more free memory
#  in PE            1
#  Increase npartmax
#
#      seconds         %    STEP (rank=      1)
#        0.009       0.2    coarse levels
#        0.010       0.2    refine
#        2.663      54.6    io
#        0.853      17.5    poisson
#        0.041       0.8    courant
#        0.006       0.1    hydro - set unew
#        1.182      24.2    hydro - godunov
#        0.018       0.4    hydro - set uold
#        0.042       0.9    cooling
#        0.006       0.1    hydro - ghostzones
#        0.044       0.9    flag
#        4.880     100.0    TOTAL

# %% [raw]
# ../pm/star_formation.f90:255:  numbp_free_tot=numbp_free
# ../pm/pm/add_list.f90:77:     if(numbp_free>0)then
# ../pm/pm/add_list.f90:83:        numbp_free=numbp_free+1
# ../pm/pm/add_list.f90:90:        numbp_free=1
# ../pm/pm/add_list.f90:93:  npart=npartmax-numbp_free
# ../pm/pm/add_list.f90:145:        if(numbp_free>0)then
# ../pm/pm/add_list.f90:151:           numbp_free=numbp_free+1
# ../pm/pm/add_list.f90:158:           numbp_free=1

# %% [markdown]
# intuitively npartmax should have effected numbpfree but no effect
