# %%
# %pylab inline 
import plot_is
import yt
yt.funcs.mylog.setLevel(50)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd /project/projectdirs/astro250/doris/ramses/trunk/ramses/bin
# Out:
# /global/project/projectdirs/astro250/doris/ramses/trunk/ramses/bin

# %%
plot_is.check_IC_profiles()
# Out:
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:645: RuntimeWarning: divide by zero encountered in double_scalars
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:645: RuntimeWarning: invalid value encountered in multiply
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:701: RuntimeWarning: invalid value encountered in less
#   short = np.repeat(length < minsh, 8, axis=1)
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:711: RuntimeWarning: invalid value encountered in less
#   tooshort = length < self.minlength

# %%
ls
# Out:
# 826773.err              hydro_boundary.o          output_00018/
# 826773.out              hydro_commons.mod         output_amr.o
# 826810.err              hydro_commons.o           output_hydro.o
# 826810.out              hydro_flag.o              output_part.o
# 826894.err              hydro_parameters.mod      output_poisson.o
# 826894.out              hydro_parameters.o        output_sink.o
# 827021.err              ic_sink                   particle_tree.o
# 827021.out              ic_sink_restart           phi_fine_cg.o
# 827038.err              init_amr.o                physical_boundaries.o
# 827038.out              init_flow_fine.o          pm_commons.mod
# 827146.err              init_hydro.o              pm_commons.o
# 827146.out              init_part.o               pm_parameters.mod
# 829230.err              init_poisson.o            pm_parameters.o
# 829230.out              init_refine.o             poisson_commons.mod
# 829233.err              init_sink.o               poisson_commons.o
# 829233.out              init_time.o               poisson_parameters.mod
# adaptive_loop.o         interpol_hydro.o          poisson_parameters.o
# add_list.o              interpol_phi.o            ramses3d*
# amr_commons.mod         light_cone.o              ramses.o
# amr_commons.o           load_balance.o            random.mod
# amr_parameters.mod      Makefile                  random.o
# amr_parameters.o        Makefile.rhd              read_hydro_params.o
# amr_step.o              Makefile.rt               read_params.o
# bisection.mod           move_fine.o               refine_utils.o
# bisection.o             movie.o                   remove_list.o
# boundana.o              multigrid_coarse.o        rho_ana.o
# boundary_potential.o    multigrid_fine_coarse.o   rho_fine.o
# clfind_commons.mod      multigrid_fine_commons.o  sink/
# clfind_commons.o        multigrid_fine_fine.o     sink_particle.o
# clump_finder.o          nbors_utils.o             sort.o
# clump_merger.o          newdt_fine.o              sparse_mat.o
# condinit.o              output_00001/             sparse_matrix.mod
# const.mod               output_00002/             srun.pbs
# cooling_fine.o          output_00003/             star_formation.o
# cooling_module.mod      output_00004/             synchro_fine.o
# cooling_module.o        output_00005/             synchro_hydro_fine.o
# courant_fine.o          output_00006/             timer_m.mod
# debug_srun.pbs          output_00007/             title.o
# feedback.o              output_00008/             umuscl.o
# flag_formation_sites.o  output_00009/             units.o
# flag_utils.o            output_00010/             update_time.o
# force_fine.o            output_00011/             uplmde.o
# gadgetreadfilemod.mod   output_00012/             virtual_boundaries.o
# gadgetreadfile.o        output_00013/             write_gitinfo.o
# godunov_fine.o          output_00014/             write_makefile.o
# godunov_utils.o         output_00015/             write_patch.o
# gravana.o               output_00016/             write_screen.o
# hilbert.o               output_00017/

# %%
# for i in np.arange(1,180):
#     if i%20==0:
#         plot_is.plot_time_slice("density",i,plot_size=4)

# %%
cd /project/projectdirs/astro250/doris/ramses4/trunk/ramses/bin
# Out:
# /global/project/projectdirs/astro250/doris/ramses4/trunk/ramses/bin

# %%
plot_is.check_IC_profiles()

# %%
for i in np.arange(1,346):
    if i%50==0:
        plot_is.plot_time_slice("density",i,plot_size=4)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
