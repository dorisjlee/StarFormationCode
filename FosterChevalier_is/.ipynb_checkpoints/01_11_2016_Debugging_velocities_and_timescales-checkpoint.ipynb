# %%
# %pylab inline 
import plot_is
import yt
yt.funcs.mylog.setLevel(50)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # With gravity, Marginally stable case $\xi =6.470001$

# %% [markdown]
# Inside ramses4/

# %%
cd /project/projectdirs/astro250/doris/ramses4/trunk/ramses/bin
# Out:
# /global/project/projectdirs/astro250/doris/ramses4/trunk/ramses/bin

# %%
plot_is.check_IC_profiles()

# %%
plot_is.plot_time_slice("radial_velocity",100,plot_size=6)#,log=False)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_is.plot_time_slice("radial_velocity",150,plot_size=6)#,log=False)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_is.plot_time_slice("radial_velocity",300,plot_size=6)#,log=False)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_is.plot_time_slice("radial_velocity",600,plot_size=6)#,log=False)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_is.plot_time_slice("radial_velocity",700,plot_size=6)#,log=False)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# This looks like the plots [here](http://nbviewer.ipython.org/github/dorislee0309/StarFormationCode/blob/master/FosterChevalier_is/11_28_2015AMR_comparison.ipynb) if I pull the same colormap for all time

# %%
plot_is.plot_time_slice("radial_velocity",700,plot_size=6,zmin=-1e3, zmax=1e3)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# #### Coarsen grid to level=5

# %%
cd /project/projectdirs/astro250/doris/ramses6/trunk/ramses/bin
# Out:
# /global/project/projectdirs/astro250/doris/ramses6/trunk/ramses/bin

# %%
for i in np.arange(1,201):
    if i%50==0 or i==1 :
        plot_is.plot_time_slice("density",i,plot_size=6,zmin=1e-26,zmax=1e-19)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
for i in np.arange(1,201):
    if i%100==0:
        plot_is.plot_time_slice("radial_velocity",i,plot_size=6,zmin=1e-26,zmax=1e-19,log=False)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# This is a bit too coarse, but activating AMR to level=[5,7] is slow

# %% [markdown]
# #### level = 6

# %%
plot_is.plot_time_slice("density",1,plot_size=6,zmin=1e-26,zmax=1e-19)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_is.plot_time_slice("density",7,plot_size=6,zmin=1e-26,zmax=1e-19)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
for i in np.arange(1,201):
    if i%50==0 or i==1 :
        plot_is.plot_time_slice("density",i,plot_size=6,zmin=1e-26,zmax=1e-19)
