# %% [raw]
# module load cray-hdf5

# %% [markdown]
# remember to use make -j or everything is going to be super slow

# %% [raw]
# aprun -n 24 ./flash4

# %% [markdown]
# Ok got this runnning MPI

# %% [markdown]
# Here are the output files , load them onto ramses

# %% [raw]
# dorislee@nid00896:/project/projectdirs/astro250/doris/FLASH4.3/object> vim sedov
# sedov.dat                       sedov_hdf5_chk_0000             sedov_hdf5_chk_0002             sedov_hdf5_chk_0004             sedov_hdf5_plt_cnt_0000
# sedov_forced_hdf5_plt_cnt_0000  sedov_hdf5_chk_0001             sedov_hdf5_chk_0003             sedov_hdf5_chk_0005             sedov.log

# %% [markdown]
# plot files are for plotting; check files are for restarts. they are spat out at different rates

# %%
# %pylab inline
import yt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd /project/projectdirs/astro250/doris/FLASH4.3/object
# Out:
# /global/project/projectdirs/astro250/doris/FLASH4.3/object

# %%
yt.funcs.mylog.setLevel(50) #coerce output null

# %%
for i in np.arange(1,6):
    ds = yt.load("sedov_hdf5_chk_000{}".format(i))
    physical_quantity="density"
    slc = yt.SlicePlot(ds, "z",physical_quantity)
    slc.annotate_velocity()
    slc.annotate_grids()
    slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
6
