# %%
# %pylab inline
import plot_is
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# this is inside sink/

# %% [markdown]
# Rethnking about the sink simple test case, dont' use clumpfind just simply put a particle down

# %%
cd /project/projectdirs/astro250/doris/sink/trunk/ramses/bin
# Out:
# /global/project/projectdirs/astro250/doris/sink/trunk/ramses/bin

# %%
plot_is.plot_time_slice("density",1,plot_size=3,zmin=1e-26,zmax=1e-19)
plot_is.plot_time_slice("density",2,plot_size=3,zmin=1e-26,zmax=1e-19)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# Sink with MPI now works, no idea why... the cube is expanding so the contracting criterion is false, so no sink formation

# %%
plot_is.check_IC_profiles()

# %% [markdown]
# forcing very high pressure on outside to force collapse not expansion

# %% [raw]
# if ((int(xc) .eq. 0) .and.(int(yc) .eq. 0).and. (int(zc) .eq. 0))then
#         q(i,5)=0.5
#      else
#         q(i,5)=1000.

# %%
plot_is.check_IC_profiles()

# %%
plot_is.plot_time_slice("density",2,plot_size=3,zmin=1e-26,zmax=1e-19)
# plot_is.plot_time_slice("density",10,plot_size=3,zmin=1e-26,zmax=1e-19)
# Out:
# ---------------------------------------------------------------------------
# YTOutputNotIdentified                     Traceback (most recent call last)
# <ipython-input-15-c46889b4d688> in <module>()
# ----> 1 plot_is.plot_time_slice("density",2,plot_size=3,zmin=1e-26,zmax=1e-19)
#       2 # plot_is.plot_time_slice("density",10,plot_size=3,zmin=1e-26,zmax=1e-19)
#
# plot_is.pyc in plot_time_slice(physical_quantity, timestep, zmin, zmax, text, title, zoom_factor, velocity, grid, save, log, plot_size)
#
# /global/homes/d/dorislee/anaconda/lib/python2.7/site-packages/yt/convenience.pyc in load(*args, **kwargs)
#      72         mylog.error("None of the arguments provided to load() is a valid file")
#      73         mylog.error("Please check that you have used a correct path")
# ---> 74         raise YTOutputNotIdentified(args, kwargs)
#      75     for n, c in output_type_registry.items():
#      76         if n is None: continue
#
# ...
