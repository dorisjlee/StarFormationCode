# %%
Submitting job

# %%
(2**9)**3/48

# %%
&CLUMPFIND_PARAMS
density_threshold=0.03
/

# %% [markdown]
# rho_c in condinit is 0.02806

# %% [markdown]
# so I set rho threshold  as 0.02 instead

# %%
forrtl: severe (174): SIGSEGV, segmentation fault occurred

# %% [markdown]
# running works without sink particle but when sink particle is added then seg fault, the gdb debugger output was not enlightening

# %% [markdown]
# increasing my ngridtot to 300000

# %% [markdown]
# But this does work if I have no MPI

# %% [raw]
# Building initial AMR grid
#  Looking for file ic_sink: ic_sink
#  finished init_sink
#  Initial mesh structure

# %% [markdown]
# With a densty_threshold of 0.028 the sink particle still not activated
#
# So now switch to density thredhold of 0.02 still not activated

# %% [markdown]
# Now try absurdly small rho (1e-5)  to see if there is many sinks

# %% [markdown]
# Nothing happens

# %% [markdown]
# I'm just going to submit a job using MPI with ramses2 which is a levelmin 8 grid for now(no sink)

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import plot_is
import yt

# %%
cd /project/projectdirs/astro250/doris/ramses3/trunk/ramses/bin
# Out:
# /global/project/projectdirs/astro250/doris/ramses3/trunk/ramses/bin

# %%
cd data_10_10_2015/
# Out:
# /global/project/projectdirs/astro250/doris/ramses3/trunk/ramses/bin/data_10_10_2015

# %%
timestep=30
ds= yt.load("output_{0}/info_{0}.txt".format(str(timestep).zfill(5)))
# slc = yt.SlicePlot(ds, "z",physical_quantity)
# slc.set_axes_unit('pc')
# slc.set_cmap(physical_quantity,"rainbow")
# slc.set_font_size(20)
# if title!="":
#     slc.annotate_title(title)
# if text!="":
# slc.annotate_text((0.1, 0.1),text, coord_system='axis')	
# slc.annotate_text((0.05, 0.05),"timestep: {}".format(timestep), coord_system='axis')
# slc.annotate_text((0.05, 0.02),"time: {} Myrs".format(timestep*61793.091/1000000.), coord_system='axis')
# slc.annotate_velocity()
# slc.annotate_grids()
# slc.show()

# %%
# ds.field_info
# data = ds.all_data()
# data["x"]
# vx = data['velocity_x']
# vx = data['velocity_x']
# vrad = data["radial_velocity"]

# %% [markdown]
# derived quantity is bad all the array is zero, should probably write my own

# %% [markdown]
# Oh wait this is the first timestep  that's why there's no radial velocities oops, so this thing is actually working, I don't have to write my own derived quantiity then.

# %%
for timestep in np.arange(1,209):
    if timestep%10==0 :
        ds= yt.load("output_{0}/info_{0}.txt".format(str(timestep).zfill(5)))
        slc = yt.SlicePlot(ds,"x","radial_velocity")
        slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# ...

# %% [markdown]
# So clearly the radial velocities gets weird and the four sides (non sphereical) as time evolves (its initally kind of spherical but it should stay like that)
