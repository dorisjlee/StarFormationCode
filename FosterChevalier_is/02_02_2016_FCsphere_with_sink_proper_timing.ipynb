# %%
# %pylab inline 
import plot_is
import yt
yt.funcs.mylog.setLevel(50)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Inside ramses/

# %% [markdown]
# For debugging purposes, I've relaxed the err_grad_d condition a bit from 1e-3 to 0.1 so that AMR is not that intense.

# %% [markdown]
# turned courant_factor to something larger so that timesteps are not that constraining
#
# courant_factor =0.5 --> 0.8

# %% [markdown]
# The delta_tout = 1.0 = T_scale = 0.06196 Myr
#
# Tff = 6.66 Myr so about 107 timesteps $\approx$ 1 t_{ff}

# %%
cd /project/projectdirs/astro250/doris/ramses/trunk/ramses/bin
# Out:
# /global/project/projectdirs/astro250/doris/ramses/trunk/ramses/bin

# %% [raw]
# levelmin=5
# levelmax=8

# %%
plot_is.plot_time_slice("density",1,grid=True)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# This seemed a bit too fine, I lowered the levelmin

# %% [raw]
# levelmin=3
# levelmax=8

# %%
plot_is.plot_time_slice("density",1,grid=True)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_is.plot_time_slice("density",2,grid=True)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# that's no good...

# %% [raw]
# levelmin=4
# levelmax=7

# %%
plot_is.plot_time_slice("density",1,grid=True)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_is.plot_time_slice("density",2,grid=True)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_is.plot_time_slice("density",11,velocity=False)#,grid=True)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
plot_is.plot_time_slice("density",11,velocity=True)#,grid=True)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
