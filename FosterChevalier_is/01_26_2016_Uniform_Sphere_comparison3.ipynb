# %% [markdown]
# Tried another 3 level one (last one was 4 levels) also finer timesteps

# %%
# %pylab inline 
import plot_is
import yt
yt.funcs.mylog.setLevel(50)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd /project/projectdirs/astro250/doris/uniform_sphere/trunk/ramses/bin
# Out:
# /global/project/projectdirs/astro250/doris/uniform_sphere/trunk/ramses/bin

# %%
plot_is.check_IC_profiles()

# %%
def plot_time_slice(physical_quantity,timestep,zmin="",zmax="" ,text="",title="",zoom_factor="",velocity=True,grid=False,save=False,log=True,plot_size=5):
    ds= yt.load("output_{0}/info_{0}.txt".format(str(timestep).zfill(5)))
    slc = yt.SlicePlot(ds, "y",physical_quantity)
#     if axes_unit!="":
#         slc.set_axes_unit(axes_unit)
    slc.set_figure_size(plot_size)
    slc.set_font_size(plot_size*2.5)
    if (log==False):
	slc.set_log(physical_quantity, False)
    if zoom_factor!="":
        slc.zoom(zoom_factor)
    if zmin!="" and zmax!="":
        slc.set_zlim(physical_quantity, zmin,zmax)
    if title!="":
    	slc.annotate_title(title)
    slc.annotate_text((0.05, 0.05),"timestep: {}".format(timestep-1), coord_system='axis')
    if (velocity):
        slc.annotate_velocity()
    if(grid): 
        slc.annotate_grids()
    if (save):
       name  =str(timestep)#physical_quantity[:3]+str(timestep)
       slc.save(name)
    else:
       slc.show()

# %%
plot_time_slice("density",1,grid=True, velocity=False,plot_size=5,log=False)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
for i in np.arange(1,21):
    if i%2==0 or i==1:
        plot_time_slice("density",i,velocity=False, plot_size=5)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
for i in  np.arange(1,21):
    if i%2==0 or i==1:
        plot_time_slice("radial_velocity",i,plot_size=5,velocity=False)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# # Plus Sink Particle

# %%
for i in np.arange(1,21):
    if i%2==0 or i==1:
        plot_time_slice("density",i,velocity=False, plot_size=5)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# ---------------------------------------------------------------------------
# YTOutputNotIdentified                     Traceback (most recent call last)
# <ipython-input-13-3b868145dc2d> in <module>()
#       1 for i in np.arange(1,21):
#       2     if i%2==0 or i==1:
# ----> 3         plot_time_slice("density",i,velocity=False, plot_size=5)
#
# <ipython-input-4-40982271d345> in plot_time_slice(physical_quantity, timestep, zmin, zmax, text, title, zoom_factor, velocity, grid, save, log, plot_size)
#       1 def plot_time_slice(physical_quantity,timestep,zmin="",zmax="" ,text="",title="",zoom_factor="",velocity=True,grid=False,save=False,log=True,plot_size=5):
# ----> 2     ds= yt.load("output_{0}/info_{0}.txt".format(str(timestep).zfill(5)))
#       3     slc = yt.SlicePlot(ds, "y",physical_quantity)
#       4 #     if axes_unit!="":
#       5 #         slc.set_axes_unit(axes_unit)
#
# ...

# %% [markdown]
# The timstep got extremely small when there's sink, not too sure why .

# %% [raw]
#  Entering make_boundary_force for level  6
#    Entering synchro_fine for level  6
#    Entering synchro_hydro_fine for level 6
#    Entering make_boundary_hydro for level  6
#    Entering collect_acczone_avg for level  6
#    Entering newdt_fine for level  6
#  dt_acc/dt    0.050141      limited by sink:           1
#    Entering courant_fine for level  6
#    Entering set_unew for level  6
#  Mesh structure
#  Level  1 has          1 grids (       1,       1,       1,)
#  Level  2 has          8 grids (       8,       8,       8,)
#  Level  3 has         64 grids (      64,      64,      64,)
#  Level  4 has        512 grids (     512,     512,     512,)
#  Level  5 has       4096 grids (    4096,    4096,    4096,)
#  Level  6 has      32768 grids (   32768,   32768,   32768,)
#  Main step=  1236 mcons=-1.19E-01 econs=-1.00E+00 epot=-2.84E-03 ekin= 1.05E-11
#  Fine step=  1236 t= 1.03244E-20 dt= 7.413E-24 a= 1.000E+00 mem= 0.2%  0.0%
#  Entering update_sink for level            6
#    Entering grow_sink for level  6
#    Entering godunov_fine for level  6

# %% [raw]
#  Entering make_boundary_hydro for level  4
#    Entering update_cloud for level  4
#  sink drift due to accretion relative to grid size at level            4
#  #sink:            1  drift:   1.212140296897683E-015  1.212140296897683E-015
#  -1.212140296897683E-015
#  Number of sink =            1
#  Total mass in sink =   2.387985588230749E-011
#  simulation time =   1.033177274671964E-020
#  ================================================================================================================================================
#    Id     M[Msol]          x             y             z            vx            vy            vz    acc_rate[Msol/y] acc_lum[Lsol]     age
#  ================================================================================================================================================
#     1   0.23880E-10   0.20328E-16   0.20328E-16   0.20327E-16   0.33206E+00   0.33206E+00  -0.10302E-01   0.17253E-12   0.00000E+00   0.64000E-15
#  ================================================================================================================================================
#    Entering upload_fine for level 3
#    Entering make_boundary_hydro for level  3
