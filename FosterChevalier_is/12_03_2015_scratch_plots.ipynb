# %%
# %pylab inline
import plot_is
import yt
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import AxesGrid
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd /project/projectdirs/astro250/doris
# Out:
# /global/project/projectdirs/astro250/doris

# %%
physical_quantity="pressure"
timestep = 50
fns = ['ramses2/trunk/ramses/bin/output_{0}/info_{0}.txt'.format(str(timestep).zfill(5)), 'ramses2_data/data/output_{0}/info_{0}.txt'.format(str(timestep).zfill(5))]
fig = plt.figure()
grid = AxesGrid(fig, (0.075,0.075,0.85,0.85),
                nrows_ncols = (1,2),
                axes_pad = 0.05,
                label_mode = "L",
                share_all = True,
                cbar_location="right",
                cbar_mode="single",
                cbar_size="3%",
                cbar_pad="0%")
for i, fn in enumerate(fns):
    ds = yt.load(fn) 
    slc = yt.SlicePlot(ds, "z",physical_quantity)
    slc.set_axes_unit('pc')
    slc.set_cmap(physical_quantity,"rainbow")
    slc.set_font_size(20)
#     slc.set_zlim(physical_quantity, 1e-35, 1e-26)# Ensure the colorbar limits match for all plots
    slc.annotate_text((0.05, 0.02),"time: {} Myrs".format(timestep*61793.091/1000000.), coord_system='axis')
    #Forcing Sliceplot to redraw AxesGrid
    plot = slc.plots[physical_quantity]
    plot.figure = fig
    plot.axes = grid[i].axes
    plot.cax = grid.cbar_axes[i]
    slc._setup_plots()

# %%
physical_quantity="pressure"
timestep = 100
fns = ['ramses2/trunk/ramses/bin/output_{0}/info_{0}.txt'.format(str(timestep).zfill(5)), 'ramses2_data/data/output_{0}/info_{0}.txt'.format(str(timestep).zfill(5))]
fig = plt.figure()
grid = AxesGrid(fig, (0.075,0.075,0.85,0.85),
                nrows_ncols = (1,2),
                axes_pad = 0.05,
                label_mode = "L",
                share_all = True,
                cbar_location="right",
                cbar_mode="single",
                cbar_size="3%",
                cbar_pad="0%")
for i, fn in enumerate(fns):
    ds = yt.load(fn) 
    slc = yt.SlicePlot(ds, "z",physical_quantity)
    slc.set_axes_unit('pc')
    slc.set_cmap(physical_quantity,"rainbow")
    slc.set_font_size(20)
#     slc.set_zlim(physical_quantity, 1e-35, 1e-26)# Ensure the colorbar limits match for all plots
    slc.annotate_text((0.05, 0.02),"time: {} Myrs".format(timestep*61793.091/1000000.), coord_system='axis')
    #Forcing Sliceplot to redraw AxesGrid
    plot = slc.plots[physical_quantity]
    plot.figure = fig
    plot.axes = grid[i].axes
    plot.cax = grid.cbar_axes[i]
    slc._setup_plots()

# %%
physical_quantity="density"
for timestep in np.arange(1,113):
    if timestep %10 ==0:
        fns = ['ramses2/trunk/ramses/bin/output_{0}/info_{0}.txt'.format(str(timestep).zfill(5)), 'ramses2_data/data/output_{0}/info_{0}.txt'.format(str(timestep).zfill(5))]
        fig = plt.figure()
        grid = AxesGrid(fig, (0.075,0.075,0.85,0.85),
                        nrows_ncols = (1,2),
                        axes_pad = 0.05,
                        label_mode = "L",
                        share_all = True,
                        cbar_location="right",
                        cbar_mode="single",
                        cbar_size="3%",
                        cbar_pad="0%")
        for i, fn in enumerate(fns):
            ds = yt.load(fn) 
            slc = yt.SlicePlot(ds, "z",physical_quantity)
            slc.set_axes_unit('pc')
            slc.set_cmap(physical_quantity,"rainbow")
            slc.set_font_size(20)
            slc.set_zlim(physical_quantity, 1e-32, 1e-26)# Ensure the colorbar limits match for all plots
            slc.annotate_text((0.05, 0.02),"time: {} Myrs".format(timestep*61793.091/1000000.), coord_system='axis')
            #Forcing Sliceplot to redraw AxesGrid
            plot = slc.plots[physical_quantity]
            plot.figure = fig
            plot.axes = grid[i].axes
            plot.cax = grid.cbar_axes[i]
            slc._setup_plots()
